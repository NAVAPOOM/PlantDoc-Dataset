# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import os
import torch
import torchvision.transforms as transforms
import glob
import torchvision
import time
import random
from PIL import Image
from torch.utils.data import DataLoader, Dataset

# %%
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split

ROOT_DIR_TRAIN = "train"
ROOT_DIR_TEST = "test"

# Common transforms
common_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Prepare the Dataset
dataset = datasets.ImageFolder(root=ROOT_DIR_TRAIN, transform=common_transform)

train_size = int(0.80 * len(dataset))
valid_size = len(dataset) - train_size

# Use random_split to create train and validation datasets
train_dataset, valid_dataset = random_split(dataset, [train_size, valid_size])
test_dataset = datasets.ImageFolder(root=ROOT_DIR_TEST, transform=common_transform)

# Prepare the Data Loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=4)

# %%
num_images = len(dataset)
num_classes = len(dataset.classes)
print(f"Number of Images: {num_images}")
print(f"Number of Classes: {num_classes}")
# Out:
# Number of Images: 2316
# Number of Classes: 27

# %%
num_images = len(test_dataset)
num_classes = len(test_dataset.classes)
print(f"Number of Images: {num_images}")
print(f"Number of Classes: {num_classes}")
# Out:
# Number of Images: 236
# Number of Classes: 27

# %%
print(f"Number of training images: {len(train_dataset)}")
print(f"Number of validation images: {len(valid_dataset)}")
print(f"Number of test images: {len(test_dataset)}")
# Out:
# Number of training images: 1852
# Number of validation images: 464
# Number of test images: 236

# %%
from torchvision import models
dir(models)
# Out:
# ['AlexNet',
#  'AlexNet_Weights',
#  'ConvNeXt',
#  'ConvNeXt_Base_Weights',
#  'ConvNeXt_Large_Weights',
#  'ConvNeXt_Small_Weights',
#  'ConvNeXt_Tiny_Weights',
#  'DenseNet',
#  'DenseNet121_Weights',
#  'DenseNet161_Weights',
#  'DenseNet169_Weights',
#  'DenseNet201_Weights',
#  'EfficientNet',
#  'EfficientNet_B0_Weights',
#  'EfficientNet_B1_Weights',
#  'EfficientNet_B2_Weights',
#  'EfficientNet_B3_Weights',
#  'EfficientNet_B4_Weights',
#  'EfficientNet_B5_Weights',
#  'EfficientNet_B6_Weights',
#  'EfficientNet_B7_Weights',
#  'EfficientNet_V2_L_Weights',
#  'EfficientNet_V2_M_Weights',
#  'EfficientNet_V2_S_Weights',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'GoogLeNet_Weights',
#  'Inception3',
#  'InceptionOutputs',
#  'Inception_V3_Weights',
#  'MNASNet',
#  'MNASNet0_5_Weights',
#  'MNASNet0_75_Weights',
#  'MNASNet1_0_Weights',
#  'MNASNet1_3_Weights',
#  'MaxVit',
#  'MaxVit_T_Weights',
#  'MobileNetV2',
#  'MobileNetV3',
#  'MobileNet_V2_Weights',
#  'MobileNet_V3_Large_Weights',
#  'MobileNet_V3_Small_Weights',
#  'RegNet',
#  'RegNet_X_16GF_Weights',
#  'RegNet_X_1_6GF_Weights',
#  'RegNet_X_32GF_Weights',
#  'RegNet_X_3_2GF_Weights',
#  'RegNet_X_400MF_Weights',
#  'RegNet_X_800MF_Weights',
#  'RegNet_X_8GF_Weights',
#  'RegNet_Y_128GF_Weights',
#  'RegNet_Y_16GF_Weights',
#  'RegNet_Y_1_6GF_Weights',
#  'RegNet_Y_32GF_Weights',
#  'RegNet_Y_3_2GF_Weights',
#  'RegNet_Y_400MF_Weights',
#  'RegNet_Y_800MF_Weights',
#  'RegNet_Y_8GF_Weights',
#  'ResNeXt101_32X8D_Weights',
#  'ResNeXt101_64X4D_Weights',
#  'ResNeXt50_32X4D_Weights',
#  'ResNet',
#  'ResNet101_Weights',
#  'ResNet152_Weights',
#  'ResNet18_Weights',
#  'ResNet34_Weights',
#  'ResNet50_Weights',
#  'ShuffleNetV2',
#  'ShuffleNet_V2_X0_5_Weights',
#  'ShuffleNet_V2_X1_0_Weights',
#  'ShuffleNet_V2_X1_5_Weights',
#  'ShuffleNet_V2_X2_0_Weights',
#  'SqueezeNet',
#  'SqueezeNet1_0_Weights',
#  'SqueezeNet1_1_Weights',
#  'SwinTransformer',
#  'Swin_B_Weights',
#  'Swin_S_Weights',
#  'Swin_T_Weights',
#  'Swin_V2_B_Weights',
#  'Swin_V2_S_Weights',
#  'Swin_V2_T_Weights',
#  'VGG',
#  'VGG11_BN_Weights',
#  'VGG11_Weights',
#  'VGG13_BN_Weights',
#  'VGG13_Weights',
#  'VGG16_BN_Weights',
#  'VGG16_Weights',
#  'VGG19_BN_Weights',
#  'VGG19_Weights',
#  'ViT_B_16_Weights',
#  'ViT_B_32_Weights',
#  'ViT_H_14_Weights',
#  'ViT_L_16_Weights',
#  'ViT_L_32_Weights',
#  'VisionTransformer',
#  'Weights',
#  'WeightsEnum',
#  'Wide_ResNet101_2_Weights',
#  'Wide_ResNet50_2_Weights',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_api',
#  '_meta',
#  '_utils',
#  'alexnet',
#  'convnext',
#  'convnext_base',
#  'convnext_large',
#  'convnext_small',
#  'convnext_tiny',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'efficientnet',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'efficientnet_b3',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_v2_l',
#  'efficientnet_v2_m',
#  'efficientnet_v2_s',
#  'get_model',
#  'get_model_builder',
#  'get_model_weights',
#  'get_weight',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'list_models',
#  'maxvit',
#  'maxvit_t',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'optical_flow',
#  'quantization',
#  'regnet',
#  'regnet_x_16gf',
#  'regnet_x_1_6gf',
#  'regnet_x_32gf',
#  'regnet_x_3_2gf',
#  'regnet_x_400mf',
#  'regnet_x_800mf',
#  'regnet_x_8gf',
#  'regnet_y_128gf',
#  'regnet_y_16gf',
#  'regnet_y_1_6gf',
#  'regnet_y_32gf',
#  'regnet_y_3_2gf',
#  'regnet_y_400mf',
#  'regnet_y_800mf',
#  'regnet_y_8gf',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext101_64x4d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'swin_b',
#  'swin_s',
#  'swin_t',
#  'swin_transformer',
#  'swin_v2_b',
#  'swin_v2_s',
#  'swin_v2_t',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'video',
#  'vision_transformer',
#  'vit_b_16',
#  'vit_b_32',
#  'vit_h_14',
#  'vit_l_16',
#  'vit_l_32',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
# !pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.9/dist-packages (1.5.1)

# %%
import torch.nn as nn
from torchsummary import summary
from torchvision import models

# Load a pre-trained VGG-16 model
vgg16 = models.vgg16(pretrained=True)

# Set the number of classes to match your dataset
num_classes = 27

# Modify the fully connected layer to match the number of classes
vgg16.classifier[6] = nn.Linear(vgg16.classifier[6].in_features, num_classes)

# Set the device (CPU or GPU)
vgg16.to(device)

# Display the model summary
summary(vgg16, input_size=(3, 224, 224))
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:07<00:00, 78.3MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#         MaxPool2d-17          [-1, 256, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       1,180,160
#              ReLU-19          [-1, 512, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       2,359,808
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#         MaxPool2d-24          [-1, 512, 14, 14]               0
#            Conv2d-25          [-1, 512, 14, 14]       2,359,808
#              ReLU-26          [-1, 512, 14, 14]               0
#            Conv2d-27          [-1, 512, 14, 14]       2,359,808
#              ReLU-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#         MaxPool2d-31            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                   [-1, 27]         110,619
# ================================================================
# Total params: 134,371,163
# Trainable params: 134,371,163
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 218.77
# Params size (MB): 512.59
# Estimated Total Size (MB): 731.93
# ----------------------------------------------------------------

# %%
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader, Subset
import numpy as np

def train_model(model, criterion, optimizer, dataloader, device):
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

def validate_model(model, criterion, dataloader, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(dataloader.dataset)
        epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

# %%
def test_model(model, criterion, test_loader, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(test_loader.dataset)
        epoch_acc = running_corrects.double() / len(test_loader.dataset)

    return epoch_loss, epoch_acc

# %%
torch.backends.cudnn.benchmark = True

# %%
# Set the number of folds
num_folds = 5

# Prepare the data
X = np.arange(len(dataset))
y = np.array([label for _, label in dataset.imgs])

# Set up the StratifiedKFold
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Set device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize lists to store fold results
fold_train_losses = []
fold_valid_losses = []
fold_test_losses = []
fold_train_accs = []
fold_valid_accs = []
fold_test_accs = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, y)):
    print(f"Fold {fold + 1}/{num_folds}")

    # Create data loaders for the current fold
    train_data = Subset(dataset, train_index)
    valid_data = Subset(dataset, valid_index)
    train_loader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=4)
    valid_loader = DataLoader(valid_data, batch_size=32, shuffle=False, num_workers=4)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

    # Load and prepare the model
    model = models.vgg16(pretrained=True)
    model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)
    model.to(device)

    # Set the criterion and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    # Train and validate the model
    num_epochs = 50
    epoch_train_losses = []
    epoch_valid_losses = []
    epoch_test_losses = []
    epoch_train_accs = []
    epoch_valid_accs = []
    epoch_test_accs = []
    for epoch in range(num_epochs):
        train_loss, train_acc = train_model(model, criterion, optimizer, train_loader, device)
        valid_loss, valid_acc = validate_model(model, criterion, valid_loader, device)
        test_loss, test_acc = test_model(model, criterion, test_loader, device)

        epoch_train_losses.append(train_loss)
        epoch_valid_losses.append(valid_loss)
        epoch_test_losses.append(test_loss)
        epoch_train_accs.append(train_acc)
        epoch_valid_accs.append(valid_acc)
        epoch_test_accs.append(test_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}: "
              f"Train Loss: {train_loss:.4f} Train Accuracy: {train_acc * 100:.4f} "
              f"Valid Loss: {valid_loss:.4f} Valid Accuracy: {valid_acc * 100:.4f} "
              f"Test Loss: {test_loss:.4f} Test Accuracy: {test_acc * 100:.4f}")

    fold_train_losses.append(epoch_train_losses)
    fold_valid_losses.append(epoch_valid_losses)
    fold_test_losses.append(epoch_test_losses)
    fold_train_accs.append(epoch_train_accs)
    fold_valid_accs.append(epoch_valid_accs)
    fold_test_accs.append(epoch_test_accs)

    print("Finished Fold")
    print("=" * 50)
# Out:
# Fold 1/5
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50: Train Loss: 2.7975 Train Accuracy: 20.2484 Valid Loss: 2.0451 Valid Accuracy: 39.2241 Test Loss: 2.3032 Test Accuracy: 31.7797
# Epoch 2/50: Train Loss: 1.7470 Train Accuracy: 45.8423 Valid Loss: 1.6961 Valid Accuracy: 46.5517 Test Loss: 1.8469 Test Accuracy: 40.2542
# Epoch 3/50: Train Loss: 1.2775 Train Accuracy: 58.7473 Valid Loss: 1.4493 Valid Accuracy: 55.1724 Test Loss: 1.5030 Test Accuracy: 49.1525
# Epoch 4/50: Train Loss: 0.9106 Train Accuracy: 69.6544 Valid Loss: 1.4612 Valid Accuracy: 54.5259 Test Loss: 1.6277 Test Accuracy: 47.8814
# Epoch 5/50: Train Loss: 0.7328 Train Accuracy: 74.5140 Valid Loss: 1.4467 Valid Accuracy: 56.8966 Test Loss: 1.4915 Test Accuracy: 48.3051
# Epoch 6/50: Train Loss: 0.5413 Train Accuracy: 81.6415 Valid Loss: 1.4972 Valid Accuracy: 54.5259 Test Loss: 1.4913 Test Accuracy: 53.8136
# Epoch 7/50: Train Loss: 0.3696 Train Accuracy: 87.7970 Valid Loss: 1.6408 Valid Accuracy: 59.0517 Test Loss: 1.8211 Test Accuracy: 54.2373
# Epoch 8/50: Train Loss: 0.3350 Train Accuracy: 88.9309 Valid Loss: 1.4818 Valid Accuracy: 60.3448 Test Loss: 1.7107 Test Accuracy: 52.1186
# Epoch 9/50: Train Loss: 0.2063 Train Accuracy: 93.2505 Valid Loss: 1.6528 Valid Accuracy: 56.6810 Test Loss: 1.6444 Test Accuracy: 53.8136
# Epoch 10/50: Train Loss: 0.1692 Train Accuracy: 94.6004 Valid Loss: 1.6937 Valid Accuracy: 57.7586 Test Loss: 1.6236 Test Accuracy: 57.6271
# Epoch 11/50: Train Loss: 0.1440 Train Accuracy: 95.3024 Valid Loss: 1.8533 Valid Accuracy: 57.3276 Test Loss: 1.8060 Test Accuracy: 55.5085
# Epoch 12/50: Train Loss: 0.1069 Train Accuracy: 96.7603 Valid Loss: 2.0737 Valid Accuracy: 60.1293 Test Loss: 2.1856 Test Accuracy: 50.8475
# Epoch 13/50: Train Loss: 0.1120 Train Accuracy: 96.8143 Valid Loss: 1.8958 Valid Accuracy: 61.4224 Test Loss: 1.9380 Test Accuracy: 52.9661
# Epoch 14/50: Train Loss: 0.1309 Train Accuracy: 96.6523 Valid Loss: 1.6886 Valid Accuracy: 60.9914 Test Loss: 1.7524 Test Accuracy: 54.2373
# Epoch 15/50: Train Loss: 0.0996 Train Accuracy: 96.9762 Valid Loss: 1.8044 Valid Accuracy: 59.0517 Test Loss: 2.0897 Test Accuracy: 54.6610
# Epoch 16/50: Train Loss: 0.0652 Train Accuracy: 98.5421 Valid Loss: 1.9862 Valid Accuracy: 61.8534 Test Loss: 2.2686 Test Accuracy: 52.9661
# Epoch 17/50: Train Loss: 0.0697 Train Accuracy: 98.0022 Valid Loss: 1.7036 Valid Accuracy: 61.2069 Test Loss: 1.9586 Test Accuracy: 54.6610
# Epoch 18/50: Train Loss: 0.0542 Train Accuracy: 97.9482 Valid Loss: 2.1177 Valid Accuracy: 61.6379 Test Loss: 2.2699 Test Accuracy: 55.5085
# Epoch 19/50: Train Loss: 0.0672 Train Accuracy: 97.9482 Valid Loss: 1.9558 Valid Accuracy: 61.8534 Test Loss: 2.3019 Test Accuracy: 56.7797
# Epoch 20/50: Train Loss: 0.0621 Train Accuracy: 97.3542 Valid Loss: 1.9343 Valid Accuracy: 59.2672 Test Loss: 2.0755 Test Accuracy: 55.0847
# Epoch 21/50: Train Loss: 0.0521 Train Accuracy: 98.1641 Valid Loss: 1.8231 Valid Accuracy: 59.0517 Test Loss: 2.1345 Test Accuracy: 55.5085
# Epoch 22/50: Train Loss: 0.0567 Train Accuracy: 98.3261 Valid Loss: 1.8205 Valid Accuracy: 60.3448 Test Loss: 1.9225 Test Accuracy: 59.7458
# Epoch 23/50: Train Loss: 0.0391 Train Accuracy: 98.9741 Valid Loss: 1.8625 Valid Accuracy: 62.0690 Test Loss: 2.1237 Test Accuracy: 58.4746
# Epoch 24/50: Train Loss: 0.0437 Train Accuracy: 98.8121 Valid Loss: 1.8719 Valid Accuracy: 62.5000 Test Loss: 2.2193 Test Accuracy: 54.6610
# Epoch 25/50: Train Loss: 0.0242 Train Accuracy: 99.2441 Valid Loss: 2.0529 Valid Accuracy: 62.7155 Test Loss: 2.2406 Test Accuracy: 57.2034
# Epoch 26/50: Train Loss: 0.0351 Train Accuracy: 98.7581 Valid Loss: 1.8928 Valid Accuracy: 59.4828 Test Loss: 2.2662 Test Accuracy: 57.2034
# Epoch 27/50: Train Loss: 0.0345 Train Accuracy: 98.5961 Valid Loss: 1.8110 Valid Accuracy: 61.2069 Test Loss: 2.0694 Test Accuracy: 55.0847
# Epoch 28/50: Train Loss: 0.0269 Train Accuracy: 99.0281 Valid Loss: 1.8916 Valid Accuracy: 60.5603 Test Loss: 2.1006 Test Accuracy: 58.8983
# Epoch 29/50: Train Loss: 0.0300 Train Accuracy: 98.7041 Valid Loss: 1.9072 Valid Accuracy: 61.2069 Test Loss: 2.2246 Test Accuracy: 55.9322
# Epoch 30/50: Train Loss: 0.0277 Train Accuracy: 98.9741 Valid Loss: 1.8456 Valid Accuracy: 62.7155 Test Loss: 2.2293 Test Accuracy: 57.2034
# Epoch 31/50: Train Loss: 0.0232 Train Accuracy: 99.0281 Valid Loss: 2.0997 Valid Accuracy: 61.8534 Test Loss: 2.4109 Test Accuracy: 57.6271
# Epoch 32/50: Train Loss: 0.0316 Train Accuracy: 98.8121 Valid Loss: 2.0925 Valid Accuracy: 60.5603 Test Loss: 2.2028 Test Accuracy: 56.7797
# Epoch 33/50: Train Loss: 0.0276 Train Accuracy: 98.9201 Valid Loss: 2.0325 Valid Accuracy: 61.2069 Test Loss: 2.2791 Test Accuracy: 55.0847
# Epoch 34/50: Train Loss: 0.0222 Train Accuracy: 99.1901 Valid Loss: 2.1487 Valid Accuracy: 60.3448 Test Loss: 2.3427 Test Accuracy: 57.2034
# Epoch 35/50: Train Loss: 0.0427 Train Accuracy: 98.3261 Valid Loss: 2.5419 Valid Accuracy: 60.3448 Test Loss: 2.5453 Test Accuracy: 54.6610
# Epoch 36/50: Train Loss: 0.0284 Train Accuracy: 98.9741 Valid Loss: 2.0496 Valid Accuracy: 64.0086 Test Loss: 2.4092 Test Accuracy: 54.2373
# Epoch 37/50: Train Loss: 0.0235 Train Accuracy: 99.1901 Valid Loss: 2.1946 Valid Accuracy: 60.7759 Test Loss: 2.4288 Test Accuracy: 54.6610
# Epoch 38/50: Train Loss: 0.0205 Train Accuracy: 99.1901 Valid Loss: 2.0959 Valid Accuracy: 62.9310 Test Loss: 2.5947 Test Accuracy: 54.2373
# Epoch 39/50: Train Loss: 0.0238 Train Accuracy: 98.9741 Valid Loss: 2.0263 Valid Accuracy: 61.2069 Test Loss: 2.3761 Test Accuracy: 57.6271
# Epoch 40/50: Train Loss: 0.0240 Train Accuracy: 99.0281 Valid Loss: 2.1567 Valid Accuracy: 60.9914 Test Loss: 2.5006 Test Accuracy: 56.7797
# Epoch 41/50: Train Loss: 0.0176 Train Accuracy: 99.1361 Valid Loss: 2.2020 Valid Accuracy: 62.2845 Test Loss: 2.5807 Test Accuracy: 55.9322
# Epoch 42/50: Train Loss: 0.0297 Train Accuracy: 98.7041 Valid Loss: 2.2035 Valid Accuracy: 59.0517 Test Loss: 2.2620 Test Accuracy: 59.7458
# Epoch 43/50: Train Loss: 0.0259 Train Accuracy: 98.8661 Valid Loss: 2.1218 Valid Accuracy: 62.2845 Test Loss: 2.4027 Test Accuracy: 57.2034
# Epoch 44/50: Train Loss: 0.0216 Train Accuracy: 98.7581 Valid Loss: 2.0976 Valid Accuracy: 61.6379 Test Loss: 2.4684 Test Accuracy: 56.3559
# Epoch 45/50: Train Loss: 0.0206 Train Accuracy: 98.9741 Valid Loss: 2.0093 Valid Accuracy: 60.5603 Test Loss: 2.3793 Test Accuracy: 58.0508
# Epoch 46/50: Train Loss: 0.0136 Train Accuracy: 99.4600 Valid Loss: 2.2013 Valid Accuracy: 61.6379 Test Loss: 2.4599 Test Accuracy: 58.8983
# Epoch 47/50: Train Loss: 0.0169 Train Accuracy: 99.2441 Valid Loss: 2.1657 Valid Accuracy: 62.9310 Test Loss: 2.4597 Test Accuracy: 56.3559
# Epoch 48/50: Train Loss: 0.0181 Train Accuracy: 99.1361 Valid Loss: 2.0636 Valid Accuracy: 60.5603 Test Loss: 2.5024 Test Accuracy: 55.0847
# Epoch 49/50: Train Loss: 0.0191 Train Accuracy: 99.2441 Valid Loss: 2.1532 Valid Accuracy: 62.2845 Test Loss: 2.5119 Test Accuracy: 56.7797
# Epoch 50/50: Train Loss: 0.0283 Train Accuracy: 98.8661 Valid Loss: 2.1107 Valid Accuracy: 60.7759 Test Loss: 2.5130 Test Accuracy: 54.2373
# Finished Fold
# ==================================================
# Fold 2/5
# Epoch 1/50: Train Loss: 2.6445 Train Accuracy: 25.0944 Valid Loss: 1.7474 Valid Accuracy: 44.2765 Test Loss: 1.9454 Test Accuracy: 38.5593
# Epoch 2/50: Train Loss: 1.5765 Train Accuracy: 50.3508 Valid Loss: 1.4924 Valid Accuracy: 52.0518 Test Loss: 1.6767 Test Accuracy: 44.9153
# Epoch 3/50: Train Loss: 1.2694 Train Accuracy: 58.7696 Valid Loss: 1.3330 Valid Accuracy: 57.8834 Test Loss: 1.5747 Test Accuracy: 47.0339
# Epoch 4/50: Train Loss: 0.9157 Train Accuracy: 68.7534 Valid Loss: 1.2915 Valid Accuracy: 58.5313 Test Loss: 1.4863 Test Accuracy: 47.8814
# Epoch 5/50: Train Loss: 0.7297 Train Accuracy: 75.9309 Valid Loss: 1.2958 Valid Accuracy: 60.0432 Test Loss: 1.4293 Test Accuracy: 52.5424
# Epoch 6/50: Train Loss: 0.5726 Train Accuracy: 81.2196 Valid Loss: 1.2720 Valid Accuracy: 63.2829 Test Loss: 1.4567 Test Accuracy: 54.2373
# Epoch 7/50: Train Loss: 0.4177 Train Accuracy: 86.8861 Valid Loss: 1.4010 Valid Accuracy: 56.3715 Test Loss: 1.6963 Test Accuracy: 51.6949
# Epoch 8/50: Train Loss: 0.3024 Train Accuracy: 90.1241 Valid Loss: 1.5881 Valid Accuracy: 61.7711 Test Loss: 1.7223 Test Accuracy: 56.3559
# Epoch 9/50: Train Loss: 0.2406 Train Accuracy: 92.0669 Valid Loss: 1.5669 Valid Accuracy: 60.9071 Test Loss: 1.6870 Test Accuracy: 55.9322
# Epoch 10/50: Train Loss: 0.1982 Train Accuracy: 93.0383 Valid Loss: 1.5583 Valid Accuracy: 59.6112 Test Loss: 1.9688 Test Accuracy: 53.3898
# Epoch 11/50: Train Loss: 0.1739 Train Accuracy: 94.1716 Valid Loss: 1.4168 Valid Accuracy: 62.6350 Test Loss: 1.7101 Test Accuracy: 56.7797
# Epoch 12/50: Train Loss: 0.1336 Train Accuracy: 95.7906 Valid Loss: 1.6143 Valid Accuracy: 61.5551 Test Loss: 2.0450 Test Accuracy: 54.2373
# Epoch 13/50: Train Loss: 0.0846 Train Accuracy: 97.2477 Valid Loss: 1.6947 Valid Accuracy: 60.4752 Test Loss: 1.8903 Test Accuracy: 57.6271
# Epoch 14/50: Train Loss: 0.0976 Train Accuracy: 96.9239 Valid Loss: 1.7976 Valid Accuracy: 57.6674 Test Loss: 2.1461 Test Accuracy: 52.1186
# Epoch 15/50: Train Loss: 0.0981 Train Accuracy: 97.1937 Valid Loss: 1.7095 Valid Accuracy: 60.0432 Test Loss: 1.8128 Test Accuracy: 57.2034
# Epoch 16/50: Train Loss: 0.0857 Train Accuracy: 97.3017 Valid Loss: 1.8732 Valid Accuracy: 60.2592 Test Loss: 1.9501 Test Accuracy: 54.2373
# Epoch 17/50: Train Loss: 0.0642 Train Accuracy: 98.0032 Valid Loss: 2.0076 Valid Accuracy: 61.7711 Test Loss: 2.1680 Test Accuracy: 55.5085
# Epoch 18/50: Train Loss: 0.0524 Train Accuracy: 98.4889 Valid Loss: 1.8501 Valid Accuracy: 63.0670 Test Loss: 2.1958 Test Accuracy: 56.7797
# Epoch 19/50: Train Loss: 0.0434 Train Accuracy: 98.5969 Valid Loss: 1.7253 Valid Accuracy: 60.6911 Test Loss: 2.0168 Test Accuracy: 54.6610
# Epoch 20/50: Train Loss: 0.0569 Train Accuracy: 98.4889 Valid Loss: 1.8144 Valid Accuracy: 61.1231 Test Loss: 2.0493 Test Accuracy: 53.3898
# Epoch 21/50: Train Loss: 0.0567 Train Accuracy: 98.3810 Valid Loss: 1.7260 Valid Accuracy: 61.3391 Test Loss: 2.0160 Test Accuracy: 52.9661
# Epoch 22/50: Train Loss: 0.0373 Train Accuracy: 98.6508 Valid Loss: 2.1665 Valid Accuracy: 60.9071 Test Loss: 2.3553 Test Accuracy: 52.9661
# Epoch 23/50: Train Loss: 0.0450 Train Accuracy: 98.9207 Valid Loss: 1.8028 Valid Accuracy: 65.2268 Test Loss: 2.1555 Test Accuracy: 58.0508
# Epoch 24/50: Train Loss: 0.0330 Train Accuracy: 99.0826 Valid Loss: 1.7240 Valid Accuracy: 62.4190 Test Loss: 2.1567 Test Accuracy: 56.3559
# Epoch 25/50: Train Loss: 0.0237 Train Accuracy: 99.2445 Valid Loss: 1.8604 Valid Accuracy: 64.1469 Test Loss: 2.2434 Test Accuracy: 56.7797
# Epoch 26/50: Train Loss: 0.0169 Train Accuracy: 99.3524 Valid Loss: 1.9937 Valid Accuracy: 63.4989 Test Loss: 2.3753 Test Accuracy: 56.3559
# Epoch 27/50: Train Loss: 0.0213 Train Accuracy: 99.2445 Valid Loss: 1.8056 Valid Accuracy: 65.6587 Test Loss: 2.1734 Test Accuracy: 57.6271
# Epoch 28/50: Train Loss: 0.0141 Train Accuracy: 99.4603 Valid Loss: 1.8472 Valid Accuracy: 63.4989 Test Loss: 2.3410 Test Accuracy: 55.5085
# Epoch 29/50: Train Loss: 0.0247 Train Accuracy: 99.2445 Valid Loss: 1.7517 Valid Accuracy: 64.1469 Test Loss: 2.1343 Test Accuracy: 57.6271
# Epoch 30/50: Train Loss: 0.0156 Train Accuracy: 99.4064 Valid Loss: 2.0671 Valid Accuracy: 63.2829 Test Loss: 2.7076 Test Accuracy: 52.9661
# Epoch 31/50: Train Loss: 0.0208 Train Accuracy: 99.3524 Valid Loss: 2.0516 Valid Accuracy: 64.1469 Test Loss: 2.3412 Test Accuracy: 57.6271
# Epoch 32/50: Train Loss: 0.0185 Train Accuracy: 99.2984 Valid Loss: 2.0409 Valid Accuracy: 63.7149 Test Loss: 2.4249 Test Accuracy: 56.7797
# Epoch 33/50: Train Loss: 0.0264 Train Accuracy: 99.1905 Valid Loss: 1.9960 Valid Accuracy: 64.7948 Test Loss: 2.4374 Test Accuracy: 55.9322
# Epoch 34/50: Train Loss: 0.0178 Train Accuracy: 99.4603 Valid Loss: 2.4707 Valid Accuracy: 62.2030 Test Loss: 2.6519 Test Accuracy: 55.0847
# Epoch 35/50: Train Loss: 0.0453 Train Accuracy: 98.7048 Valid Loss: 1.7609 Valid Accuracy: 62.6350 Test Loss: 2.2139 Test Accuracy: 55.5085
# Epoch 36/50: Train Loss: 0.0220 Train Accuracy: 99.2445 Valid Loss: 1.8848 Valid Accuracy: 65.8747 Test Loss: 2.3347 Test Accuracy: 55.0847
# Epoch 37/50: Train Loss: 0.0149 Train Accuracy: 99.5143 Valid Loss: 2.0021 Valid Accuracy: 60.9071 Test Loss: 2.4781 Test Accuracy: 50.0000
# Epoch 38/50: Train Loss: 0.0215 Train Accuracy: 99.1905 Valid Loss: 2.0984 Valid Accuracy: 65.0108 Test Loss: 2.4280 Test Accuracy: 54.2373
# Epoch 39/50: Train Loss: 0.0162 Train Accuracy: 99.4603 Valid Loss: 2.2040 Valid Accuracy: 63.9309 Test Loss: 2.6254 Test Accuracy: 53.3898
# Epoch 40/50: Train Loss: 0.0197 Train Accuracy: 99.1365 Valid Loss: 2.1548 Valid Accuracy: 63.7149 Test Loss: 2.4819 Test Accuracy: 57.2034
# Epoch 41/50: Train Loss: 0.0240 Train Accuracy: 99.1365 Valid Loss: 1.9889 Valid Accuracy: 65.2268 Test Loss: 2.5418 Test Accuracy: 55.5085
# Epoch 42/50: Train Loss: 0.0140 Train Accuracy: 99.3524 Valid Loss: 2.0028 Valid Accuracy: 65.0108 Test Loss: 2.3727 Test Accuracy: 55.5085
# Epoch 43/50: Train Loss: 0.0112 Train Accuracy: 99.4603 Valid Loss: 2.0004 Valid Accuracy: 65.0108 Test Loss: 2.4356 Test Accuracy: 55.0847
# Epoch 44/50: Train Loss: 0.0152 Train Accuracy: 99.6762 Valid Loss: 2.0338 Valid Accuracy: 65.0108 Test Loss: 2.4970 Test Accuracy: 57.6271
# Epoch 45/50: Train Loss: 0.0118 Train Accuracy: 99.5683 Valid Loss: 2.0192 Valid Accuracy: 63.9309 Test Loss: 2.4761 Test Accuracy: 56.7797
# Epoch 46/50: Train Loss: 0.0159 Train Accuracy: 99.3524 Valid Loss: 1.9284 Valid Accuracy: 64.5788 Test Loss: 2.4296 Test Accuracy: 55.9322
# Epoch 47/50: Train Loss: 0.0215 Train Accuracy: 99.4064 Valid Loss: 1.9584 Valid Accuracy: 61.9870 Test Loss: 2.4095 Test Accuracy: 54.2373
# Epoch 48/50: Train Loss: 0.0129 Train Accuracy: 99.4603 Valid Loss: 2.0294 Valid Accuracy: 62.4190 Test Loss: 2.4855 Test Accuracy: 57.6271
# Epoch 49/50: Train Loss: 0.0115 Train Accuracy: 99.4064 Valid Loss: 2.0348 Valid Accuracy: 64.3629 Test Loss: 2.6459 Test Accuracy: 55.9322
# Epoch 50/50: Train Loss: 0.0098 Train Accuracy: 99.6762 Valid Loss: 2.0066 Valid Accuracy: 63.9309 Test Loss: 2.6559 Test Accuracy: 56.7797
# Finished Fold
# ==================================================
# Fold 3/5
# Epoch 1/50: Train Loss: 2.6917 Train Accuracy: 23.8532 Valid Loss: 1.8285 Valid Accuracy: 44.9244 Test Loss: 2.0775 Test Accuracy: 38.1356
# Epoch 2/50: Train Loss: 1.6139 Train Accuracy: 49.6492 Valid Loss: 1.5385 Valid Accuracy: 51.6199 Test Loss: 1.6826 Test Accuracy: 45.3390
# Epoch 3/50: Train Loss: 1.1932 Train Accuracy: 62.1695 Valid Loss: 1.3662 Valid Accuracy: 59.3952 Test Loss: 1.3820 Test Accuracy: 51.6949
# Epoch 4/50: Train Loss: 0.8548 Train Accuracy: 72.2072 Valid Loss: 1.4483 Valid Accuracy: 55.2916 Test Loss: 1.4670 Test Accuracy: 55.9322
# Epoch 5/50: Train Loss: 0.6964 Train Accuracy: 76.0389 Valid Loss: 1.4313 Valid Accuracy: 56.5875 Test Loss: 1.5253 Test Accuracy: 55.5085
# Epoch 6/50: Train Loss: 0.5385 Train Accuracy: 82.1910 Valid Loss: 1.3738 Valid Accuracy: 60.9071 Test Loss: 1.4319 Test Accuracy: 58.4746
# Epoch 7/50: Train Loss: 0.3493 Train Accuracy: 87.8575 Valid Loss: 1.7351 Valid Accuracy: 62.6350 Test Loss: 1.9203 Test Accuracy: 56.7797
# Epoch 8/50: Train Loss: 0.3298 Train Accuracy: 89.2067 Valid Loss: 1.6681 Valid Accuracy: 63.7149 Test Loss: 1.8114 Test Accuracy: 53.8136
# Epoch 9/50: Train Loss: 0.2200 Train Accuracy: 92.4987 Valid Loss: 1.7178 Valid Accuracy: 59.1793 Test Loss: 1.8701 Test Accuracy: 52.9661
# Epoch 10/50: Train Loss: 0.1452 Train Accuracy: 95.6287 Valid Loss: 1.7276 Valid Accuracy: 60.6911 Test Loss: 1.9068 Test Accuracy: 51.6949
# Epoch 11/50: Train Loss: 0.1379 Train Accuracy: 95.7366 Valid Loss: 1.7330 Valid Accuracy: 60.0432 Test Loss: 1.8081 Test Accuracy: 57.2034
# Epoch 12/50: Train Loss: 0.1617 Train Accuracy: 95.2509 Valid Loss: 1.9311 Valid Accuracy: 58.5313 Test Loss: 1.9519 Test Accuracy: 53.8136
# Epoch 13/50: Train Loss: 0.0979 Train Accuracy: 97.1398 Valid Loss: 1.7593 Valid Accuracy: 59.8272 Test Loss: 1.8804 Test Accuracy: 52.1186
# Epoch 14/50: Train Loss: 0.0912 Train Accuracy: 96.8160 Valid Loss: 2.0662 Valid Accuracy: 57.2354 Test Loss: 1.9977 Test Accuracy: 52.9661
# Epoch 15/50: Train Loss: 0.0834 Train Accuracy: 97.6255 Valid Loss: 1.8990 Valid Accuracy: 61.5551 Test Loss: 1.9941 Test Accuracy: 55.5085
# Epoch 16/50: Train Loss: 0.0601 Train Accuracy: 98.1651 Valid Loss: 1.7760 Valid Accuracy: 59.1793 Test Loss: 1.7569 Test Accuracy: 55.5085
# Epoch 17/50: Train Loss: 0.0856 Train Accuracy: 97.2477 Valid Loss: 1.8952 Valid Accuracy: 61.7711 Test Loss: 1.8053 Test Accuracy: 59.7458
# Epoch 18/50: Train Loss: 0.0639 Train Accuracy: 98.0032 Valid Loss: 1.9686 Valid Accuracy: 61.1231 Test Loss: 2.0542 Test Accuracy: 52.5424
# Epoch 19/50: Train Loss: 0.0662 Train Accuracy: 97.6794 Valid Loss: 2.1750 Valid Accuracy: 61.3391 Test Loss: 2.0778 Test Accuracy: 58.0508
# Epoch 20/50: Train Loss: 0.0500 Train Accuracy: 98.8127 Valid Loss: 2.2044 Valid Accuracy: 60.6911 Test Loss: 2.2615 Test Accuracy: 53.3898
# Epoch 21/50: Train Loss: 0.0720 Train Accuracy: 98.4350 Valid Loss: 1.7814 Valid Accuracy: 63.2829 Test Loss: 1.9721 Test Accuracy: 53.8136
# Epoch 22/50: Train Loss: 0.0415 Train Accuracy: 98.7048 Valid Loss: 1.9864 Valid Accuracy: 62.6350 Test Loss: 2.0247 Test Accuracy: 56.7797
# Epoch 23/50: Train Loss: 0.0300 Train Accuracy: 99.1905 Valid Loss: 1.9724 Valid Accuracy: 62.8510 Test Loss: 2.0298 Test Accuracy: 55.5085
# Epoch 24/50: Train Loss: 0.0247 Train Accuracy: 99.0826 Valid Loss: 2.0526 Valid Accuracy: 64.1469 Test Loss: 2.0777 Test Accuracy: 54.6610
# Epoch 25/50: Train Loss: 0.0217 Train Accuracy: 99.1365 Valid Loss: 1.9254 Valid Accuracy: 61.3391 Test Loss: 2.1518 Test Accuracy: 57.6271
# Epoch 26/50: Train Loss: 0.0466 Train Accuracy: 98.4889 Valid Loss: 2.0458 Valid Accuracy: 62.2030 Test Loss: 2.1333 Test Accuracy: 56.3559
# Epoch 27/50: Train Loss: 0.0305 Train Accuracy: 98.9746 Valid Loss: 2.1079 Valid Accuracy: 62.8510 Test Loss: 2.2107 Test Accuracy: 54.6610
# Epoch 28/50: Train Loss: 0.0307 Train Accuracy: 98.9207 Valid Loss: 2.0811 Valid Accuracy: 61.9870 Test Loss: 2.1386 Test Accuracy: 54.6610
# Epoch 29/50: Train Loss: 0.0256 Train Accuracy: 98.8667 Valid Loss: 2.1724 Valid Accuracy: 60.2592 Test Loss: 1.9745 Test Accuracy: 56.7797
# Epoch 30/50: Train Loss: 0.0206 Train Accuracy: 99.1905 Valid Loss: 2.1465 Valid Accuracy: 60.9071 Test Loss: 2.2122 Test Accuracy: 55.5085
# Epoch 31/50: Train Loss: 0.0222 Train Accuracy: 99.1905 Valid Loss: 2.1336 Valid Accuracy: 60.6911 Test Loss: 2.4324 Test Accuracy: 55.0847
# Epoch 32/50: Train Loss: 0.0201 Train Accuracy: 99.2445 Valid Loss: 2.2125 Valid Accuracy: 62.4190 Test Loss: 2.3115 Test Accuracy: 55.9322
# Epoch 33/50: Train Loss: 0.0255 Train Accuracy: 98.9746 Valid Loss: 2.0906 Valid Accuracy: 62.6350 Test Loss: 2.4351 Test Accuracy: 55.0847
# Epoch 34/50: Train Loss: 0.0214 Train Accuracy: 99.1365 Valid Loss: 2.0383 Valid Accuracy: 61.7711 Test Loss: 2.1594 Test Accuracy: 58.0508
# Epoch 35/50: Train Loss: 0.0202 Train Accuracy: 99.1365 Valid Loss: 1.9222 Valid Accuracy: 61.9870 Test Loss: 2.1982 Test Accuracy: 56.3559
# Epoch 36/50: Train Loss: 0.0505 Train Accuracy: 98.3270 Valid Loss: 1.9068 Valid Accuracy: 60.6911 Test Loss: 1.9844 Test Accuracy: 53.3898
# Epoch 37/50: Train Loss: 0.0251 Train Accuracy: 99.0826 Valid Loss: 2.0482 Valid Accuracy: 64.5788 Test Loss: 2.2048 Test Accuracy: 55.9322
# Epoch 38/50: Train Loss: 0.0205 Train Accuracy: 99.0286 Valid Loss: 2.2848 Valid Accuracy: 60.9071 Test Loss: 2.3695 Test Accuracy: 56.3559
# Epoch 39/50: Train Loss: 0.0175 Train Accuracy: 99.5683 Valid Loss: 2.1259 Valid Accuracy: 63.0670 Test Loss: 2.4471 Test Accuracy: 55.9322
# Epoch 40/50: Train Loss: 0.0206 Train Accuracy: 99.1365 Valid Loss: 2.2985 Valid Accuracy: 61.5551 Test Loss: 2.3271 Test Accuracy: 57.6271
# Epoch 41/50: Train Loss: 0.0193 Train Accuracy: 99.2445 Valid Loss: 2.2218 Valid Accuracy: 64.1469 Test Loss: 2.2690 Test Accuracy: 55.5085
# Epoch 42/50: Train Loss: 0.0126 Train Accuracy: 99.5143 Valid Loss: 2.3294 Valid Accuracy: 65.6587 Test Loss: 2.3238 Test Accuracy: 56.3559
# Epoch 43/50: Train Loss: 0.0144 Train Accuracy: 99.2445 Valid Loss: 2.2861 Valid Accuracy: 65.8747 Test Loss: 2.3920 Test Accuracy: 56.7797
# Epoch 44/50: Train Loss: 0.0146 Train Accuracy: 99.5143 Valid Loss: 2.1396 Valid Accuracy: 64.5788 Test Loss: 2.3370 Test Accuracy: 56.7797
# Epoch 45/50: Train Loss: 0.0128 Train Accuracy: 99.4603 Valid Loss: 2.2291 Valid Accuracy: 63.2829 Test Loss: 2.3196 Test Accuracy: 59.3220
# Epoch 46/50: Train Loss: 0.0115 Train Accuracy: 99.5143 Valid Loss: 2.3475 Valid Accuracy: 63.7149 Test Loss: 2.4641 Test Accuracy: 58.4746
# Epoch 47/50: Train Loss: 0.0160 Train Accuracy: 99.4064 Valid Loss: 2.1663 Valid Accuracy: 63.7149 Test Loss: 2.3583 Test Accuracy: 58.0508
# Epoch 48/50: Train Loss: 0.0192 Train Accuracy: 99.2984 Valid Loss: 2.2862 Valid Accuracy: 63.2829 Test Loss: 2.2329 Test Accuracy: 59.3220
# Epoch 49/50: Train Loss: 0.0125 Train Accuracy: 99.5143 Valid Loss: 2.1925 Valid Accuracy: 63.7149 Test Loss: 2.3919 Test Accuracy: 58.8983
# Epoch 50/50: Train Loss: 0.0134 Train Accuracy: 99.4603 Valid Loss: 2.1557 Valid Accuracy: 63.2829 Test Loss: 2.3904 Test Accuracy: 56.7797
# Finished Fold
# ==================================================
# Fold 4/5
# Epoch 1/50: Train Loss: 2.7231 Train Accuracy: 23.0437 Valid Loss: 1.8448 Valid Accuracy: 42.1166 Test Loss: 2.0781 Test Accuracy: 33.4746
# Epoch 2/50: Train Loss: 1.6817 Train Accuracy: 48.2461 Valid Loss: 1.6620 Valid Accuracy: 46.4363 Test Loss: 1.8275 Test Accuracy: 44.9153
# Epoch 3/50: Train Loss: 1.2264 Train Accuracy: 60.8743 Valid Loss: 1.3935 Valid Accuracy: 54.4276 Test Loss: 1.5458 Test Accuracy: 48.7288
# Epoch 4/50: Train Loss: 0.9084 Train Accuracy: 69.5089 Valid Loss: 1.3617 Valid Accuracy: 57.6674 Test Loss: 1.5151 Test Accuracy: 53.3898
# Epoch 5/50: Train Loss: 0.6820 Train Accuracy: 77.2261 Valid Loss: 1.4094 Valid Accuracy: 58.9633 Test Loss: 1.6829 Test Accuracy: 50.4237
# Epoch 6/50: Train Loss: 0.5152 Train Accuracy: 83.7561 Valid Loss: 1.4229 Valid Accuracy: 57.0194 Test Loss: 1.5084 Test Accuracy: 55.5085
# Epoch 7/50: Train Loss: 0.3659 Train Accuracy: 88.2893 Valid Loss: 1.4878 Valid Accuracy: 59.8272 Test Loss: 1.7188 Test Accuracy: 54.2373
# Epoch 8/50: Train Loss: 0.2964 Train Accuracy: 89.9083 Valid Loss: 1.4952 Valid Accuracy: 59.8272 Test Loss: 1.8820 Test Accuracy: 52.1186
# Epoch 9/50: Train Loss: 0.2163 Train Accuracy: 92.8225 Valid Loss: 1.5733 Valid Accuracy: 59.1793 Test Loss: 1.8223 Test Accuracy: 53.8136
# Epoch 10/50: Train Loss: 0.1677 Train Accuracy: 94.3875 Valid Loss: 1.6815 Valid Accuracy: 59.1793 Test Loss: 1.9494 Test Accuracy: 56.3559
# Epoch 11/50: Train Loss: 0.1753 Train Accuracy: 94.1176 Valid Loss: 1.7967 Valid Accuracy: 57.0194 Test Loss: 2.0550 Test Accuracy: 55.5085
# Epoch 12/50: Train Loss: 0.1700 Train Accuracy: 94.9271 Valid Loss: 1.5172 Valid Accuracy: 57.8834 Test Loss: 1.8713 Test Accuracy: 55.5085
# Epoch 13/50: Train Loss: 0.1168 Train Accuracy: 96.1684 Valid Loss: 1.6593 Valid Accuracy: 58.0994 Test Loss: 1.8166 Test Accuracy: 57.2034
# Epoch 14/50: Train Loss: 0.0874 Train Accuracy: 97.0858 Valid Loss: 1.8986 Valid Accuracy: 59.1793 Test Loss: 2.0567 Test Accuracy: 56.7797
# Epoch 15/50: Train Loss: 0.0882 Train Accuracy: 97.1398 Valid Loss: 1.6834 Valid Accuracy: 59.8272 Test Loss: 2.0599 Test Accuracy: 55.0847
# Epoch 16/50: Train Loss: 0.0704 Train Accuracy: 98.2731 Valid Loss: 1.7883 Valid Accuracy: 59.8272 Test Loss: 2.1693 Test Accuracy: 54.6610
# Epoch 17/50: Train Loss: 0.0540 Train Accuracy: 98.3810 Valid Loss: 1.9565 Valid Accuracy: 61.9870 Test Loss: 2.4367 Test Accuracy: 57.2034
# Epoch 18/50: Train Loss: 0.0516 Train Accuracy: 98.4889 Valid Loss: 1.8341 Valid Accuracy: 61.3391 Test Loss: 2.2761 Test Accuracy: 54.2373
# Epoch 19/50: Train Loss: 0.0478 Train Accuracy: 98.5969 Valid Loss: 1.6400 Valid Accuracy: 62.8510 Test Loss: 2.0046 Test Accuracy: 59.3220
# Epoch 20/50: Train Loss: 0.0520 Train Accuracy: 98.4350 Valid Loss: 1.9067 Valid Accuracy: 58.5313 Test Loss: 2.2813 Test Accuracy: 56.7797
# Epoch 21/50: Train Loss: 0.0382 Train Accuracy: 98.7048 Valid Loss: 2.0202 Valid Accuracy: 61.3391 Test Loss: 2.7034 Test Accuracy: 55.5085
# Epoch 22/50: Train Loss: 0.0559 Train Accuracy: 98.5429 Valid Loss: 1.7909 Valid Accuracy: 60.9071 Test Loss: 2.1789 Test Accuracy: 55.9322
# Epoch 23/50: Train Loss: 0.0446 Train Accuracy: 98.3270 Valid Loss: 1.8211 Valid Accuracy: 61.1231 Test Loss: 2.3459 Test Accuracy: 57.6271
# Epoch 24/50: Train Loss: 0.0403 Train Accuracy: 98.5429 Valid Loss: 1.7810 Valid Accuracy: 61.5551 Test Loss: 2.3768 Test Accuracy: 55.5085
# Epoch 25/50: Train Loss: 0.0265 Train Accuracy: 98.9207 Valid Loss: 2.1639 Valid Accuracy: 59.8272 Test Loss: 2.3817 Test Accuracy: 58.0508
# Epoch 26/50: Train Loss: 0.0340 Train Accuracy: 98.8667 Valid Loss: 1.9843 Valid Accuracy: 61.1231 Test Loss: 2.4841 Test Accuracy: 55.0847
# Epoch 27/50: Train Loss: 0.0354 Train Accuracy: 98.6508 Valid Loss: 2.1916 Valid Accuracy: 59.3952 Test Loss: 2.5989 Test Accuracy: 55.0847
# Epoch 28/50: Train Loss: 0.0296 Train Accuracy: 99.0826 Valid Loss: 2.0184 Valid Accuracy: 61.7711 Test Loss: 2.4812 Test Accuracy: 55.9322
# Epoch 29/50: Train Loss: 0.0231 Train Accuracy: 98.9207 Valid Loss: 1.9397 Valid Accuracy: 59.6112 Test Loss: 2.4016 Test Accuracy: 55.5085
# Epoch 30/50: Train Loss: 0.0211 Train Accuracy: 99.1905 Valid Loss: 1.9167 Valid Accuracy: 62.4190 Test Loss: 2.4600 Test Accuracy: 57.2034
# Epoch 31/50: Train Loss: 0.0272 Train Accuracy: 99.1365 Valid Loss: 2.0114 Valid Accuracy: 61.1231 Test Loss: 2.4438 Test Accuracy: 55.0847
# Epoch 32/50: Train Loss: 0.0208 Train Accuracy: 99.1365 Valid Loss: 2.0248 Valid Accuracy: 62.6350 Test Loss: 2.5721 Test Accuracy: 54.2373
# Epoch 33/50: Train Loss: 0.0298 Train Accuracy: 99.0286 Valid Loss: 1.8818 Valid Accuracy: 61.3391 Test Loss: 2.3344 Test Accuracy: 54.6610
# Epoch 34/50: Train Loss: 0.0189 Train Accuracy: 99.3524 Valid Loss: 2.0628 Valid Accuracy: 61.3391 Test Loss: 2.5490 Test Accuracy: 55.9322
# Epoch 35/50: Train Loss: 0.0202 Train Accuracy: 99.1905 Valid Loss: 2.0342 Valid Accuracy: 59.8272 Test Loss: 2.4810 Test Accuracy: 56.7797
# Epoch 36/50: Train Loss: 0.0212 Train Accuracy: 99.0826 Valid Loss: 2.0247 Valid Accuracy: 58.5313 Test Loss: 2.6232 Test Accuracy: 54.2373
# Epoch 37/50: Train Loss: 0.0179 Train Accuracy: 99.3524 Valid Loss: 2.0680 Valid Accuracy: 63.0670 Test Loss: 2.6818 Test Accuracy: 55.9322
# Epoch 38/50: Train Loss: 0.0193 Train Accuracy: 99.1365 Valid Loss: 2.0493 Valid Accuracy: 62.2030 Test Loss: 2.7097 Test Accuracy: 55.5085
# Epoch 39/50: Train Loss: 0.0190 Train Accuracy: 99.1905 Valid Loss: 2.0088 Valid Accuracy: 63.4989 Test Loss: 2.6272 Test Accuracy: 56.3559
# Epoch 40/50: Train Loss: 0.0194 Train Accuracy: 99.0826 Valid Loss: 2.0536 Valid Accuracy: 62.4190 Test Loss: 2.5982 Test Accuracy: 56.3559
# Epoch 41/50: Train Loss: 0.0137 Train Accuracy: 99.5143 Valid Loss: 2.1344 Valid Accuracy: 63.9309 Test Loss: 2.7551 Test Accuracy: 58.0508
# Epoch 42/50: Train Loss: 0.0174 Train Accuracy: 99.3524 Valid Loss: 2.1144 Valid Accuracy: 62.8510 Test Loss: 2.7241 Test Accuracy: 58.8983
# Epoch 43/50: Train Loss: 0.0218 Train Accuracy: 98.9207 Valid Loss: 2.2579 Valid Accuracy: 61.9870 Test Loss: 3.0071 Test Accuracy: 54.6610
# Epoch 44/50: Train Loss: 0.0381 Train Accuracy: 98.4350 Valid Loss: 2.1248 Valid Accuracy: 60.2592 Test Loss: 2.6518 Test Accuracy: 54.6610
# Epoch 45/50: Train Loss: 0.0235 Train Accuracy: 99.4603 Valid Loss: 1.9624 Valid Accuracy: 63.7149 Test Loss: 2.5296 Test Accuracy: 56.3559
# Epoch 46/50: Train Loss: 0.0157 Train Accuracy: 99.3524 Valid Loss: 2.3033 Valid Accuracy: 61.7711 Test Loss: 2.6423 Test Accuracy: 57.2034
# Epoch 47/50: Train Loss: 0.0254 Train Accuracy: 98.9207 Valid Loss: 2.0973 Valid Accuracy: 59.3952 Test Loss: 2.6713 Test Accuracy: 55.0847
# Epoch 48/50: Train Loss: 0.0231 Train Accuracy: 99.2445 Valid Loss: 2.2262 Valid Accuracy: 60.0432 Test Loss: 2.6733 Test Accuracy: 55.5085
# Epoch 49/50: Train Loss: 0.0315 Train Accuracy: 98.7588 Valid Loss: 1.9375 Valid Accuracy: 61.7711 Test Loss: 2.3456 Test Accuracy: 55.5085
# Epoch 50/50: Train Loss: 0.0172 Train Accuracy: 99.2984 Valid Loss: 2.1837 Valid Accuracy: 62.2030 Test Loss: 2.6605 Test Accuracy: 56.7797
# Finished Fold
# ==================================================
# Fold 5/5
# Epoch 1/50: Train Loss: 2.7034 Train Accuracy: 22.2882 Valid Loss: 1.7962 Valid Accuracy: 47.3002 Test Loss: 2.0752 Test Accuracy: 37.7119
# Epoch 2/50: Train Loss: 1.6810 Train Accuracy: 49.4873 Valid Loss: 1.3815 Valid Accuracy: 53.3477 Test Loss: 1.6339 Test Accuracy: 48.7288
# Epoch 3/50: Train Loss: 1.2060 Train Accuracy: 59.4172 Valid Loss: 1.2477 Valid Accuracy: 59.3952 Test Loss: 1.5108 Test Accuracy: 49.1525
# Epoch 4/50: Train Loss: 0.9094 Train Accuracy: 69.1851 Valid Loss: 1.4357 Valid Accuracy: 53.9957 Test Loss: 1.4685 Test Accuracy: 53.3898
# Epoch 5/50: Train Loss: 0.7115 Train Accuracy: 75.8230 Valid Loss: 1.2988 Valid Accuracy: 58.7473 Test Loss: 1.4630 Test Accuracy: 53.8136
# Epoch 6/50: Train Loss: 0.4793 Train Accuracy: 83.8640 Valid Loss: 1.4535 Valid Accuracy: 58.7473 Test Loss: 1.6061 Test Accuracy: 51.2712
# Epoch 7/50: Train Loss: 0.3390 Train Accuracy: 87.9115 Valid Loss: 1.4835 Valid Accuracy: 62.4190 Test Loss: 1.6527 Test Accuracy: 56.3559
# Epoch 8/50: Train Loss: 0.2986 Train Accuracy: 90.2860 Valid Loss: 1.5969 Valid Accuracy: 58.5313 Test Loss: 1.7860 Test Accuracy: 49.1525
# Epoch 9/50: Train Loss: 0.2384 Train Accuracy: 92.3368 Valid Loss: 1.6814 Valid Accuracy: 58.0994 Test Loss: 1.8228 Test Accuracy: 47.8814
# Epoch 10/50: Train Loss: 0.1984 Train Accuracy: 93.9557 Valid Loss: 1.6490 Valid Accuracy: 57.0194 Test Loss: 1.8984 Test Accuracy: 47.0339
# Epoch 11/50: Train Loss: 0.1283 Train Accuracy: 95.7366 Valid Loss: 1.6146 Valid Accuracy: 60.9071 Test Loss: 1.9519 Test Accuracy: 51.2712
# Epoch 12/50: Train Loss: 0.1197 Train Accuracy: 96.1144 Valid Loss: 1.6970 Valid Accuracy: 59.3952 Test Loss: 1.9908 Test Accuracy: 50.0000
# Epoch 13/50: Train Loss: 0.1012 Train Accuracy: 96.5461 Valid Loss: 2.0936 Valid Accuracy: 59.1793 Test Loss: 2.5349 Test Accuracy: 53.3898
# Epoch 14/50: Train Loss: 0.0916 Train Accuracy: 97.0858 Valid Loss: 1.8583 Valid Accuracy: 60.6911 Test Loss: 2.1127 Test Accuracy: 56.7797
# Epoch 15/50: Train Loss: 0.0920 Train Accuracy: 97.1937 Valid Loss: 1.6400 Valid Accuracy: 61.1231 Test Loss: 1.8726 Test Accuracy: 52.5424
# Epoch 16/50: Train Loss: 0.1048 Train Accuracy: 97.0318 Valid Loss: 1.8634 Valid Accuracy: 59.1793 Test Loss: 2.0898 Test Accuracy: 50.4237
# Epoch 17/50: Train Loss: 0.0669 Train Accuracy: 98.0032 Valid Loss: 2.0101 Valid Accuracy: 58.7473 Test Loss: 2.2046 Test Accuracy: 51.6949
# Epoch 18/50: Train Loss: 0.0770 Train Accuracy: 97.9493 Valid Loss: 1.7251 Valid Accuracy: 61.1231 Test Loss: 2.1492 Test Accuracy: 50.4237
# Epoch 19/50: Train Loss: 0.0597 Train Accuracy: 97.9493 Valid Loss: 1.7799 Valid Accuracy: 61.3391 Test Loss: 2.2557 Test Accuracy: 57.6271
# Epoch 20/50: Train Loss: 0.0385 Train Accuracy: 99.1365 Valid Loss: 1.8755 Valid Accuracy: 59.8272 Test Loss: 2.3869 Test Accuracy: 51.2712
# Epoch 21/50: Train Loss: 0.0377 Train Accuracy: 98.8667 Valid Loss: 1.8806 Valid Accuracy: 60.9071 Test Loss: 2.2951 Test Accuracy: 52.5424
# Epoch 22/50: Train Loss: 0.0433 Train Accuracy: 98.7048 Valid Loss: 1.9173 Valid Accuracy: 60.0432 Test Loss: 2.2212 Test Accuracy: 54.6610
# Epoch 23/50: Train Loss: 0.0340 Train Accuracy: 98.8667 Valid Loss: 1.8345 Valid Accuracy: 61.5551 Test Loss: 2.3689 Test Accuracy: 52.9661
# Epoch 24/50: Train Loss: 0.0349 Train Accuracy: 98.7588 Valid Loss: 1.8892 Valid Accuracy: 59.8272 Test Loss: 2.3656 Test Accuracy: 51.6949
# Epoch 25/50: Train Loss: 0.0233 Train Accuracy: 99.1905 Valid Loss: 1.8577 Valid Accuracy: 61.9870 Test Loss: 2.4601 Test Accuracy: 50.4237
# Epoch 26/50: Train Loss: 0.0225 Train Accuracy: 99.4064 Valid Loss: 1.9257 Valid Accuracy: 61.7711 Test Loss: 2.2961 Test Accuracy: 54.2373
# Epoch 27/50: Train Loss: 0.0258 Train Accuracy: 99.2445 Valid Loss: 1.9748 Valid Accuracy: 62.4190 Test Loss: 2.3832 Test Accuracy: 55.0847
# Epoch 28/50: Train Loss: 0.0217 Train Accuracy: 99.1365 Valid Loss: 1.9421 Valid Accuracy: 60.9071 Test Loss: 2.3758 Test Accuracy: 55.9322
# Epoch 29/50: Train Loss: 0.0168 Train Accuracy: 99.3524 Valid Loss: 2.0865 Valid Accuracy: 61.5551 Test Loss: 2.6790 Test Accuracy: 51.2712
# Epoch 30/50: Train Loss: 0.0337 Train Accuracy: 98.6508 Valid Loss: 1.9467 Valid Accuracy: 59.8272 Test Loss: 2.1103 Test Accuracy: 55.9322
# Epoch 31/50: Train Loss: 0.0302 Train Accuracy: 99.0286 Valid Loss: 1.9259 Valid Accuracy: 64.1469 Test Loss: 2.5115 Test Accuracy: 52.1186
# Epoch 32/50: Train Loss: 0.0258 Train Accuracy: 99.2984 Valid Loss: 1.8114 Valid Accuracy: 63.0670 Test Loss: 2.3208 Test Accuracy: 53.3898
# Epoch 33/50: Train Loss: 0.0147 Train Accuracy: 99.3524 Valid Loss: 2.1509 Valid Accuracy: 63.4989 Test Loss: 2.5824 Test Accuracy: 52.9661
# Epoch 34/50: Train Loss: 0.0238 Train Accuracy: 98.9746 Valid Loss: 2.0906 Valid Accuracy: 60.4752 Test Loss: 2.5244 Test Accuracy: 54.2373
# Epoch 35/50: Train Loss: 0.0243 Train Accuracy: 98.9746 Valid Loss: 2.1974 Valid Accuracy: 59.8272 Test Loss: 2.7018 Test Accuracy: 55.9322
# Epoch 36/50: Train Loss: 0.0297 Train Accuracy: 98.9207 Valid Loss: 1.9522 Valid Accuracy: 63.0670 Test Loss: 2.5480 Test Accuracy: 53.8136
# Epoch 37/50: Train Loss: 0.0154 Train Accuracy: 99.2445 Valid Loss: 2.0963 Valid Accuracy: 63.0670 Test Loss: 2.7192 Test Accuracy: 53.8136
# Epoch 38/50: Train Loss: 0.0222 Train Accuracy: 99.1365 Valid Loss: 2.2363 Valid Accuracy: 56.1555 Test Loss: 2.7420 Test Accuracy: 53.8136
# Epoch 39/50: Train Loss: 0.0136 Train Accuracy: 99.5143 Valid Loss: 2.2883 Valid Accuracy: 61.7711 Test Loss: 2.6233 Test Accuracy: 56.7797
# Epoch 40/50: Train Loss: 0.0178 Train Accuracy: 99.2984 Valid Loss: 2.1284 Valid Accuracy: 61.5551 Test Loss: 2.7600 Test Accuracy: 54.2373
# Epoch 41/50: Train Loss: 0.0159 Train Accuracy: 99.4064 Valid Loss: 2.0401 Valid Accuracy: 63.0670 Test Loss: 2.6454 Test Accuracy: 52.9661
# Epoch 42/50: Train Loss: 0.0197 Train Accuracy: 99.2445 Valid Loss: 2.1988 Valid Accuracy: 60.4752 Test Loss: 2.8452 Test Accuracy: 53.8136
# Epoch 43/50: Train Loss: 0.0191 Train Accuracy: 99.4064 Valid Loss: 1.9726 Valid Accuracy: 61.9870 Test Loss: 2.6800 Test Accuracy: 53.8136
# Epoch 44/50: Train Loss: 0.0553 Train Accuracy: 98.4350 Valid Loss: 2.0324 Valid Accuracy: 60.9071 Test Loss: 2.6116 Test Accuracy: 53.3898
# Epoch 45/50: Train Loss: 0.0197 Train Accuracy: 99.2984 Valid Loss: 2.1712 Valid Accuracy: 61.7711 Test Loss: 2.7701 Test Accuracy: 53.8136
# Epoch 46/50: Train Loss: 0.0187 Train Accuracy: 99.1905 Valid Loss: 2.0075 Valid Accuracy: 62.8510 Test Loss: 2.4037 Test Accuracy: 53.8136
# Epoch 47/50: Train Loss: 0.0221 Train Accuracy: 99.2984 Valid Loss: 2.2297 Valid Accuracy: 65.0108 Test Loss: 2.7650 Test Accuracy: 52.1186
# Epoch 48/50: Train Loss: 0.0156 Train Accuracy: 99.4064 Valid Loss: 2.1698 Valid Accuracy: 61.7711 Test Loss: 2.6084 Test Accuracy: 53.3898
# Epoch 49/50: Train Loss: 0.0164 Train Accuracy: 99.0286 Valid Loss: 2.0949 Valid Accuracy: 61.5551 Test Loss: 2.6286 Test Accuracy: 52.9661
# Epoch 50/50: Train Loss: 0.0162 Train Accuracy: 99.4603 Valid Loss: 2.0243 Valid Accuracy: 64.3629 Test Loss: 2.8174 Test Accuracy: 52.1186
# Finished Fold
# ==================================================

# %%
# Evaluate the trained model on the training and validation sets for each fold.
vgg16_avg_train_acc_k_folds = []
vgg16_avg_val_acc_k_folds = []

def evaluate_accuracy(history, index):
    history_cpu = [item.cpu() for item in history]
    return sum(history_cpu) / len(history_cpu)

for i in range(num_folds):
    train_accuracy = evaluate_accuracy(fold_train_accs[i], 2)
    valid_accuracy = evaluate_accuracy(fold_valid_accs[i], 3)
    print(f'Fold {i + 1}/{num_folds}:')
    print(f'\tTraining Accuracy: {train_accuracy * 100:.2f}%')
    print(f'\tValidation Accuracy: {valid_accuracy * 100:.2f}%')
    vgg16_avg_train_acc_k_folds.append(train_accuracy)
    vgg16_avg_val_acc_k_folds.append(valid_accuracy)

# Compute the average training and validation accuracy over all folds.
overall_train_acc = sum(vgg16_avg_train_acc_k_folds) / len(vgg16_avg_train_acc_k_folds)
overall_val_acc = sum(vgg16_avg_val_acc_k_folds) / len(vgg16_avg_val_acc_k_folds)

# Calculate the average and standard deviation of the training and validation accuracy over all folds.
vgg16_avg_train_acc = np.mean(vgg16_avg_train_acc_k_folds)
vgg16_std_train_acc = np.std(vgg16_avg_train_acc_k_folds)
vgg16_avg_val_acc = np.mean(vgg16_avg_val_acc_k_folds)
vgg16_std_val_acc = np.std(vgg16_avg_val_acc_k_folds)

# Print the average and standard deviation of the training and validation accuracy over all folds.
print(f'\nAverage Training Accuracy over {num_folds}-fold Cross Validation: {vgg16_avg_train_acc * 100:.2f}% +/- {vgg16_std_train_acc * 100:.2f}%')
print(f'Average Validation Accuracy over {num_folds}-fold Cross Validation: {vgg16_avg_val_acc * 100:.2f}% +/- {vgg16_std_val_acc * 100:.2f}%')
# Out:
# Fold 1/5:
# 	Training Accuracy: 93.10%
# 	Validation Accuracy: 59.71%
# Fold 2/5:
# 	Training Accuracy: 93.45%
# 	Validation Accuracy: 61.93%
# Fold 3/5:
# 	Training Accuracy: 93.56%
# 	Validation Accuracy: 61.21%
# Fold 4/5:
# 	Training Accuracy: 93.41%
# 	Validation Accuracy: 59.88%
# Fold 5/5:
# 	Training Accuracy: 93.43%
# 	Validation Accuracy: 60.41%
#
# Average Training Accuracy over 5-fold Cross Validation: 93.39% +/- 0.15%
# Average Validation Accuracy over 5-fold Cross Validation: 60.63% +/- 0.83%

# %%
# Plot the training and validation loss for each epoch
model_name = "VGG-16"
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(fold_train_losses[fold], label=f'Training Loss (Fold {fold+1})')
    plt.plot(fold_valid_losses[fold], label=f'Validation Loss (Fold {fold+1})')

plt.title(f'{model_name} Training and Validation Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Compute mean loss across all folds at each epoch
train_loss_mean = np.mean([np.array(fold_train_losses[i]) for i in range(num_folds)], axis=0)
valid_loss_mean = np.mean([np.array(fold_valid_losses[i]) for i in range(num_folds)], axis=0)

# Plot mean loss history
plt.figure(figsize=(10, 7))
plt.plot(train_loss_mean, label='Training Loss', color='pink')
plt.plot(valid_loss_mean, label='Validation Loss', color='purple')
plt.title(f'{model_name} Mean Training and Validation Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the training and validation accuracy for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(np.array([acc.cpu() for acc in fold_train_accs[fold]]) * 100, label=f'Training Accuracy (Fold {fold+1})')
    plt.plot(np.array([acc.cpu() for acc in fold_valid_accs[fold]]) * 100, label=f'Validation Accuracy (Fold {fold+1})')

plt.title(f'{model_name} Training and Validation Accuracy - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Compute mean accuracy across all folds at each epoch
train_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_train_accs[i]]) for i in range(num_folds)], axis=0)
valid_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_valid_accs[i]]) for i in range(num_folds)], axis=0)

# Plot mean accuracy history
plt.figure(figsize=(10, 7))
plt.plot(np.arange(1, num_epochs + 1), train_acc_mean * 100, label='Training Accuracy', color='pink')
plt.plot(np.arange(1, num_epochs + 1), valid_acc_mean, label='Validation Accuracy', color='purple')
plt.title(f'{model_name} Mean Training and Validation Accuracy for {num_folds}-fold Cross-validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Evaluate the trained model on the test sets for each fold.
vgg16_avg_test_acc_k_folds = []

def evaluate_accuracy(history, index):
    history_cpu = [item.cpu() for item in history]
    return sum(history_cpu) / len(history_cpu)

for i in range(num_folds):
    test_accuracy = evaluate_accuracy(fold_test_accs[i], 2)
    print(f'Fold {i + 1}/{num_folds}:')
    print(f'\tTest Accuracy: {test_accuracy * 100:.2f}%')
    vgg16_avg_test_acc_k_folds.append(test_accuracy)

# Compute the average test accuracy over all folds.
overall_test_acc = sum(vgg16_avg_test_acc_k_folds) / len(vgg16_avg_test_acc_k_folds)

# Calculate the average and standard deviation of the test accuracy over all folds.
vgg16_avg_test_acc = np.mean(vgg16_avg_test_acc_k_folds)
vgg16_std_test_acc = np.std(vgg16_avg_test_acc_k_folds)

# Print the average and standard deviation of the test accuracy over all folds.
print(f'\nAverage Test Accuracy over {num_folds}-fold Cross Validation: {vgg16_avg_test_acc * 100:.2f}% +/- {vgg16_std_test_acc * 100:.2f}%')
# Out:
# Fold 1/5:
# 	Test Accuracy: 54.59%
# Fold 2/5:
# 	Test Accuracy: 54.48%
# Fold 3/5:
# 	Test Accuracy: 55.27%
# Fold 4/5:
# 	Test Accuracy: 54.89%
# Fold 5/5:
# 	Test Accuracy: 52.56%
#
# Average Test Accuracy over 5-fold Cross Validation: 54.36% +/- 0.94%

# %%
# Plot the test loss for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(fold_test_losses[fold], label=f'Test Loss (Fold {fold+1})')

plt.title(f'{model_name} Test Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the test accuracy for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(np.array([acc.cpu() for acc in fold_test_accs[fold]]) * 100, label=f'Test Accuracy (Fold {fold+1})')

plt.title(f'{model_name} Test Accuracy - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Compute mean accuracy across all folds at each epoch
test_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_test_accs[i]]) for i in range(num_folds)], axis=0)

# Plot mean accuracy history
plt.figure(figsize=(10, 7))
plt.plot(np.arange(1, num_epochs + 1), test_acc_mean * 100, label='Test Accuracy', color='purple')
plt.title(f'{model_name} Mean Test Accuracy for {num_folds}-fold Cross-validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
print("Classes: ")
class_names = test_dataset.classes
print(test_dataset.classes)
# Out:
# Classes:
# ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Bell_pepper leaf', 'Bell_pepper leaf spot', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Potato leaf early blight', 'Potato leaf late blight', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'Tomato Early blight leaf', 'Tomato Septoria leaf spot', 'Tomato leaf', 'Tomato leaf bacterial spot', 'Tomato leaf late blight', 'Tomato leaf mosaic virus', 'Tomato leaf yellow virus', 'Tomato mold leaf', 'grape leaf', 'grape leaf black rot']

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

def predict_single_image(model, image_path, device, top_k=3):
    model.eval()

    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    image = Image.open(image_path).convert('RGB')
    image_tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image_tensor)
        probabilities = torch.nn.functional.softmax(output, dim=1)
        top_probs, top_indices = torch.topk(probabilities, top_k)

    top_probs = top_probs.cpu().numpy().flatten()
    top_indices = top_indices.cpu().numpy().flatten()

    return top_probs, top_indices

import matplotlib.cm as cm

def display_image_with_predictions(image_path, top_probs, top_indices, class_names):
    image = Image.open(image_path).convert('RGB')
    
    fig, (ax1, ax2) = plt.subplots(figsize=(8, 4), ncols=2)
    
    ax1.imshow(image)
    ax1.axis('on')
    ax1.set_title(f"Class: {class_names[top_indices[0]]}")
    
    for idx in range(len(top_indices)):
        ax1.annotate(f"{top_probs[idx]*100:.2f}%", 
                     (image.size[0] * (idx+1) / (len(top_indices)+1), image.size[1] - 20),
                     color='white',
                     fontsize=12,
                     bbox=dict(facecolor='black', edgecolor='white', boxstyle='round,pad=0.5'))
    
    y_pos = np.arange(len(top_indices))
    cmap = cm.get_cmap('viridis')
    colors = cmap(np.linspace(0, 1, len(top_indices)))
    ax2.barh(y_pos, top_probs * 100, align='center', color=colors)
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels([test_dataset.classes[idx] for idx in top_indices])
    ax2.invert_yaxis()
    ax2.set_xlabel('Score (%)')
    ax2.set_title('Top 3 Predictions')

    plt.tight_layout()
    plt.show()

image_path = "test/Apple rust leaf/Apple rust leaf (6).jpg"
top_probs, top_indices = predict_single_image(model, image_path, device, top_k=3)
display_image_with_predictions(image_path, top_probs, top_indices, test_dataset.classes)
# Out:
# <ipython-input-26-4a79520e20bc>:49: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis')

# %%
def print_predictions(top_probs, top_indices, class_names):
    print("Predictions:")
    for i in range(len(top_indices)):
        print(f"Prediction {i+1}: {test_dataset.classes[top_indices[i]]}, Score: {top_probs[i] * 100:.5f}%")

print_predictions(top_probs, top_indices, test_dataset.classes)
# Out:
# Predictions:
# Prediction 1: Apple rust leaf, Score: 98.50848%
# Prediction 2: grape leaf black rot, Score: 1.49152%
# Prediction 3: Raspberry leaf, Score: 0.00000%

# %%
image_path = "test/grape leaf black rot/grape leaf black rot (3).jpg"
top_probs, top_indices = predict_single_image(model, image_path, device, top_k=3)
display_image_with_predictions(image_path, top_probs, top_indices, test_dataset.classes)
# Out:
# <ipython-input-26-4a79520e20bc>:49: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis')

# %%
def print_predictions(top_probs, top_indices, class_names):
    print("Predictions:")
    for i in range(len(top_indices)):
        print(f"Prediction {i+1}: {test_dataset.classes[top_indices[i]]}, Score: {top_probs[i] * 100:.5f}%")

print_predictions(top_probs, top_indices, test_dataset.classes)
# Out:
# Predictions:
# Prediction 1: grape leaf black rot, Score: 99.99994%
# Prediction 2: Apple rust leaf, Score: 0.00005%
# Prediction 3: Tomato Septoria leaf spot, Score: 0.00000%
