# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import os
import torch
import torchvision.transforms as transforms
import glob
import torchvision
import time
import random
from PIL import Image
from torch.utils.data import DataLoader, Dataset

# %%
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split

ROOT_DIR_TRAIN = "train"
ROOT_DIR_TEST = "test"

# Common transforms
common_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Prepare the Dataset
dataset = datasets.ImageFolder(root=ROOT_DIR_TRAIN, transform=common_transform)

train_size = int(0.80 * len(dataset))
valid_size = len(dataset) - train_size

# Use random_split to create train and validation datasets
train_dataset, valid_dataset = random_split(dataset, [train_size, valid_size])
test_dataset = datasets.ImageFolder(root=ROOT_DIR_TEST, transform=common_transform)

# Prepare the Data Loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=4)

# %%
num_images = len(dataset)
num_classes = len(dataset.classes)
print(f"Number of Images: {num_images}")
print(f"Number of Classes: {num_classes}")
# Out:
# Number of Images: 2316
# Number of Classes: 27

# %%
num_images = len(test_dataset)
num_classes = len(test_dataset.classes)
print(f"Number of Images: {num_images}")
print(f"Number of Classes: {num_classes}")
# Out:
# Number of Images: 236
# Number of Classes: 27

# %%
print(f"Number of training images: {len(train_dataset)}")
print(f"Number of validation images: {len(valid_dataset)}")
print(f"Number of test images: {len(test_dataset)}")
# Out:
# Number of training images: 1852
# Number of validation images: 464
# Number of test images: 236

# %%
from torchvision import models
dir(models)
# Out:
# ['AlexNet',
#  'DenseNet',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'Inception3',
#  'InceptionOutputs',
#  'MNASNet',
#  'MobileNetV2',
#  'MobileNetV3',
#  'ResNet',
#  'ShuffleNetV2',
#  'SqueezeNet',
#  'VGG',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_utils',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'quantization',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'utils',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'video',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in c:\users\navapoom punsathit\anaconda3\lib\site-packages (1.5.1)

# %%
import torch.nn as nn
from torchsummary import summary
from torchvision import models

# Load a pre-trained MobileNet model
mobilenet = models.mobilenet_v2(pretrained=True)

# Set the number of classes to match your dataset
num_classes = 27

# Modify the fully connected layer to match the number of classes
mobilenet.classifier[1] = nn.Linear(mobilenet.last_channel, num_classes)

# Set the device (CPU or GPU)
mobilenet.to(device)

# Display the model summary
summary(mobilenet, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#              ReLU6-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#              ReLU6-6         [-1, 32, 112, 112]               0
#             Conv2d-7         [-1, 16, 112, 112]             512
#        BatchNorm2d-8         [-1, 16, 112, 112]              32
#   InvertedResidual-9         [-1, 16, 112, 112]               0
#            Conv2d-10         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-11         [-1, 96, 112, 112]             192
#             ReLU6-12         [-1, 96, 112, 112]               0
#            Conv2d-13           [-1, 96, 56, 56]             864
#       BatchNorm2d-14           [-1, 96, 56, 56]             192
#             ReLU6-15           [-1, 96, 56, 56]               0
#            Conv2d-16           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-17           [-1, 24, 56, 56]              48
#  InvertedResidual-18           [-1, 24, 56, 56]               0
#            Conv2d-19          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-20          [-1, 144, 56, 56]             288
#             ReLU6-21          [-1, 144, 56, 56]               0
#            Conv2d-22          [-1, 144, 56, 56]           1,296
#       BatchNorm2d-23          [-1, 144, 56, 56]             288
#             ReLU6-24          [-1, 144, 56, 56]               0
#            Conv2d-25           [-1, 24, 56, 56]           3,456
#       BatchNorm2d-26           [-1, 24, 56, 56]              48
#  InvertedResidual-27           [-1, 24, 56, 56]               0
#            Conv2d-28          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-29          [-1, 144, 56, 56]             288
#             ReLU6-30          [-1, 144, 56, 56]               0
#            Conv2d-31          [-1, 144, 28, 28]           1,296
#       BatchNorm2d-32          [-1, 144, 28, 28]             288
#             ReLU6-33          [-1, 144, 28, 28]               0
#            Conv2d-34           [-1, 32, 28, 28]           4,608
#       BatchNorm2d-35           [-1, 32, 28, 28]              64
#  InvertedResidual-36           [-1, 32, 28, 28]               0
#            Conv2d-37          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-38          [-1, 192, 28, 28]             384
#             ReLU6-39          [-1, 192, 28, 28]               0
#            Conv2d-40          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-41          [-1, 192, 28, 28]             384
#             ReLU6-42          [-1, 192, 28, 28]               0
#            Conv2d-43           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-44           [-1, 32, 28, 28]              64
#  InvertedResidual-45           [-1, 32, 28, 28]               0
#            Conv2d-46          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-47          [-1, 192, 28, 28]             384
#             ReLU6-48          [-1, 192, 28, 28]               0
#            Conv2d-49          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-50          [-1, 192, 28, 28]             384
#             ReLU6-51          [-1, 192, 28, 28]               0
#            Conv2d-52           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-53           [-1, 32, 28, 28]              64
#  InvertedResidual-54           [-1, 32, 28, 28]               0
#            Conv2d-55          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-56          [-1, 192, 28, 28]             384
#             ReLU6-57          [-1, 192, 28, 28]               0
#            Conv2d-58          [-1, 192, 14, 14]           1,728
#       BatchNorm2d-59          [-1, 192, 14, 14]             384
#             ReLU6-60          [-1, 192, 14, 14]               0
#            Conv2d-61           [-1, 64, 14, 14]          12,288
#       BatchNorm2d-62           [-1, 64, 14, 14]             128
#  InvertedResidual-63           [-1, 64, 14, 14]               0
#            Conv2d-64          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-65          [-1, 384, 14, 14]             768
#             ReLU6-66          [-1, 384, 14, 14]               0
#            Conv2d-67          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-68          [-1, 384, 14, 14]             768
#             ReLU6-69          [-1, 384, 14, 14]               0
#            Conv2d-70           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-71           [-1, 64, 14, 14]             128
#  InvertedResidual-72           [-1, 64, 14, 14]               0
#            Conv2d-73          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-74          [-1, 384, 14, 14]             768
#             ReLU6-75          [-1, 384, 14, 14]               0
#            Conv2d-76          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-77          [-1, 384, 14, 14]             768
#             ReLU6-78          [-1, 384, 14, 14]               0
#            Conv2d-79           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-80           [-1, 64, 14, 14]             128
#  InvertedResidual-81           [-1, 64, 14, 14]               0
#            Conv2d-82          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-83          [-1, 384, 14, 14]             768
#             ReLU6-84          [-1, 384, 14, 14]               0
#            Conv2d-85          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-86          [-1, 384, 14, 14]             768
#             ReLU6-87          [-1, 384, 14, 14]               0
#            Conv2d-88           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-89           [-1, 64, 14, 14]             128
#  InvertedResidual-90           [-1, 64, 14, 14]               0
#            Conv2d-91          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-92          [-1, 384, 14, 14]             768
#             ReLU6-93          [-1, 384, 14, 14]               0
#            Conv2d-94          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-95          [-1, 384, 14, 14]             768
#             ReLU6-96          [-1, 384, 14, 14]               0
#            Conv2d-97           [-1, 96, 14, 14]          36,864
#       BatchNorm2d-98           [-1, 96, 14, 14]             192
#  InvertedResidual-99           [-1, 96, 14, 14]               0
#           Conv2d-100          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-101          [-1, 576, 14, 14]           1,152
#            ReLU6-102          [-1, 576, 14, 14]               0
#           Conv2d-103          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-104          [-1, 576, 14, 14]           1,152
#            ReLU6-105          [-1, 576, 14, 14]               0
#           Conv2d-106           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-107           [-1, 96, 14, 14]             192
# InvertedResidual-108           [-1, 96, 14, 14]               0
#           Conv2d-109          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-110          [-1, 576, 14, 14]           1,152
#            ReLU6-111          [-1, 576, 14, 14]               0
#           Conv2d-112          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-113          [-1, 576, 14, 14]           1,152
#            ReLU6-114          [-1, 576, 14, 14]               0
#           Conv2d-115           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-116           [-1, 96, 14, 14]             192
# InvertedResidual-117           [-1, 96, 14, 14]               0
#           Conv2d-118          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-119          [-1, 576, 14, 14]           1,152
#            ReLU6-120          [-1, 576, 14, 14]               0
#           Conv2d-121            [-1, 576, 7, 7]           5,184
#      BatchNorm2d-122            [-1, 576, 7, 7]           1,152
#            ReLU6-123            [-1, 576, 7, 7]               0
#           Conv2d-124            [-1, 160, 7, 7]          92,160
#      BatchNorm2d-125            [-1, 160, 7, 7]             320
# InvertedResidual-126            [-1, 160, 7, 7]               0
#           Conv2d-127            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-128            [-1, 960, 7, 7]           1,920
#            ReLU6-129            [-1, 960, 7, 7]               0
#           Conv2d-130            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-131            [-1, 960, 7, 7]           1,920
#            ReLU6-132            [-1, 960, 7, 7]               0
#           Conv2d-133            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-134            [-1, 160, 7, 7]             320
# InvertedResidual-135            [-1, 160, 7, 7]               0
#           Conv2d-136            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-137            [-1, 960, 7, 7]           1,920
#            ReLU6-138            [-1, 960, 7, 7]               0
#           Conv2d-139            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-140            [-1, 960, 7, 7]           1,920
#            ReLU6-141            [-1, 960, 7, 7]               0
#           Conv2d-142            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-143            [-1, 160, 7, 7]             320
# InvertedResidual-144            [-1, 160, 7, 7]               0
#           Conv2d-145            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-146            [-1, 960, 7, 7]           1,920
#            ReLU6-147            [-1, 960, 7, 7]               0
#           Conv2d-148            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-149            [-1, 960, 7, 7]           1,920
#            ReLU6-150            [-1, 960, 7, 7]               0
#           Conv2d-151            [-1, 320, 7, 7]         307,200
#      BatchNorm2d-152            [-1, 320, 7, 7]             640
# InvertedResidual-153            [-1, 320, 7, 7]               0
#           Conv2d-154           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-155           [-1, 1280, 7, 7]           2,560
#            ReLU6-156           [-1, 1280, 7, 7]               0
#          Dropout-157                 [-1, 1280]               0
#           Linear-158                   [-1, 27]          34,587
# ================================================================
# Total params: 2,258,459
# Trainable params: 2,258,459
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 152.86
# Params size (MB): 8.62
# Estimated Total Size (MB): 162.05
# ----------------------------------------------------------------

# %%
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader, Subset
import numpy as np

def train_model(model, criterion, optimizer, dataloader, device):
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

def validate_model(model, criterion, dataloader, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(dataloader.dataset)
        epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

# %%
def test_model(model, criterion, test_loader, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(test_loader.dataset)
        epoch_acc = running_corrects.double() / len(test_loader.dataset)

    return epoch_loss, epoch_acc

# %%
torch.backends.cudnn.benchmark = True

# %%
# Set the number of folds
num_folds = 5

# Prepare the data
X = np.arange(len(dataset))
y = np.array([label for _, label in dataset.imgs])

# Set up the StratifiedKFold
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Set device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize lists to store fold results
fold_train_losses = []
fold_valid_losses = []
fold_test_losses = []
fold_train_accs = []
fold_valid_accs = []
fold_test_accs = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, y)):
    print(f"Fold {fold + 1}/{num_folds}")

    # Create data loaders for the current fold
    train_data = Subset(dataset, train_index)
    valid_data = Subset(dataset, valid_index)
    train_loader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=4)
    valid_loader = DataLoader(valid_data, batch_size=32, shuffle=False, num_workers=4)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

    # Load and prepare the model
    model = models.mobilenet_v2(pretrained=True)
    model.classifier[1] = nn.Linear(model.last_channel, num_classes)
    model.to(device)

    # Set the criterion and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    # Train and validate the model
    num_epochs = 50
    epoch_train_losses = []
    epoch_valid_losses = []
    epoch_test_losses = []
    epoch_train_accs = []
    epoch_valid_accs = []
    epoch_test_accs = []
    for epoch in range(num_epochs):
        train_loss, train_acc = train_model(model, criterion, optimizer, train_loader, device)
        valid_loss, valid_acc = validate_model(model, criterion, valid_loader, device)
        test_loss, test_acc = test_model(model, criterion, test_loader, device)

        epoch_train_losses.append(train_loss)
        epoch_valid_losses.append(valid_loss)
        epoch_test_losses.append(test_loss)
        epoch_train_accs.append(train_acc)
        epoch_valid_accs.append(valid_acc)
        epoch_test_accs.append(test_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}: "
              f"Train Loss: {train_loss:.4f} Train Accuracy: {train_acc * 100:.4f} "
              f"Valid Loss: {valid_loss:.4f} Valid Accuracy: {valid_acc * 100:.4f} "
              f"Test Loss: {test_loss:.4f} Test Accuracy: {test_acc * 100:.4f}")

    fold_train_losses.append(epoch_train_losses)
    fold_valid_losses.append(epoch_valid_losses)
    fold_test_losses.append(epoch_test_losses)
    fold_train_accs.append(epoch_train_accs)
    fold_valid_accs.append(epoch_valid_accs)
    fold_test_accs.append(epoch_test_accs)

    print("Finished Fold")
    print("=" * 50)
# Out:
# Fold 1/5
# Epoch 1/50: Train Loss: 2.8548 Train Accuracy: 20.5184 Valid Loss: 2.2458 Valid Accuracy: 40.5172 Test Loss: 2.4233 Test Accuracy: 33.4746
# Epoch 2/50: Train Loss: 1.8811 Train Accuracy: 48.1641 Valid Loss: 1.6444 Valid Accuracy: 53.0172 Test Loss: 1.8184 Test Accuracy: 45.3390
# Epoch 3/50: Train Loss: 1.3603 Train Accuracy: 61.9330 Valid Loss: 1.3617 Valid Accuracy: 60.1293 Test Loss: 1.5378 Test Accuracy: 50.8475
# Epoch 4/50: Train Loss: 1.0470 Train Accuracy: 70.7343 Valid Loss: 1.2222 Valid Accuracy: 61.8534 Test Loss: 1.3527 Test Accuracy: 53.3898
# Epoch 5/50: Train Loss: 0.8116 Train Accuracy: 78.5097 Valid Loss: 1.1544 Valid Accuracy: 63.5776 Test Loss: 1.2879 Test Accuracy: 54.2373
# Epoch 6/50: Train Loss: 0.6444 Train Accuracy: 84.2873 Valid Loss: 1.1074 Valid Accuracy: 63.7931 Test Loss: 1.2478 Test Accuracy: 53.8136
# Epoch 7/50: Train Loss: 0.5169 Train Accuracy: 88.3369 Valid Loss: 1.0824 Valid Accuracy: 63.7931 Test Loss: 1.2230 Test Accuracy: 54.2373
# Epoch 8/50: Train Loss: 0.3949 Train Accuracy: 91.9006 Valid Loss: 1.0855 Valid Accuracy: 63.7931 Test Loss: 1.2303 Test Accuracy: 55.0847
# Epoch 9/50: Train Loss: 0.3086 Train Accuracy: 94.3305 Valid Loss: 1.0940 Valid Accuracy: 62.5000 Test Loss: 1.2079 Test Accuracy: 57.6271
# Epoch 10/50: Train Loss: 0.2460 Train Accuracy: 96.0583 Valid Loss: 1.1029 Valid Accuracy: 63.7931 Test Loss: 1.2120 Test Accuracy: 56.7797
# Epoch 11/50: Train Loss: 0.1763 Train Accuracy: 98.0562 Valid Loss: 1.0798 Valid Accuracy: 64.4397 Test Loss: 1.2789 Test Accuracy: 54.2373
# Epoch 12/50: Train Loss: 0.1441 Train Accuracy: 98.5421 Valid Loss: 1.1209 Valid Accuracy: 64.4397 Test Loss: 1.2818 Test Accuracy: 54.6610
# Epoch 13/50: Train Loss: 0.1201 Train Accuracy: 98.6501 Valid Loss: 1.1183 Valid Accuracy: 65.0862 Test Loss: 1.2703 Test Accuracy: 56.7797
# Epoch 14/50: Train Loss: 0.0950 Train Accuracy: 99.1361 Valid Loss: 1.1311 Valid Accuracy: 64.0086 Test Loss: 1.2744 Test Accuracy: 57.6271
# Epoch 15/50: Train Loss: 0.0905 Train Accuracy: 98.6501 Valid Loss: 1.1528 Valid Accuracy: 64.4397 Test Loss: 1.3173 Test Accuracy: 57.2034
# Epoch 16/50: Train Loss: 0.0742 Train Accuracy: 99.0281 Valid Loss: 1.1534 Valid Accuracy: 64.2241 Test Loss: 1.3148 Test Accuracy: 57.2034
# Epoch 17/50: Train Loss: 0.0774 Train Accuracy: 98.7581 Valid Loss: 1.1965 Valid Accuracy: 63.7931 Test Loss: 1.3615 Test Accuracy: 55.9322
# Epoch 18/50: Train Loss: 0.0718 Train Accuracy: 98.9201 Valid Loss: 1.1733 Valid Accuracy: 64.0086 Test Loss: 1.3877 Test Accuracy: 56.3559
# Epoch 19/50: Train Loss: 0.0601 Train Accuracy: 99.0821 Valid Loss: 1.1855 Valid Accuracy: 62.7155 Test Loss: 1.3581 Test Accuracy: 54.2373
# Epoch 20/50: Train Loss: 0.0528 Train Accuracy: 99.1361 Valid Loss: 1.1836 Valid Accuracy: 64.2241 Test Loss: 1.3815 Test Accuracy: 55.5085
# Epoch 21/50: Train Loss: 0.0560 Train Accuracy: 98.9201 Valid Loss: 1.1936 Valid Accuracy: 65.0862 Test Loss: 1.3736 Test Accuracy: 56.7797
# Epoch 22/50: Train Loss: 0.0492 Train Accuracy: 99.1901 Valid Loss: 1.1980 Valid Accuracy: 64.4397 Test Loss: 1.4209 Test Accuracy: 56.7797
# Epoch 23/50: Train Loss: 0.0509 Train Accuracy: 98.8661 Valid Loss: 1.1921 Valid Accuracy: 64.2241 Test Loss: 1.4535 Test Accuracy: 55.9322
# Epoch 24/50: Train Loss: 0.0435 Train Accuracy: 98.9201 Valid Loss: 1.1982 Valid Accuracy: 64.8707 Test Loss: 1.4473 Test Accuracy: 56.7797
# Epoch 25/50: Train Loss: 0.0415 Train Accuracy: 98.9741 Valid Loss: 1.1899 Valid Accuracy: 65.0862 Test Loss: 1.4243 Test Accuracy: 57.6271
# Epoch 26/50: Train Loss: 0.0368 Train Accuracy: 99.1361 Valid Loss: 1.2035 Valid Accuracy: 64.0086 Test Loss: 1.4570 Test Accuracy: 56.7797
# Epoch 27/50: Train Loss: 0.0371 Train Accuracy: 99.1901 Valid Loss: 1.2114 Valid Accuracy: 63.3621 Test Loss: 1.4270 Test Accuracy: 57.6271
# Epoch 28/50: Train Loss: 0.0373 Train Accuracy: 99.1901 Valid Loss: 1.2157 Valid Accuracy: 64.6552 Test Loss: 1.4468 Test Accuracy: 57.2034
# Epoch 29/50: Train Loss: 0.0368 Train Accuracy: 99.1901 Valid Loss: 1.2466 Valid Accuracy: 64.2241 Test Loss: 1.4653 Test Accuracy: 55.9322
# Epoch 30/50: Train Loss: 0.0333 Train Accuracy: 99.1901 Valid Loss: 1.2275 Valid Accuracy: 64.8707 Test Loss: 1.4595 Test Accuracy: 57.2034
# Epoch 31/50: Train Loss: 0.0333 Train Accuracy: 99.1901 Valid Loss: 1.2374 Valid Accuracy: 64.2241 Test Loss: 1.4625 Test Accuracy: 56.3559
# Epoch 32/50: Train Loss: 0.0261 Train Accuracy: 99.3521 Valid Loss: 1.2403 Valid Accuracy: 65.9483 Test Loss: 1.4749 Test Accuracy: 55.9322
# Epoch 33/50: Train Loss: 0.0278 Train Accuracy: 99.0281 Valid Loss: 1.2582 Valid Accuracy: 64.6552 Test Loss: 1.4717 Test Accuracy: 57.2034
# Epoch 34/50: Train Loss: 0.0292 Train Accuracy: 99.2441 Valid Loss: 1.2620 Valid Accuracy: 64.6552 Test Loss: 1.4998 Test Accuracy: 56.3559
# Epoch 35/50: Train Loss: 0.0307 Train Accuracy: 99.1901 Valid Loss: 1.2774 Valid Accuracy: 63.5776 Test Loss: 1.4697 Test Accuracy: 55.5085
# Epoch 36/50: Train Loss: 0.0291 Train Accuracy: 99.2441 Valid Loss: 1.2916 Valid Accuracy: 63.5776 Test Loss: 1.4915 Test Accuracy: 55.5085
# Epoch 37/50: Train Loss: 0.0253 Train Accuracy: 99.1901 Valid Loss: 1.3053 Valid Accuracy: 63.1466 Test Loss: 1.5123 Test Accuracy: 56.7797
# Epoch 38/50: Train Loss: 0.0236 Train Accuracy: 99.4060 Valid Loss: 1.2838 Valid Accuracy: 64.8707 Test Loss: 1.5298 Test Accuracy: 55.5085
# Epoch 39/50: Train Loss: 0.0281 Train Accuracy: 99.1901 Valid Loss: 1.2935 Valid Accuracy: 64.0086 Test Loss: 1.5175 Test Accuracy: 55.0847
# Epoch 40/50: Train Loss: 0.0265 Train Accuracy: 99.1361 Valid Loss: 1.2878 Valid Accuracy: 63.7931 Test Loss: 1.5468 Test Accuracy: 54.6610
# Epoch 41/50: Train Loss: 0.0279 Train Accuracy: 99.1901 Valid Loss: 1.3014 Valid Accuracy: 63.7931 Test Loss: 1.5478 Test Accuracy: 54.2373
# Epoch 42/50: Train Loss: 0.0209 Train Accuracy: 99.4060 Valid Loss: 1.3072 Valid Accuracy: 64.6552 Test Loss: 1.5621 Test Accuracy: 55.5085
# Epoch 43/50: Train Loss: 0.0196 Train Accuracy: 99.4060 Valid Loss: 1.3046 Valid Accuracy: 65.3017 Test Loss: 1.5598 Test Accuracy: 55.0847
# Epoch 44/50: Train Loss: 0.0173 Train Accuracy: 99.5140 Valid Loss: 1.3135 Valid Accuracy: 64.6552 Test Loss: 1.5586 Test Accuracy: 55.0847
# Epoch 45/50: Train Loss: 0.0216 Train Accuracy: 99.2981 Valid Loss: 1.3061 Valid Accuracy: 64.8707 Test Loss: 1.5591 Test Accuracy: 56.7797
# Epoch 46/50: Train Loss: 0.0189 Train Accuracy: 99.4600 Valid Loss: 1.3142 Valid Accuracy: 64.0086 Test Loss: 1.5870 Test Accuracy: 55.5085
# Epoch 47/50: Train Loss: 0.0196 Train Accuracy: 99.4060 Valid Loss: 1.3015 Valid Accuracy: 64.2241 Test Loss: 1.5972 Test Accuracy: 54.6610
# Epoch 48/50: Train Loss: 0.0220 Train Accuracy: 99.4060 Valid Loss: 1.2951 Valid Accuracy: 64.8707 Test Loss: 1.5731 Test Accuracy: 55.0847
# Epoch 49/50: Train Loss: 0.0223 Train Accuracy: 99.1901 Valid Loss: 1.2968 Valid Accuracy: 65.0862 Test Loss: 1.6045 Test Accuracy: 55.0847
# Epoch 50/50: Train Loss: 0.0177 Train Accuracy: 99.2441 Valid Loss: 1.3192 Valid Accuracy: 65.0862 Test Loss: 1.6051 Test Accuracy: 53.8136
# Finished Fold
# ==================================================
# Fold 2/5
# Epoch 1/50: Train Loss: 2.8842 Train Accuracy: 19.7518 Valid Loss: 2.2124 Valid Accuracy: 35.6371 Test Loss: 2.3949 Test Accuracy: 30.5085
# Epoch 2/50: Train Loss: 1.8776 Train Accuracy: 49.5953 Valid Loss: 1.6142 Valid Accuracy: 51.8359 Test Loss: 1.8140 Test Accuracy: 44.9153
# Epoch 3/50: Train Loss: 1.3551 Train Accuracy: 63.0329 Valid Loss: 1.3371 Valid Accuracy: 58.7473 Test Loss: 1.4896 Test Accuracy: 50.8475
# Epoch 4/50: Train Loss: 1.0474 Train Accuracy: 72.0993 Valid Loss: 1.2073 Valid Accuracy: 64.5788 Test Loss: 1.3580 Test Accuracy: 55.5085
# Epoch 5/50: Train Loss: 0.8237 Train Accuracy: 78.3594 Valid Loss: 1.1376 Valid Accuracy: 61.5551 Test Loss: 1.2931 Test Accuracy: 54.2373
# Epoch 6/50: Train Loss: 0.6299 Train Accuracy: 85.2671 Valid Loss: 1.0835 Valid Accuracy: 64.5788 Test Loss: 1.2087 Test Accuracy: 56.7797
# Epoch 7/50: Train Loss: 0.4820 Train Accuracy: 90.1781 Valid Loss: 1.0872 Valid Accuracy: 63.7149 Test Loss: 1.2105 Test Accuracy: 55.0847
# Epoch 8/50: Train Loss: 0.3836 Train Accuracy: 92.3907 Valid Loss: 1.0804 Valid Accuracy: 63.0670 Test Loss: 1.1982 Test Accuracy: 55.5085
# Epoch 9/50: Train Loss: 0.3049 Train Accuracy: 94.2795 Valid Loss: 1.1237 Valid Accuracy: 64.1469 Test Loss: 1.2516 Test Accuracy: 55.5085
# Epoch 10/50: Train Loss: 0.2378 Train Accuracy: 96.9239 Valid Loss: 1.1015 Valid Accuracy: 63.4989 Test Loss: 1.2481 Test Accuracy: 53.8136
# Epoch 11/50: Train Loss: 0.1864 Train Accuracy: 97.3017 Valid Loss: 1.1282 Valid Accuracy: 63.2829 Test Loss: 1.2813 Test Accuracy: 54.6610
# Epoch 12/50: Train Loss: 0.1410 Train Accuracy: 98.8127 Valid Loss: 1.1437 Valid Accuracy: 64.1469 Test Loss: 1.3096 Test Accuracy: 55.5085
# Epoch 13/50: Train Loss: 0.1301 Train Accuracy: 98.5969 Valid Loss: 1.2058 Valid Accuracy: 63.2829 Test Loss: 1.3140 Test Accuracy: 57.6271
# Epoch 14/50: Train Loss: 0.1072 Train Accuracy: 98.9746 Valid Loss: 1.1949 Valid Accuracy: 63.7149 Test Loss: 1.3221 Test Accuracy: 56.3559
# Epoch 15/50: Train Loss: 0.0908 Train Accuracy: 99.1905 Valid Loss: 1.1877 Valid Accuracy: 63.2829 Test Loss: 1.3403 Test Accuracy: 55.0847
# Epoch 16/50: Train Loss: 0.0743 Train Accuracy: 99.1365 Valid Loss: 1.2074 Valid Accuracy: 65.6587 Test Loss: 1.3612 Test Accuracy: 57.6271
# Epoch 17/50: Train Loss: 0.0606 Train Accuracy: 99.4064 Valid Loss: 1.2099 Valid Accuracy: 63.4989 Test Loss: 1.3740 Test Accuracy: 54.6610
# Epoch 18/50: Train Loss: 0.0561 Train Accuracy: 99.5143 Valid Loss: 1.2458 Valid Accuracy: 63.2829 Test Loss: 1.3857 Test Accuracy: 54.6610
# Epoch 19/50: Train Loss: 0.0517 Train Accuracy: 99.4064 Valid Loss: 1.2501 Valid Accuracy: 64.1469 Test Loss: 1.4234 Test Accuracy: 54.2373
# Epoch 20/50: Train Loss: 0.0505 Train Accuracy: 99.3524 Valid Loss: 1.2593 Valid Accuracy: 62.8510 Test Loss: 1.3832 Test Accuracy: 55.9322
# Epoch 21/50: Train Loss: 0.0434 Train Accuracy: 99.4064 Valid Loss: 1.2471 Valid Accuracy: 63.7149 Test Loss: 1.3934 Test Accuracy: 55.9322
# Epoch 22/50: Train Loss: 0.0395 Train Accuracy: 99.5683 Valid Loss: 1.2730 Valid Accuracy: 64.7948 Test Loss: 1.3976 Test Accuracy: 56.3559
# Epoch 23/50: Train Loss: 0.0401 Train Accuracy: 99.4064 Valid Loss: 1.2614 Valid Accuracy: 65.0108 Test Loss: 1.4368 Test Accuracy: 54.6610
# Epoch 24/50: Train Loss: 0.0312 Train Accuracy: 99.5683 Valid Loss: 1.2618 Valid Accuracy: 64.5788 Test Loss: 1.4514 Test Accuracy: 55.0847
# Epoch 25/50: Train Loss: 0.0321 Train Accuracy: 99.5683 Valid Loss: 1.2644 Valid Accuracy: 66.5227 Test Loss: 1.4608 Test Accuracy: 58.4746
# Epoch 26/50: Train Loss: 0.0314 Train Accuracy: 99.4603 Valid Loss: 1.2806 Valid Accuracy: 64.3629 Test Loss: 1.4475 Test Accuracy: 58.0508
# Epoch 27/50: Train Loss: 0.0292 Train Accuracy: 99.6762 Valid Loss: 1.2695 Valid Accuracy: 64.3629 Test Loss: 1.4800 Test Accuracy: 54.6610
# Epoch 28/50: Train Loss: 0.0257 Train Accuracy: 99.5683 Valid Loss: 1.2905 Valid Accuracy: 63.2829 Test Loss: 1.4734 Test Accuracy: 55.9322
# Epoch 29/50: Train Loss: 0.0257 Train Accuracy: 99.4603 Valid Loss: 1.3239 Valid Accuracy: 63.7149 Test Loss: 1.4920 Test Accuracy: 56.3559
# Epoch 30/50: Train Loss: 0.0270 Train Accuracy: 99.4603 Valid Loss: 1.3094 Valid Accuracy: 63.4989 Test Loss: 1.5177 Test Accuracy: 55.5085
# Epoch 31/50: Train Loss: 0.0269 Train Accuracy: 99.5683 Valid Loss: 1.2916 Valid Accuracy: 64.7948 Test Loss: 1.5105 Test Accuracy: 55.9322
# Epoch 32/50: Train Loss: 0.0243 Train Accuracy: 99.4603 Valid Loss: 1.3419 Valid Accuracy: 63.7149 Test Loss: 1.4863 Test Accuracy: 56.7797
# Epoch 33/50: Train Loss: 0.0199 Train Accuracy: 99.6222 Valid Loss: 1.3223 Valid Accuracy: 63.2829 Test Loss: 1.5252 Test Accuracy: 55.9322
# Epoch 34/50: Train Loss: 0.0216 Train Accuracy: 99.6762 Valid Loss: 1.3197 Valid Accuracy: 63.4989 Test Loss: 1.5285 Test Accuracy: 55.0847
# Epoch 35/50: Train Loss: 0.0175 Train Accuracy: 99.7302 Valid Loss: 1.3447 Valid Accuracy: 63.9309 Test Loss: 1.5255 Test Accuracy: 57.6271
# Epoch 36/50: Train Loss: 0.0176 Train Accuracy: 99.6222 Valid Loss: 1.3220 Valid Accuracy: 63.9309 Test Loss: 1.5226 Test Accuracy: 56.7797
# Epoch 37/50: Train Loss: 0.0154 Train Accuracy: 99.6762 Valid Loss: 1.3552 Valid Accuracy: 64.5788 Test Loss: 1.5414 Test Accuracy: 56.3559
# Epoch 38/50: Train Loss: 0.0187 Train Accuracy: 99.6222 Valid Loss: 1.3200 Valid Accuracy: 65.2268 Test Loss: 1.5555 Test Accuracy: 56.3559
# Epoch 39/50: Train Loss: 0.0195 Train Accuracy: 99.7302 Valid Loss: 1.3660 Valid Accuracy: 64.7948 Test Loss: 1.5333 Test Accuracy: 56.3559
# Epoch 40/50: Train Loss: 0.0161 Train Accuracy: 99.7302 Valid Loss: 1.3359 Valid Accuracy: 64.7948 Test Loss: 1.5785 Test Accuracy: 54.6610
# Epoch 41/50: Train Loss: 0.0211 Train Accuracy: 99.5143 Valid Loss: 1.3275 Valid Accuracy: 64.3629 Test Loss: 1.5658 Test Accuracy: 56.3559
# Epoch 42/50: Train Loss: 0.0221 Train Accuracy: 99.3524 Valid Loss: 1.3546 Valid Accuracy: 64.1469 Test Loss: 1.5294 Test Accuracy: 55.5085
# Epoch 43/50: Train Loss: 0.0152 Train Accuracy: 99.6762 Valid Loss: 1.3777 Valid Accuracy: 64.3629 Test Loss: 1.5663 Test Accuracy: 55.5085
# Epoch 44/50: Train Loss: 0.0136 Train Accuracy: 99.6762 Valid Loss: 1.3674 Valid Accuracy: 63.9309 Test Loss: 1.5525 Test Accuracy: 57.2034
# Epoch 45/50: Train Loss: 0.0144 Train Accuracy: 99.6762 Valid Loss: 1.3414 Valid Accuracy: 65.0108 Test Loss: 1.5917 Test Accuracy: 57.6271
# Epoch 46/50: Train Loss: 0.0190 Train Accuracy: 99.7302 Valid Loss: 1.3842 Valid Accuracy: 63.2829 Test Loss: 1.5971 Test Accuracy: 57.2034
# Epoch 47/50: Train Loss: 0.0138 Train Accuracy: 99.7302 Valid Loss: 1.3768 Valid Accuracy: 64.1469 Test Loss: 1.5769 Test Accuracy: 56.3559
# Epoch 48/50: Train Loss: 0.0150 Train Accuracy: 99.6762 Valid Loss: 1.3800 Valid Accuracy: 64.5788 Test Loss: 1.5997 Test Accuracy: 56.3559
# Epoch 49/50: Train Loss: 0.0146 Train Accuracy: 99.7841 Valid Loss: 1.3961 Valid Accuracy: 64.3629 Test Loss: 1.6066 Test Accuracy: 58.0508
# Epoch 50/50: Train Loss: 0.0109 Train Accuracy: 99.7841 Valid Loss: 1.4089 Valid Accuracy: 63.7149 Test Loss: 1.6173 Test Accuracy: 55.9322
# Finished Fold
# ==================================================
# Fold 3/5
# Epoch 1/50: Train Loss: 2.8398 Train Accuracy: 21.1009 Valid Loss: 2.2401 Valid Accuracy: 38.8769 Test Loss: 2.4441 Test Accuracy: 30.0847
# Epoch 2/50: Train Loss: 1.8728 Train Accuracy: 49.4873 Valid Loss: 1.6784 Valid Accuracy: 51.1879 Test Loss: 1.8160 Test Accuracy: 45.7627
# Epoch 3/50: Train Loss: 1.3647 Train Accuracy: 61.7377 Valid Loss: 1.4086 Valid Accuracy: 58.5313 Test Loss: 1.5123 Test Accuracy: 50.0000
# Epoch 4/50: Train Loss: 1.0746 Train Accuracy: 70.2105 Valid Loss: 1.2792 Valid Accuracy: 61.7711 Test Loss: 1.3501 Test Accuracy: 54.2373
# Epoch 5/50: Train Loss: 0.8324 Train Accuracy: 77.1722 Valid Loss: 1.2380 Valid Accuracy: 63.0670 Test Loss: 1.2562 Test Accuracy: 56.7797
# Epoch 6/50: Train Loss: 0.6532 Train Accuracy: 83.5942 Valid Loss: 1.1798 Valid Accuracy: 60.6911 Test Loss: 1.2077 Test Accuracy: 56.7797
# Epoch 7/50: Train Loss: 0.5223 Train Accuracy: 87.2639 Valid Loss: 1.1531 Valid Accuracy: 63.7149 Test Loss: 1.1467 Test Accuracy: 59.7458
# Epoch 8/50: Train Loss: 0.3999 Train Accuracy: 91.9050 Valid Loss: 1.1721 Valid Accuracy: 63.4989 Test Loss: 1.1380 Test Accuracy: 60.1695
# Epoch 9/50: Train Loss: 0.3193 Train Accuracy: 94.6573 Valid Loss: 1.1713 Valid Accuracy: 63.4989 Test Loss: 1.1862 Test Accuracy: 61.4407
# Epoch 10/50: Train Loss: 0.2462 Train Accuracy: 96.4922 Valid Loss: 1.2142 Valid Accuracy: 65.4428 Test Loss: 1.1794 Test Accuracy: 61.8644
# Epoch 11/50: Train Loss: 0.1887 Train Accuracy: 97.8953 Valid Loss: 1.2385 Valid Accuracy: 64.1469 Test Loss: 1.1318 Test Accuracy: 62.2881
# Epoch 12/50: Train Loss: 0.1481 Train Accuracy: 98.6508 Valid Loss: 1.2602 Valid Accuracy: 63.0670 Test Loss: 1.1792 Test Accuracy: 62.7119
# Epoch 13/50: Train Loss: 0.1108 Train Accuracy: 98.8127 Valid Loss: 1.2533 Valid Accuracy: 64.7948 Test Loss: 1.2103 Test Accuracy: 61.4407
# Epoch 14/50: Train Loss: 0.1059 Train Accuracy: 99.0286 Valid Loss: 1.2662 Valid Accuracy: 63.7149 Test Loss: 1.2264 Test Accuracy: 59.3220
# Epoch 15/50: Train Loss: 0.0876 Train Accuracy: 98.8667 Valid Loss: 1.2766 Valid Accuracy: 65.6587 Test Loss: 1.2257 Test Accuracy: 61.0169
# Epoch 16/50: Train Loss: 0.0730 Train Accuracy: 99.2445 Valid Loss: 1.3041 Valid Accuracy: 65.4428 Test Loss: 1.2309 Test Accuracy: 60.5932
# Epoch 17/50: Train Loss: 0.0671 Train Accuracy: 99.0826 Valid Loss: 1.3174 Valid Accuracy: 63.0670 Test Loss: 1.3042 Test Accuracy: 61.4407
# Epoch 18/50: Train Loss: 0.0579 Train Accuracy: 99.4064 Valid Loss: 1.3191 Valid Accuracy: 64.7948 Test Loss: 1.2568 Test Accuracy: 63.1356
# Epoch 19/50: Train Loss: 0.0541 Train Accuracy: 99.4064 Valid Loss: 1.3567 Valid Accuracy: 65.2268 Test Loss: 1.2988 Test Accuracy: 61.0169
# Epoch 20/50: Train Loss: 0.0523 Train Accuracy: 99.2445 Valid Loss: 1.3579 Valid Accuracy: 66.0907 Test Loss: 1.3044 Test Accuracy: 60.5932
# Epoch 21/50: Train Loss: 0.0456 Train Accuracy: 99.2984 Valid Loss: 1.3613 Valid Accuracy: 66.0907 Test Loss: 1.2722 Test Accuracy: 61.8644
# Epoch 22/50: Train Loss: 0.0431 Train Accuracy: 99.1905 Valid Loss: 1.3709 Valid Accuracy: 64.5788 Test Loss: 1.3024 Test Accuracy: 61.4407
# Epoch 23/50: Train Loss: 0.0376 Train Accuracy: 99.3524 Valid Loss: 1.3756 Valid Accuracy: 65.0108 Test Loss: 1.3358 Test Accuracy: 59.7458
# Epoch 24/50: Train Loss: 0.0315 Train Accuracy: 99.6222 Valid Loss: 1.3834 Valid Accuracy: 64.3629 Test Loss: 1.3488 Test Accuracy: 62.2881
# Epoch 25/50: Train Loss: 0.0350 Train Accuracy: 99.3524 Valid Loss: 1.4005 Valid Accuracy: 64.1469 Test Loss: 1.3665 Test Accuracy: 61.4407
# Epoch 26/50: Train Loss: 0.0289 Train Accuracy: 99.5683 Valid Loss: 1.4193 Valid Accuracy: 64.3629 Test Loss: 1.3710 Test Accuracy: 61.0169
# Epoch 27/50: Train Loss: 0.0338 Train Accuracy: 99.4064 Valid Loss: 1.4292 Valid Accuracy: 64.5788 Test Loss: 1.3837 Test Accuracy: 61.0169
# Epoch 28/50: Train Loss: 0.0324 Train Accuracy: 99.2984 Valid Loss: 1.4002 Valid Accuracy: 64.1469 Test Loss: 1.3952 Test Accuracy: 61.8644
# Epoch 29/50: Train Loss: 0.0305 Train Accuracy: 99.3524 Valid Loss: 1.4199 Valid Accuracy: 64.5788 Test Loss: 1.3785 Test Accuracy: 61.4407
# Epoch 30/50: Train Loss: 0.0272 Train Accuracy: 99.5143 Valid Loss: 1.4158 Valid Accuracy: 65.2268 Test Loss: 1.3932 Test Accuracy: 61.4407
# Epoch 31/50: Train Loss: 0.0253 Train Accuracy: 99.4603 Valid Loss: 1.4389 Valid Accuracy: 64.7948 Test Loss: 1.3911 Test Accuracy: 62.2881
# Epoch 32/50: Train Loss: 0.0227 Train Accuracy: 99.4603 Valid Loss: 1.4178 Valid Accuracy: 64.5788 Test Loss: 1.4231 Test Accuracy: 60.5932
# Epoch 33/50: Train Loss: 0.0229 Train Accuracy: 99.5143 Valid Loss: 1.4556 Valid Accuracy: 64.3629 Test Loss: 1.3862 Test Accuracy: 63.1356
# Epoch 34/50: Train Loss: 0.0210 Train Accuracy: 99.6222 Valid Loss: 1.4287 Valid Accuracy: 65.4428 Test Loss: 1.4192 Test Accuracy: 61.0169
# Epoch 35/50: Train Loss: 0.0203 Train Accuracy: 99.6762 Valid Loss: 1.4787 Valid Accuracy: 64.1469 Test Loss: 1.4132 Test Accuracy: 61.4407
# Epoch 36/50: Train Loss: 0.0251 Train Accuracy: 99.5143 Valid Loss: 1.4425 Valid Accuracy: 65.0108 Test Loss: 1.4058 Test Accuracy: 61.0169
# Epoch 37/50: Train Loss: 0.0235 Train Accuracy: 99.6222 Valid Loss: 1.4537 Valid Accuracy: 64.5788 Test Loss: 1.4278 Test Accuracy: 61.0169
# Epoch 38/50: Train Loss: 0.0175 Train Accuracy: 99.6762 Valid Loss: 1.4757 Valid Accuracy: 65.0108 Test Loss: 1.4372 Test Accuracy: 63.1356
# Epoch 39/50: Train Loss: 0.0200 Train Accuracy: 99.4064 Valid Loss: 1.4736 Valid Accuracy: 64.3629 Test Loss: 1.4335 Test Accuracy: 62.7119
# Epoch 40/50: Train Loss: 0.0235 Train Accuracy: 99.4603 Valid Loss: 1.4733 Valid Accuracy: 64.5788 Test Loss: 1.4607 Test Accuracy: 60.1695
# Epoch 41/50: Train Loss: 0.0184 Train Accuracy: 99.5143 Valid Loss: 1.4790 Valid Accuracy: 64.1469 Test Loss: 1.4689 Test Accuracy: 61.8644
# Epoch 42/50: Train Loss: 0.0165 Train Accuracy: 99.5683 Valid Loss: 1.4852 Valid Accuracy: 63.7149 Test Loss: 1.4490 Test Accuracy: 63.5593
# Epoch 43/50: Train Loss: 0.0146 Train Accuracy: 99.6762 Valid Loss: 1.4777 Valid Accuracy: 65.2268 Test Loss: 1.4407 Test Accuracy: 61.8644
# Epoch 44/50: Train Loss: 0.0146 Train Accuracy: 99.6762 Valid Loss: 1.4921 Valid Accuracy: 63.7149 Test Loss: 1.4590 Test Accuracy: 62.7119
# Epoch 45/50: Train Loss: 0.0166 Train Accuracy: 99.4603 Valid Loss: 1.4893 Valid Accuracy: 63.9309 Test Loss: 1.4774 Test Accuracy: 61.0169
# Epoch 46/50: Train Loss: 0.0183 Train Accuracy: 99.6222 Valid Loss: 1.4812 Valid Accuracy: 63.9309 Test Loss: 1.4494 Test Accuracy: 61.0169
# Epoch 47/50: Train Loss: 0.0111 Train Accuracy: 99.8381 Valid Loss: 1.5040 Valid Accuracy: 64.5788 Test Loss: 1.4587 Test Accuracy: 61.4407
# Epoch 48/50: Train Loss: 0.0145 Train Accuracy: 99.6762 Valid Loss: 1.4919 Valid Accuracy: 64.3629 Test Loss: 1.4826 Test Accuracy: 61.4407
# Epoch 49/50: Train Loss: 0.0119 Train Accuracy: 99.7302 Valid Loss: 1.5093 Valid Accuracy: 65.0108 Test Loss: 1.4974 Test Accuracy: 61.0169
# Epoch 50/50: Train Loss: 0.0174 Train Accuracy: 99.3524 Valid Loss: 1.5119 Valid Accuracy: 64.1469 Test Loss: 1.5060 Test Accuracy: 61.8644
# Finished Fold
# ==================================================
# Fold 4/5
# Epoch 1/50: Train Loss: 2.8687 Train Accuracy: 21.8564 Valid Loss: 2.2411 Valid Accuracy: 38.8769 Test Loss: 2.4586 Test Accuracy: 29.2373
# Epoch 2/50: Train Loss: 1.8728 Train Accuracy: 48.7858 Valid Loss: 1.6682 Valid Accuracy: 50.1080 Test Loss: 1.8595 Test Accuracy: 45.7627
# Epoch 3/50: Train Loss: 1.3963 Train Accuracy: 61.7377 Valid Loss: 1.4103 Valid Accuracy: 58.3153 Test Loss: 1.5787 Test Accuracy: 52.5424
# Epoch 4/50: Train Loss: 1.0680 Train Accuracy: 70.9660 Valid Loss: 1.2318 Valid Accuracy: 62.6350 Test Loss: 1.3945 Test Accuracy: 52.1186
# Epoch 5/50: Train Loss: 0.8486 Train Accuracy: 78.0896 Valid Loss: 1.1584 Valid Accuracy: 63.0670 Test Loss: 1.3318 Test Accuracy: 53.8136
# Epoch 6/50: Train Loss: 0.6607 Train Accuracy: 84.1878 Valid Loss: 1.1263 Valid Accuracy: 63.7149 Test Loss: 1.2718 Test Accuracy: 56.7797
# Epoch 7/50: Train Loss: 0.5194 Train Accuracy: 87.5337 Valid Loss: 1.1040 Valid Accuracy: 65.0108 Test Loss: 1.2687 Test Accuracy: 56.7797
# Epoch 8/50: Train Loss: 0.3979 Train Accuracy: 91.9590 Valid Loss: 1.0967 Valid Accuracy: 63.4989 Test Loss: 1.2569 Test Accuracy: 57.2034
# Epoch 9/50: Train Loss: 0.3111 Train Accuracy: 94.8732 Valid Loss: 1.0895 Valid Accuracy: 65.0108 Test Loss: 1.2450 Test Accuracy: 56.3559
# Epoch 10/50: Train Loss: 0.2499 Train Accuracy: 96.1144 Valid Loss: 1.1037 Valid Accuracy: 65.2268 Test Loss: 1.2374 Test Accuracy: 59.7458
# Epoch 11/50: Train Loss: 0.1946 Train Accuracy: 97.2477 Valid Loss: 1.1164 Valid Accuracy: 65.2268 Test Loss: 1.2420 Test Accuracy: 56.7797
# Epoch 12/50: Train Loss: 0.1517 Train Accuracy: 98.4350 Valid Loss: 1.1407 Valid Accuracy: 64.5788 Test Loss: 1.2502 Test Accuracy: 58.8983
# Epoch 13/50: Train Loss: 0.1232 Train Accuracy: 98.5429 Valid Loss: 1.1333 Valid Accuracy: 65.4428 Test Loss: 1.3180 Test Accuracy: 58.4746
# Epoch 14/50: Train Loss: 0.1096 Train Accuracy: 98.6508 Valid Loss: 1.1663 Valid Accuracy: 64.3629 Test Loss: 1.3369 Test Accuracy: 57.2034
# Epoch 15/50: Train Loss: 0.0958 Train Accuracy: 98.8127 Valid Loss: 1.1533 Valid Accuracy: 66.0907 Test Loss: 1.2931 Test Accuracy: 59.3220
# Epoch 16/50: Train Loss: 0.0714 Train Accuracy: 99.2445 Valid Loss: 1.1689 Valid Accuracy: 65.0108 Test Loss: 1.3263 Test Accuracy: 58.0508
# Epoch 17/50: Train Loss: 0.0695 Train Accuracy: 99.4064 Valid Loss: 1.1938 Valid Accuracy: 65.2268 Test Loss: 1.3431 Test Accuracy: 58.4746
# Epoch 18/50: Train Loss: 0.0608 Train Accuracy: 99.1905 Valid Loss: 1.1967 Valid Accuracy: 64.1469 Test Loss: 1.3871 Test Accuracy: 59.7458
# Epoch 19/50: Train Loss: 0.0603 Train Accuracy: 98.7588 Valid Loss: 1.2074 Valid Accuracy: 65.2268 Test Loss: 1.3246 Test Accuracy: 61.0169
# Epoch 20/50: Train Loss: 0.0489 Train Accuracy: 99.3524 Valid Loss: 1.2200 Valid Accuracy: 65.8747 Test Loss: 1.3656 Test Accuracy: 59.7458
# Epoch 21/50: Train Loss: 0.0547 Train Accuracy: 98.8667 Valid Loss: 1.2243 Valid Accuracy: 65.2268 Test Loss: 1.3771 Test Accuracy: 60.1695
# Epoch 22/50: Train Loss: 0.0481 Train Accuracy: 99.0826 Valid Loss: 1.2247 Valid Accuracy: 64.5788 Test Loss: 1.4121 Test Accuracy: 59.7458
# Epoch 23/50: Train Loss: 0.0439 Train Accuracy: 99.1365 Valid Loss: 1.2631 Valid Accuracy: 64.1469 Test Loss: 1.3786 Test Accuracy: 61.0169
# Epoch 24/50: Train Loss: 0.0397 Train Accuracy: 99.4064 Valid Loss: 1.2450 Valid Accuracy: 65.0108 Test Loss: 1.4049 Test Accuracy: 60.5932
# Epoch 25/50: Train Loss: 0.0366 Train Accuracy: 99.1905 Valid Loss: 1.2362 Valid Accuracy: 65.4428 Test Loss: 1.4520 Test Accuracy: 59.3220
# Epoch 26/50: Train Loss: 0.0366 Train Accuracy: 99.4064 Valid Loss: 1.2336 Valid Accuracy: 64.5788 Test Loss: 1.4126 Test Accuracy: 58.8983
# Epoch 27/50: Train Loss: 0.0373 Train Accuracy: 99.2984 Valid Loss: 1.2604 Valid Accuracy: 63.9309 Test Loss: 1.4184 Test Accuracy: 60.1695
# Epoch 28/50: Train Loss: 0.0291 Train Accuracy: 99.5683 Valid Loss: 1.2620 Valid Accuracy: 64.5788 Test Loss: 1.4140 Test Accuracy: 60.1695
# Epoch 29/50: Train Loss: 0.0319 Train Accuracy: 99.3524 Valid Loss: 1.2634 Valid Accuracy: 63.2829 Test Loss: 1.4119 Test Accuracy: 59.3220
# Epoch 30/50: Train Loss: 0.0282 Train Accuracy: 99.4603 Valid Loss: 1.2530 Valid Accuracy: 64.7948 Test Loss: 1.4561 Test Accuracy: 60.1695
# Epoch 31/50: Train Loss: 0.0245 Train Accuracy: 99.4603 Valid Loss: 1.2880 Valid Accuracy: 63.7149 Test Loss: 1.4537 Test Accuracy: 59.3220
# Epoch 32/50: Train Loss: 0.0244 Train Accuracy: 99.6222 Valid Loss: 1.2760 Valid Accuracy: 64.7948 Test Loss: 1.4569 Test Accuracy: 61.0169
# Epoch 33/50: Train Loss: 0.0215 Train Accuracy: 99.5683 Valid Loss: 1.2911 Valid Accuracy: 65.0108 Test Loss: 1.4273 Test Accuracy: 60.5932
# Epoch 34/50: Train Loss: 0.0297 Train Accuracy: 99.4603 Valid Loss: 1.2901 Valid Accuracy: 64.5788 Test Loss: 1.4557 Test Accuracy: 58.8983
# Epoch 35/50: Train Loss: 0.0308 Train Accuracy: 99.1905 Valid Loss: 1.2933 Valid Accuracy: 63.9309 Test Loss: 1.4270 Test Accuracy: 58.4746
# Epoch 36/50: Train Loss: 0.0238 Train Accuracy: 99.5143 Valid Loss: 1.2759 Valid Accuracy: 64.3629 Test Loss: 1.4516 Test Accuracy: 60.5932
# Epoch 37/50: Train Loss: 0.0235 Train Accuracy: 99.2445 Valid Loss: 1.2791 Valid Accuracy: 64.7948 Test Loss: 1.4426 Test Accuracy: 59.3220
# Epoch 38/50: Train Loss: 0.0263 Train Accuracy: 99.2445 Valid Loss: 1.3205 Valid Accuracy: 63.7149 Test Loss: 1.4545 Test Accuracy: 58.8983
# Epoch 39/50: Train Loss: 0.0232 Train Accuracy: 99.3524 Valid Loss: 1.3155 Valid Accuracy: 63.7149 Test Loss: 1.4687 Test Accuracy: 62.2881
# Epoch 40/50: Train Loss: 0.0223 Train Accuracy: 99.0826 Valid Loss: 1.3215 Valid Accuracy: 63.4989 Test Loss: 1.5072 Test Accuracy: 59.3220
# Epoch 41/50: Train Loss: 0.0202 Train Accuracy: 99.4603 Valid Loss: 1.3132 Valid Accuracy: 63.0670 Test Loss: 1.4753 Test Accuracy: 61.0169
# Epoch 42/50: Train Loss: 0.0180 Train Accuracy: 99.5143 Valid Loss: 1.3250 Valid Accuracy: 63.0670 Test Loss: 1.4795 Test Accuracy: 60.1695
# Epoch 43/50: Train Loss: 0.0192 Train Accuracy: 99.4064 Valid Loss: 1.3184 Valid Accuracy: 63.9309 Test Loss: 1.4891 Test Accuracy: 59.3220
# Epoch 44/50: Train Loss: 0.0156 Train Accuracy: 99.6762 Valid Loss: 1.3216 Valid Accuracy: 63.9309 Test Loss: 1.4651 Test Accuracy: 63.1356
# Epoch 45/50: Train Loss: 0.0220 Train Accuracy: 99.2445 Valid Loss: 1.3505 Valid Accuracy: 63.7149 Test Loss: 1.4884 Test Accuracy: 61.0169
# Epoch 46/50: Train Loss: 0.0238 Train Accuracy: 99.2445 Valid Loss: 1.3249 Valid Accuracy: 64.3629 Test Loss: 1.5066 Test Accuracy: 59.3220
# Epoch 47/50: Train Loss: 0.0248 Train Accuracy: 99.2445 Valid Loss: 1.3388 Valid Accuracy: 62.8510 Test Loss: 1.4951 Test Accuracy: 61.0169
# Epoch 48/50: Train Loss: 0.0179 Train Accuracy: 99.2984 Valid Loss: 1.3268 Valid Accuracy: 63.0670 Test Loss: 1.4884 Test Accuracy: 62.2881
# Epoch 49/50: Train Loss: 0.0171 Train Accuracy: 99.5683 Valid Loss: 1.3489 Valid Accuracy: 63.9309 Test Loss: 1.5048 Test Accuracy: 61.0169
# Epoch 50/50: Train Loss: 0.0186 Train Accuracy: 99.2984 Valid Loss: 1.3401 Valid Accuracy: 62.6350 Test Loss: 1.5388 Test Accuracy: 59.3220
# Finished Fold
# ==================================================
# Fold 5/5
# Epoch 1/50: Train Loss: 2.8835 Train Accuracy: 22.8818 Valid Loss: 2.2523 Valid Accuracy: 37.3650 Test Loss: 2.4567 Test Accuracy: 29.6610
# Epoch 2/50: Train Loss: 1.8894 Train Accuracy: 48.8397 Valid Loss: 1.6889 Valid Accuracy: 48.3801 Test Loss: 1.8910 Test Accuracy: 40.6780
# Epoch 3/50: Train Loss: 1.4036 Train Accuracy: 60.4965 Valid Loss: 1.3875 Valid Accuracy: 56.1555 Test Loss: 1.5036 Test Accuracy: 51.2712
# Epoch 4/50: Train Loss: 1.0624 Train Accuracy: 72.8009 Valid Loss: 1.2306 Valid Accuracy: 62.2030 Test Loss: 1.3420 Test Accuracy: 53.3898
# Epoch 5/50: Train Loss: 0.8320 Train Accuracy: 77.7118 Valid Loss: 1.1660 Valid Accuracy: 63.0670 Test Loss: 1.2610 Test Accuracy: 56.3559
# Epoch 6/50: Train Loss: 0.6532 Train Accuracy: 84.2418 Valid Loss: 1.1119 Valid Accuracy: 63.2829 Test Loss: 1.2057 Test Accuracy: 59.3220
# Epoch 7/50: Train Loss: 0.5056 Train Accuracy: 89.5845 Valid Loss: 1.0878 Valid Accuracy: 64.1469 Test Loss: 1.1976 Test Accuracy: 58.8983
# Epoch 8/50: Train Loss: 0.3855 Train Accuracy: 92.8225 Valid Loss: 1.0937 Valid Accuracy: 63.2829 Test Loss: 1.1248 Test Accuracy: 61.4407
# Epoch 9/50: Train Loss: 0.2917 Train Accuracy: 95.8446 Valid Loss: 1.1152 Valid Accuracy: 60.2592 Test Loss: 1.1731 Test Accuracy: 58.0508
# Epoch 10/50: Train Loss: 0.2247 Train Accuracy: 96.7620 Valid Loss: 1.1066 Valid Accuracy: 62.6350 Test Loss: 1.2132 Test Accuracy: 56.7797
# Epoch 11/50: Train Loss: 0.1776 Train Accuracy: 98.2731 Valid Loss: 1.1121 Valid Accuracy: 61.9870 Test Loss: 1.1800 Test Accuracy: 61.8644
# Epoch 12/50: Train Loss: 0.1430 Train Accuracy: 98.7048 Valid Loss: 1.1541 Valid Accuracy: 63.2829 Test Loss: 1.2605 Test Accuracy: 59.3220
# Epoch 13/50: Train Loss: 0.1168 Train Accuracy: 98.9746 Valid Loss: 1.1461 Valid Accuracy: 64.5788 Test Loss: 1.2362 Test Accuracy: 58.0508
# Epoch 14/50: Train Loss: 0.0984 Train Accuracy: 98.8667 Valid Loss: 1.1779 Valid Accuracy: 63.7149 Test Loss: 1.2564 Test Accuracy: 59.3220
# Epoch 15/50: Train Loss: 0.0870 Train Accuracy: 99.1905 Valid Loss: 1.1802 Valid Accuracy: 64.1469 Test Loss: 1.2627 Test Accuracy: 58.0508
# Epoch 16/50: Train Loss: 0.0762 Train Accuracy: 99.0826 Valid Loss: 1.1965 Valid Accuracy: 63.4989 Test Loss: 1.3235 Test Accuracy: 58.0508
# Epoch 17/50: Train Loss: 0.0714 Train Accuracy: 98.9207 Valid Loss: 1.2046 Valid Accuracy: 63.2829 Test Loss: 1.2831 Test Accuracy: 57.6271
# Epoch 18/50: Train Loss: 0.0619 Train Accuracy: 99.2984 Valid Loss: 1.1922 Valid Accuracy: 65.0108 Test Loss: 1.3025 Test Accuracy: 57.2034
# Epoch 19/50: Train Loss: 0.0517 Train Accuracy: 99.4603 Valid Loss: 1.2288 Valid Accuracy: 63.0670 Test Loss: 1.3121 Test Accuracy: 58.8983
# Epoch 20/50: Train Loss: 0.0507 Train Accuracy: 99.2984 Valid Loss: 1.2504 Valid Accuracy: 63.2829 Test Loss: 1.3454 Test Accuracy: 56.7797
# Epoch 21/50: Train Loss: 0.0447 Train Accuracy: 99.3524 Valid Loss: 1.2304 Valid Accuracy: 62.6350 Test Loss: 1.3364 Test Accuracy: 57.6271
# Epoch 22/50: Train Loss: 0.0450 Train Accuracy: 99.3524 Valid Loss: 1.2508 Valid Accuracy: 62.6350 Test Loss: 1.3425 Test Accuracy: 56.7797
# Epoch 23/50: Train Loss: 0.0478 Train Accuracy: 98.9746 Valid Loss: 1.2456 Valid Accuracy: 63.2829 Test Loss: 1.3695 Test Accuracy: 58.4746
# Epoch 24/50: Train Loss: 0.0367 Train Accuracy: 99.5143 Valid Loss: 1.2519 Valid Accuracy: 62.8510 Test Loss: 1.3645 Test Accuracy: 60.1695
# Epoch 25/50: Train Loss: 0.0355 Train Accuracy: 99.4064 Valid Loss: 1.2725 Valid Accuracy: 62.8510 Test Loss: 1.3821 Test Accuracy: 56.7797
# Epoch 26/50: Train Loss: 0.0320 Train Accuracy: 99.4064 Valid Loss: 1.2655 Valid Accuracy: 64.1469 Test Loss: 1.3849 Test Accuracy: 58.4746
# Epoch 27/50: Train Loss: 0.0313 Train Accuracy: 99.4603 Valid Loss: 1.2624 Valid Accuracy: 64.1469 Test Loss: 1.3914 Test Accuracy: 58.4746
# Epoch 28/50: Train Loss: 0.0300 Train Accuracy: 99.4603 Valid Loss: 1.3055 Valid Accuracy: 65.0108 Test Loss: 1.4359 Test Accuracy: 58.4746
# Epoch 29/50: Train Loss: 0.0292 Train Accuracy: 99.4064 Valid Loss: 1.2977 Valid Accuracy: 64.3629 Test Loss: 1.4243 Test Accuracy: 58.0508
# Epoch 30/50: Train Loss: 0.0257 Train Accuracy: 99.5683 Valid Loss: 1.3048 Valid Accuracy: 63.2829 Test Loss: 1.4129 Test Accuracy: 56.3559
# Epoch 31/50: Train Loss: 0.0268 Train Accuracy: 99.4064 Valid Loss: 1.2830 Valid Accuracy: 63.2829 Test Loss: 1.4407 Test Accuracy: 57.2034
# Epoch 32/50: Train Loss: 0.0247 Train Accuracy: 99.5683 Valid Loss: 1.2993 Valid Accuracy: 62.4190 Test Loss: 1.4741 Test Accuracy: 56.7797
# Epoch 33/50: Train Loss: 0.0239 Train Accuracy: 99.4603 Valid Loss: 1.3103 Valid Accuracy: 64.5788 Test Loss: 1.4401 Test Accuracy: 54.6610
# Epoch 34/50: Train Loss: 0.0240 Train Accuracy: 99.3524 Valid Loss: 1.3008 Valid Accuracy: 64.5788 Test Loss: 1.4606 Test Accuracy: 57.2034
# Epoch 35/50: Train Loss: 0.0245 Train Accuracy: 99.4064 Valid Loss: 1.3315 Valid Accuracy: 64.3629 Test Loss: 1.4770 Test Accuracy: 57.2034
# Epoch 36/50: Train Loss: 0.0218 Train Accuracy: 99.5683 Valid Loss: 1.3183 Valid Accuracy: 64.1469 Test Loss: 1.4558 Test Accuracy: 57.2034
# Epoch 37/50: Train Loss: 0.0196 Train Accuracy: 99.5683 Valid Loss: 1.3130 Valid Accuracy: 63.4989 Test Loss: 1.4844 Test Accuracy: 57.6271
# Epoch 38/50: Train Loss: 0.0187 Train Accuracy: 99.5143 Valid Loss: 1.3092 Valid Accuracy: 62.8510 Test Loss: 1.4769 Test Accuracy: 58.4746
# Epoch 39/50: Train Loss: 0.0172 Train Accuracy: 99.6762 Valid Loss: 1.3227 Valid Accuracy: 63.7149 Test Loss: 1.4525 Test Accuracy: 60.5932
# Epoch 40/50: Train Loss: 0.0191 Train Accuracy: 99.6222 Valid Loss: 1.3479 Valid Accuracy: 63.9309 Test Loss: 1.4583 Test Accuracy: 56.3559
# Epoch 41/50: Train Loss: 0.0170 Train Accuracy: 99.6222 Valid Loss: 1.3295 Valid Accuracy: 62.4190 Test Loss: 1.5171 Test Accuracy: 55.9322
# Epoch 42/50: Train Loss: 0.0159 Train Accuracy: 99.6762 Valid Loss: 1.3528 Valid Accuracy: 63.7149 Test Loss: 1.4990 Test Accuracy: 58.8983
# Epoch 43/50: Train Loss: 0.0170 Train Accuracy: 99.5683 Valid Loss: 1.3585 Valid Accuracy: 65.0108 Test Loss: 1.4833 Test Accuracy: 55.5085
# Epoch 44/50: Train Loss: 0.0192 Train Accuracy: 99.4064 Valid Loss: 1.3289 Valid Accuracy: 63.4989 Test Loss: 1.5200 Test Accuracy: 58.4746
# Epoch 45/50: Train Loss: 0.0196 Train Accuracy: 99.5683 Valid Loss: 1.3470 Valid Accuracy: 63.9309 Test Loss: 1.5325 Test Accuracy: 55.5085
# Epoch 46/50: Train Loss: 0.0149 Train Accuracy: 99.4603 Valid Loss: 1.3255 Valid Accuracy: 64.3629 Test Loss: 1.5085 Test Accuracy: 58.4746
# Epoch 47/50: Train Loss: 0.0149 Train Accuracy: 99.6222 Valid Loss: 1.3523 Valid Accuracy: 63.2829 Test Loss: 1.5446 Test Accuracy: 58.4746
# Epoch 48/50: Train Loss: 0.0175 Train Accuracy: 99.4603 Valid Loss: 1.3423 Valid Accuracy: 64.3629 Test Loss: 1.5293 Test Accuracy: 58.4746
# Epoch 49/50: Train Loss: 0.0155 Train Accuracy: 99.5143 Valid Loss: 1.3431 Valid Accuracy: 63.9309 Test Loss: 1.5380 Test Accuracy: 57.6271
# Epoch 50/50: Train Loss: 0.0173 Train Accuracy: 99.3524 Valid Loss: 1.3407 Valid Accuracy: 63.7149 Test Loss: 1.5210 Test Accuracy: 58.4746
# Finished Fold
# ==================================================

# %%
# Evaluate the trained model on the training and validation sets for each fold.
mobilenetv2_avg_train_acc_k_folds = []
mobilenetv2_avg_val_acc_k_folds = []

def evaluate_accuracy(history, index):
    history_cpu = [item.cpu() for item in history]
    return sum(history_cpu) / len(history_cpu)

for i in range(num_folds):
    train_accuracy = evaluate_accuracy(fold_train_accs[i], 2)
    valid_accuracy = evaluate_accuracy(fold_valid_accs[i], 3)
    print(f'Fold {i + 1}/{num_folds}:')
    print(f'\tTraining Accuracy: {train_accuracy * 100:.2f}%')
    print(f'\tValidation Accuracy: {valid_accuracy * 100:.2f}%')
    mobilenetv2_avg_train_acc_k_folds.append(train_accuracy)
    mobilenetv2_avg_val_acc_k_folds.append(valid_accuracy)

# Compute the average training and validation accuracy over all folds.
overall_train_acc = sum(mobilenetv2_avg_train_acc_k_folds) / len(mobilenetv2_avg_train_acc_k_folds)
overall_val_acc = sum(mobilenetv2_avg_val_acc_k_folds) / len(mobilenetv2_avg_val_acc_k_folds)

# Calculate the average and standard deviation of the training and validation accuracy over all folds.
mobilenetv2_avg_train_acc = np.mean(mobilenetv2_avg_train_acc_k_folds)
mobilenetv2_std_train_acc = np.std(mobilenetv2_avg_train_acc_k_folds)
mobilenetv2_avg_val_acc = np.mean(mobilenetv2_avg_val_acc_k_folds)
mobilenetv2_std_val_acc = np.std(mobilenetv2_avg_val_acc_k_folds)

# Print the average and standard deviation of the training and validation accuracy over all folds.
print(f'\nAverage Training Accuracy over {num_folds}-fold Cross Validation: {mobilenetv2_avg_train_acc * 100:.2f}% +/- {mobilenetv2_std_train_acc * 100:.2f}%')
print(f'Average Validation Accuracy over {num_folds}-fold Cross Validation: {mobilenetv2_avg_val_acc * 100:.2f}% +/- {mobilenetv2_std_val_acc * 100:.2f}%')
# Out:
# Fold 1/5:
# 	Training Accuracy: 93.98%
# 	Validation Accuracy: 63.44%
# Fold 2/5:
# 	Training Accuracy: 94.40%
# 	Validation Accuracy: 63.14%
# Fold 3/5:
# 	Training Accuracy: 94.17%
# 	Validation Accuracy: 63.46%
# Fold 4/5:
# 	Training Accuracy: 94.08%
# 	Validation Accuracy: 63.38%
# Fold 5/5:
# 	Training Accuracy: 94.33%
# 	Validation Accuracy: 62.55%
#
# Average Training Accuracy over 5-fold Cross Validation: 94.19% +/- 0.15%
# Average Validation Accuracy over 5-fold Cross Validation: 63.19% +/- 0.34%

# %%
# Plot the training and validation loss for each epoch
model_name = "MobileNet-V2"
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(fold_train_losses[fold], label=f'Training Loss (Fold {fold+1})')
    plt.plot(fold_valid_losses[fold], label=f'Validation Loss (Fold {fold+1})')

plt.title(f'{model_name} Training and Validation Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Compute mean loss across all folds at each epoch
train_loss_mean = np.mean([np.array(fold_train_losses[i]) for i in range(num_folds)], axis=0)
valid_loss_mean = np.mean([np.array(fold_valid_losses[i]) for i in range(num_folds)], axis=0)

# Plot mean loss history
plt.figure(figsize=(10, 7))
plt.plot(train_loss_mean, label='Training Loss', color='pink')
plt.plot(valid_loss_mean, label='Validation Loss', color='purple')
plt.title(f'{model_name} Mean Training and Validation Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the training and validation accuracy for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(np.array([acc.cpu() for acc in fold_train_accs[fold]]) * 100, label=f'Training Accuracy (Fold {fold+1})')
    plt.plot(np.array([acc.cpu() for acc in fold_valid_accs[fold]]) * 100, label=f'Validation Accuracy (Fold {fold+1})')

plt.title(f'{model_name} Training and Validation Accuracy - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Compute mean accuracy across all folds at each epoch
train_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_train_accs[i]]) for i in range(num_folds)], axis=0)
valid_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_valid_accs[i]]) for i in range(num_folds)], axis=0)

# Plot mean accuracy history
plt.figure(figsize=(10, 7))
plt.plot(np.arange(1, num_epochs + 1), train_acc_mean * 100, label='Training Accuracy', color='pink')
plt.plot(np.arange(1, num_epochs + 1), valid_acc_mean * 100, label='Validation Accuracy', color='purple')
plt.title(f'{model_name} Mean Training and Validation Accuracy for {num_folds}-fold Cross-validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Evaluate the trained model on the test sets for each fold.
mobilenetv2_avg_test_acc_k_folds = []

def evaluate_accuracy(history, index):
    history_cpu = [item.cpu() for item in history]
    return sum(history_cpu) / len(history_cpu)

for i in range(num_folds):
    test_accuracy = evaluate_accuracy(fold_test_accs[i], 2)
    print(f'Fold {i + 1}/{num_folds}:')
    print(f'\tTest Accuracy: {test_accuracy * 100:.2f}%')
    mobilenetv2_avg_test_acc_k_folds.append(test_accuracy)

# Compute the average test accuracy over all folds.
overall_test_acc = sum(mobilenetv2_avg_test_acc_k_folds) / len(mobilenetv2_avg_test_acc_k_folds)

# Calculate the average and standard deviation of the test accuracy over all folds.
mobilenetv2_avg_test_acc = np.mean(mobilenetv2_avg_test_acc_k_folds)
mobilenetv2_std_test_acc = np.std(mobilenetv2_avg_test_acc_k_folds)

# Print the average and standard deviation of the test accuracy over all folds.
print(f'\nAverage Test Accuracy over {num_folds}-fold Cross Validation: {mobilenetv2_avg_test_acc * 100:.2f}% +/- {mobilenetv2_std_test_acc * 100:.2f}%')
# Out:
# Fold 1/5:
# 	Test Accuracy: 55.06%
# Fold 2/5:
# 	Test Accuracy: 55.16%
# Fold 3/5:
# 	Test Accuracy: 59.97%
# Fold 4/5:
# 	Test Accuracy: 58.28%
# Fold 5/5:
# 	Test Accuracy: 56.80%
#
# Average Test Accuracy over 5-fold Cross Validation: 57.05% +/- 1.88%

# %%
# Plot the test loss for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(fold_test_losses[fold], label=f'Test Loss (Fold {fold+1})')

plt.title(f'{model_name} Test Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the test accuracy for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(np.array([acc.cpu() for acc in fold_test_accs[fold]]) * 100, label=f'Test Accuracy (Fold {fold+1})')

plt.title(f'{model_name} Test Accuracy - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Compute mean accuracy across all folds at each epoch
test_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_test_accs[i]]) for i in range(num_folds)], axis=0)

# Plot mean accuracy history
plt.figure(figsize=(10, 7))
plt.plot(np.arange(1, num_epochs + 1), test_acc_mean * 100, label='Test Accuracy', color='purple')
plt.title(f'{model_name} Mean Test Accuracy for {num_folds}-fold Cross-validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
print("Classes: ")
class_names = test_dataset.classes
print(test_dataset.classes)
# Out:
# Classes:
# ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Bell_pepper leaf', 'Bell_pepper leaf spot', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Potato leaf early blight', 'Potato leaf late blight', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'Tomato Early blight leaf', 'Tomato Septoria leaf spot', 'Tomato leaf', 'Tomato leaf bacterial spot', 'Tomato leaf late blight', 'Tomato leaf mosaic virus', 'Tomato leaf yellow virus', 'Tomato mold leaf', 'grape leaf', 'grape leaf black rot']

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

def predict_single_image(model, image_path, device, top_k=3):
    model.eval()

    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    image = Image.open(image_path).convert('RGB')
    image_tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image_tensor)
        probabilities = torch.nn.functional.softmax(output, dim=1)
        top_probs, top_indices = torch.topk(probabilities, top_k)

    top_probs = top_probs.cpu().numpy().flatten()
    top_indices = top_indices.cpu().numpy().flatten()

    return top_probs, top_indices

import matplotlib.cm as cm

def display_image_with_predictions(image_path, top_probs, top_indices, class_names):
    image = Image.open(image_path).convert('RGB')
    
    fig, (ax1, ax2) = plt.subplots(figsize=(8, 4), ncols=2)
    
    ax1.imshow(image)
    ax1.axis('on')
    ax1.set_title(f"Class: {class_names[top_indices[0]]}")
    
    for idx in range(len(top_indices)):
        ax1.annotate(f"{top_probs[idx]*100:.2f}%", 
                     (image.size[0] * (idx+1) / (len(top_indices)+1), image.size[1] - 20),
                     color='white',
                     fontsize=12,
                     bbox=dict(facecolor='black', edgecolor='white', boxstyle='round,pad=0.5'))
    
    y_pos = np.arange(len(top_indices))
    cmap = cm.get_cmap('viridis')
    colors = cmap(np.linspace(0, 1, len(top_indices)))
    ax2.barh(y_pos, top_probs * 100, align='center', color=colors)
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels([test_dataset.classes[idx] for idx in top_indices])
    ax2.invert_yaxis()
    ax2.set_xlabel('Score (%)')
    ax2.set_title('Top 3 Predictions')

    plt.tight_layout()
    plt.show()

image_path = "test/Apple rust leaf/Apple rust leaf (6).jpg"
top_probs, top_indices = predict_single_image(model, image_path, device, top_k=3)
display_image_with_predictions(image_path, top_probs, top_indices, test_dataset.classes)

# %%
def print_predictions(top_probs, top_indices, class_names):
    print("Predictions:")
    for i in range(len(top_indices)):
        print(f"Prediction {i+1}: {test_dataset.classes[top_indices[i]]}, Score: {top_probs[i] * 100:.5f}%")

print_predictions(top_probs, top_indices, test_dataset.classes)
# Out:
# Predictions:
# Prediction 1: Apple rust leaf, Score: 98.63518%
# Prediction 2: grape leaf black rot, Score: 1.14355%
# Prediction 3: Raspberry leaf, Score: 0.06310%

# %%
image_path = "test/grape leaf black rot/grape leaf black rot (3).jpg"
top_probs, top_indices = predict_single_image(model, image_path, device, top_k=3)
display_image_with_predictions(image_path, top_probs, top_indices, test_dataset.classes)

# %%
def print_predictions(top_probs, top_indices, class_names):
    print("Predictions:")
    for i in range(len(top_indices)):
        print(f"Prediction {i+1}: {test_dataset.classes[top_indices[i]]}, Score: {top_probs[i] * 100:.5f}%")

print_predictions(top_probs, top_indices, test_dataset.classes)
# Out:
# Predictions:
# Prediction 1: grape leaf black rot, Score: 81.22958%
# Prediction 2: Tomato Septoria leaf spot, Score: 10.99749%
# Prediction 3: Apple rust leaf, Score: 3.58004%
