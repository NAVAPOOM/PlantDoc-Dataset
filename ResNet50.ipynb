# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import os
import torch
import torchvision.transforms as transforms
import glob
import torchvision
import time
import random
from PIL import Image
from torch.utils.data import DataLoader, Dataset

# %%
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split

ROOT_DIR_TRAIN = "train"
ROOT_DIR_TEST = "test"

# Common transforms
common_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Prepare the Dataset
dataset = datasets.ImageFolder(root=ROOT_DIR_TRAIN, transform=common_transform)

train_size = int(0.80 * len(dataset))
valid_size = len(dataset) - train_size

# Use random_split to create train and validation datasets
train_dataset, valid_dataset = random_split(dataset, [train_size, valid_size])
test_dataset = datasets.ImageFolder(root=ROOT_DIR_TEST, transform=common_transform)

# Prepare the Data Loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=4)

# %%
num_images = len(dataset)
num_classes = len(dataset.classes)
print(f"Number of Images: {num_images}")
print(f"Number of Classes: {num_classes}")
# Out:
# Number of Images: 2316
# Number of Classes: 27

# %%
num_images = len(test_dataset)
num_classes = len(test_dataset.classes)
print(f"Number of Images: {num_images}")
print(f"Number of Classes: {num_classes}")
# Out:
# Number of Images: 236
# Number of Classes: 27

# %%
print(f"Number of training images: {len(train_dataset)}")
print(f"Number of validation images: {len(valid_dataset)}")
print(f"Number of test images: {len(test_dataset)}")
# Out:
# Number of training images: 1852
# Number of validation images: 464
# Number of test images: 236

# %%
from torchvision import models
dir(models)
# Out:
# ['AlexNet',
#  'AlexNet_Weights',
#  'ConvNeXt',
#  'ConvNeXt_Base_Weights',
#  'ConvNeXt_Large_Weights',
#  'ConvNeXt_Small_Weights',
#  'ConvNeXt_Tiny_Weights',
#  'DenseNet',
#  'DenseNet121_Weights',
#  'DenseNet161_Weights',
#  'DenseNet169_Weights',
#  'DenseNet201_Weights',
#  'EfficientNet',
#  'EfficientNet_B0_Weights',
#  'EfficientNet_B1_Weights',
#  'EfficientNet_B2_Weights',
#  'EfficientNet_B3_Weights',
#  'EfficientNet_B4_Weights',
#  'EfficientNet_B5_Weights',
#  'EfficientNet_B6_Weights',
#  'EfficientNet_B7_Weights',
#  'EfficientNet_V2_L_Weights',
#  'EfficientNet_V2_M_Weights',
#  'EfficientNet_V2_S_Weights',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'GoogLeNet_Weights',
#  'Inception3',
#  'InceptionOutputs',
#  'Inception_V3_Weights',
#  'MNASNet',
#  'MNASNet0_5_Weights',
#  'MNASNet0_75_Weights',
#  'MNASNet1_0_Weights',
#  'MNASNet1_3_Weights',
#  'MaxVit',
#  'MaxVit_T_Weights',
#  'MobileNetV2',
#  'MobileNetV3',
#  'MobileNet_V2_Weights',
#  'MobileNet_V3_Large_Weights',
#  'MobileNet_V3_Small_Weights',
#  'RegNet',
#  'RegNet_X_16GF_Weights',
#  'RegNet_X_1_6GF_Weights',
#  'RegNet_X_32GF_Weights',
#  'RegNet_X_3_2GF_Weights',
#  'RegNet_X_400MF_Weights',
#  'RegNet_X_800MF_Weights',
#  'RegNet_X_8GF_Weights',
#  'RegNet_Y_128GF_Weights',
#  'RegNet_Y_16GF_Weights',
#  'RegNet_Y_1_6GF_Weights',
#  'RegNet_Y_32GF_Weights',
#  'RegNet_Y_3_2GF_Weights',
#  'RegNet_Y_400MF_Weights',
#  'RegNet_Y_800MF_Weights',
#  'RegNet_Y_8GF_Weights',
#  'ResNeXt101_32X8D_Weights',
#  'ResNeXt101_64X4D_Weights',
#  'ResNeXt50_32X4D_Weights',
#  'ResNet',
#  'ResNet101_Weights',
#  'ResNet152_Weights',
#  'ResNet18_Weights',
#  'ResNet34_Weights',
#  'ResNet50_Weights',
#  'ShuffleNetV2',
#  'ShuffleNet_V2_X0_5_Weights',
#  'ShuffleNet_V2_X1_0_Weights',
#  'ShuffleNet_V2_X1_5_Weights',
#  'ShuffleNet_V2_X2_0_Weights',
#  'SqueezeNet',
#  'SqueezeNet1_0_Weights',
#  'SqueezeNet1_1_Weights',
#  'SwinTransformer',
#  'Swin_B_Weights',
#  'Swin_S_Weights',
#  'Swin_T_Weights',
#  'Swin_V2_B_Weights',
#  'Swin_V2_S_Weights',
#  'Swin_V2_T_Weights',
#  'VGG',
#  'VGG11_BN_Weights',
#  'VGG11_Weights',
#  'VGG13_BN_Weights',
#  'VGG13_Weights',
#  'VGG16_BN_Weights',
#  'VGG16_Weights',
#  'VGG19_BN_Weights',
#  'VGG19_Weights',
#  'ViT_B_16_Weights',
#  'ViT_B_32_Weights',
#  'ViT_H_14_Weights',
#  'ViT_L_16_Weights',
#  'ViT_L_32_Weights',
#  'VisionTransformer',
#  'Weights',
#  'WeightsEnum',
#  'Wide_ResNet101_2_Weights',
#  'Wide_ResNet50_2_Weights',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_api',
#  '_meta',
#  '_utils',
#  'alexnet',
#  'convnext',
#  'convnext_base',
#  'convnext_large',
#  'convnext_small',
#  'convnext_tiny',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'efficientnet',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'efficientnet_b3',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_v2_l',
#  'efficientnet_v2_m',
#  'efficientnet_v2_s',
#  'get_model',
#  'get_model_builder',
#  'get_model_weights',
#  'get_weight',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'list_models',
#  'maxvit',
#  'maxvit_t',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'optical_flow',
#  'quantization',
#  'regnet',
#  'regnet_x_16gf',
#  'regnet_x_1_6gf',
#  'regnet_x_32gf',
#  'regnet_x_3_2gf',
#  'regnet_x_400mf',
#  'regnet_x_800mf',
#  'regnet_x_8gf',
#  'regnet_y_128gf',
#  'regnet_y_16gf',
#  'regnet_y_1_6gf',
#  'regnet_y_32gf',
#  'regnet_y_3_2gf',
#  'regnet_y_400mf',
#  'regnet_y_800mf',
#  'regnet_y_8gf',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext101_64x4d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'swin_b',
#  'swin_s',
#  'swin_t',
#  'swin_transformer',
#  'swin_v2_b',
#  'swin_v2_s',
#  'swin_v2_t',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'video',
#  'vision_transformer',
#  'vit_b_16',
#  'vit_b_32',
#  'vit_h_14',
#  'vit_l_16',
#  'vit_l_32',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
# !pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.9/dist-packages (1.5.1)

# %%
import torch.nn as nn
from torchsummary import summary
from torchvision import models

# Load a pre-trained ResNet-50 model
resnet50 = models.resnet50(pretrained=True)

# Set the number of classes to match your dataset
num_classes = 27

# Modify the fully connected layer to match the number of classes
resnet50.fc = nn.Linear(resnet50.fc.in_features, num_classes)

# Set the device (CPU or GPU)
resnet50.to(device)

# Display the model summary
summary(resnet50, input_size=(3, 224, 224))
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 227MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                   [-1, 27]          55,323
# ================================================================
# Total params: 23,563,355
# Trainable params: 23,563,355
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.55
# Params size (MB): 89.89
# Estimated Total Size (MB): 377.01
# ----------------------------------------------------------------

# %%
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader, Subset
import numpy as np

def train_model(model, criterion, optimizer, dataloader, device):
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

def validate_model(model, criterion, dataloader, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(dataloader.dataset)
        epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

# %%
def test_model(model, criterion, test_loader, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(test_loader.dataset)
        epoch_acc = running_corrects.double() / len(test_loader.dataset)

    return epoch_loss, epoch_acc

# %%
torch.backends.cudnn.benchmark = True

# %%
# Set the number of folds
num_folds = 5

# Prepare the data
X = np.arange(len(dataset))
y = np.array([label for _, label in dataset.imgs])

# Set up the StratifiedKFold
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Set device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize lists to store fold results
fold_train_losses = []
fold_valid_losses = []
fold_test_losses = []
fold_train_accs = []
fold_valid_accs = []
fold_test_accs = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, y)):
    print(f"Fold {fold + 1}/{num_folds}")

    # Create data loaders for the current fold
    train_data = Subset(dataset, train_index)
    valid_data = Subset(dataset, valid_index)
    train_loader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=4)
    valid_loader = DataLoader(valid_data, batch_size=32, shuffle=False, num_workers=4)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

    # Load and prepare the model
    model = models.resnet50(pretrained=True)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.to(device)

    # Set the criterion and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    # Train and validate the model
    num_epochs = 50
    epoch_train_losses = []
    epoch_valid_losses = []
    epoch_test_losses = []
    epoch_train_accs = []
    epoch_valid_accs = []
    epoch_test_accs = []
    for epoch in range(num_epochs):
        train_loss, train_acc = train_model(model, criterion, optimizer, train_loader, device)
        valid_loss, valid_acc = validate_model(model, criterion, valid_loader, device)
        test_loss, test_acc = test_model(model, criterion, test_loader, device)

        epoch_train_losses.append(train_loss)
        epoch_valid_losses.append(valid_loss)
        epoch_test_losses.append(test_loss)
        epoch_train_accs.append(train_acc)
        epoch_valid_accs.append(valid_acc)
        epoch_test_accs.append(test_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}: "
              f"Train Loss: {train_loss:.4f} Train Accuracy: {train_acc * 100:.4f} "
              f"Valid Loss: {valid_loss:.4f} Valid Accuracy: {valid_acc * 100:.4f} "
              f"Test Loss: {test_loss:.4f} Test Accuracy: {test_acc * 100:.4f}")

    fold_train_losses.append(epoch_train_losses)
    fold_valid_losses.append(epoch_valid_losses)
    fold_test_losses.append(epoch_test_losses)
    fold_train_accs.append(epoch_train_accs)
    fold_valid_accs.append(epoch_valid_accs)
    fold_test_accs.append(epoch_test_accs)

    print("Finished Fold")
    print("=" * 50)
# Out:
# Fold 1/5
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50: Train Loss: 2.9426 Train Accuracy: 19.8704 Valid Loss: 2.4728 Valid Accuracy: 35.7759 Test Loss: 2.5680 Test Accuracy: 26.6949
# Epoch 2/50: Train Loss: 2.0301 Train Accuracy: 45.5724 Valid Loss: 1.8166 Valid Accuracy: 47.8448 Test Loss: 1.9712 Test Accuracy: 45.3390
# Epoch 3/50: Train Loss: 1.4461 Train Accuracy: 60.8531 Valid Loss: 1.5070 Valid Accuracy: 58.6207 Test Loss: 1.5929 Test Accuracy: 49.5763
# Epoch 4/50: Train Loss: 1.0352 Train Accuracy: 74.4600 Valid Loss: 1.3222 Valid Accuracy: 62.2845 Test Loss: 1.3726 Test Accuracy: 56.3559
# Epoch 5/50: Train Loss: 0.7502 Train Accuracy: 83.8013 Valid Loss: 1.1998 Valid Accuracy: 64.6552 Test Loss: 1.2345 Test Accuracy: 59.3220
# Epoch 6/50: Train Loss: 0.5082 Train Accuracy: 89.7948 Valid Loss: 1.1631 Valid Accuracy: 64.8707 Test Loss: 1.1625 Test Accuracy: 59.7458
# Epoch 7/50: Train Loss: 0.3574 Train Accuracy: 94.7084 Valid Loss: 1.1273 Valid Accuracy: 65.5172 Test Loss: 1.1345 Test Accuracy: 60.5932
# Epoch 8/50: Train Loss: 0.2503 Train Accuracy: 97.3002 Valid Loss: 1.1383 Valid Accuracy: 63.5776 Test Loss: 1.1452 Test Accuracy: 60.1695
# Epoch 9/50: Train Loss: 0.1817 Train Accuracy: 98.1641 Valid Loss: 1.1351 Valid Accuracy: 64.6552 Test Loss: 1.1509 Test Accuracy: 57.6271
# Epoch 10/50: Train Loss: 0.1298 Train Accuracy: 98.8121 Valid Loss: 1.1444 Valid Accuracy: 64.6552 Test Loss: 1.1687 Test Accuracy: 60.1695
# Epoch 11/50: Train Loss: 0.0967 Train Accuracy: 98.8121 Valid Loss: 1.1680 Valid Accuracy: 65.0862 Test Loss: 1.1575 Test Accuracy: 58.8983
# Epoch 12/50: Train Loss: 0.0887 Train Accuracy: 98.9741 Valid Loss: 1.1618 Valid Accuracy: 64.6552 Test Loss: 1.1733 Test Accuracy: 59.3220
# Epoch 13/50: Train Loss: 0.0667 Train Accuracy: 99.0821 Valid Loss: 1.1701 Valid Accuracy: 63.7931 Test Loss: 1.1899 Test Accuracy: 60.5932
# Epoch 14/50: Train Loss: 0.0639 Train Accuracy: 99.1361 Valid Loss: 1.1607 Valid Accuracy: 64.4397 Test Loss: 1.2177 Test Accuracy: 60.1695
# Epoch 15/50: Train Loss: 0.0583 Train Accuracy: 98.9741 Valid Loss: 1.1846 Valid Accuracy: 63.7931 Test Loss: 1.1793 Test Accuracy: 62.2881
# Epoch 16/50: Train Loss: 0.0527 Train Accuracy: 99.1361 Valid Loss: 1.1792 Valid Accuracy: 65.5172 Test Loss: 1.2028 Test Accuracy: 61.4407
# Epoch 17/50: Train Loss: 0.0457 Train Accuracy: 99.0821 Valid Loss: 1.1946 Valid Accuracy: 64.8707 Test Loss: 1.2133 Test Accuracy: 60.5932
# Epoch 18/50: Train Loss: 0.0389 Train Accuracy: 99.2981 Valid Loss: 1.1972 Valid Accuracy: 66.1638 Test Loss: 1.2011 Test Accuracy: 58.4746
# Epoch 19/50: Train Loss: 0.0373 Train Accuracy: 99.1901 Valid Loss: 1.2280 Valid Accuracy: 64.6552 Test Loss: 1.2487 Test Accuracy: 58.8983
# Epoch 20/50: Train Loss: 0.0353 Train Accuracy: 99.1901 Valid Loss: 1.2134 Valid Accuracy: 64.6552 Test Loss: 1.2361 Test Accuracy: 60.1695
# Epoch 21/50: Train Loss: 0.0316 Train Accuracy: 99.2981 Valid Loss: 1.2058 Valid Accuracy: 65.9483 Test Loss: 1.2254 Test Accuracy: 58.8983
# Epoch 22/50: Train Loss: 0.0328 Train Accuracy: 99.1361 Valid Loss: 1.2104 Valid Accuracy: 66.5948 Test Loss: 1.2587 Test Accuracy: 59.3220
# Epoch 23/50: Train Loss: 0.0313 Train Accuracy: 99.0821 Valid Loss: 1.2093 Valid Accuracy: 67.0259 Test Loss: 1.2689 Test Accuracy: 59.7458
# Epoch 24/50: Train Loss: 0.0291 Train Accuracy: 99.3521 Valid Loss: 1.2110 Valid Accuracy: 65.9483 Test Loss: 1.3220 Test Accuracy: 59.3220
# Epoch 25/50: Train Loss: 0.0293 Train Accuracy: 99.3521 Valid Loss: 1.2407 Valid Accuracy: 64.8707 Test Loss: 1.2722 Test Accuracy: 60.5932
# Epoch 26/50: Train Loss: 0.0271 Train Accuracy: 99.1901 Valid Loss: 1.2168 Valid Accuracy: 65.5172 Test Loss: 1.2799 Test Accuracy: 60.5932
# Epoch 27/50: Train Loss: 0.0280 Train Accuracy: 99.1361 Valid Loss: 1.2385 Valid Accuracy: 65.7328 Test Loss: 1.2667 Test Accuracy: 61.0169
# Epoch 28/50: Train Loss: 0.0260 Train Accuracy: 99.3521 Valid Loss: 1.2453 Valid Accuracy: 65.5172 Test Loss: 1.2734 Test Accuracy: 60.1695
# Epoch 29/50: Train Loss: 0.0218 Train Accuracy: 99.5140 Valid Loss: 1.2475 Valid Accuracy: 64.8707 Test Loss: 1.3297 Test Accuracy: 60.1695
# Epoch 30/50: Train Loss: 0.0215 Train Accuracy: 99.2441 Valid Loss: 1.2401 Valid Accuracy: 65.5172 Test Loss: 1.3064 Test Accuracy: 59.7458
# Epoch 31/50: Train Loss: 0.0214 Train Accuracy: 99.1901 Valid Loss: 1.2329 Valid Accuracy: 66.1638 Test Loss: 1.3235 Test Accuracy: 60.1695
# Epoch 32/50: Train Loss: 0.0211 Train Accuracy: 99.2981 Valid Loss: 1.2449 Valid Accuracy: 64.6552 Test Loss: 1.3033 Test Accuracy: 59.7458
# Epoch 33/50: Train Loss: 0.0203 Train Accuracy: 99.3521 Valid Loss: 1.2427 Valid Accuracy: 65.5172 Test Loss: 1.3609 Test Accuracy: 59.7458
# Epoch 34/50: Train Loss: 0.0182 Train Accuracy: 99.2981 Valid Loss: 1.2392 Valid Accuracy: 64.2241 Test Loss: 1.3561 Test Accuracy: 59.7458
# Epoch 35/50: Train Loss: 0.0172 Train Accuracy: 99.2981 Valid Loss: 1.2369 Valid Accuracy: 66.5948 Test Loss: 1.3427 Test Accuracy: 59.7458
# Epoch 36/50: Train Loss: 0.0179 Train Accuracy: 99.4600 Valid Loss: 1.2482 Valid Accuracy: 65.3017 Test Loss: 1.3534 Test Accuracy: 60.1695
# Epoch 37/50: Train Loss: 0.0201 Train Accuracy: 99.2981 Valid Loss: 1.2820 Valid Accuracy: 64.4397 Test Loss: 1.3781 Test Accuracy: 58.4746
# Epoch 38/50: Train Loss: 0.0186 Train Accuracy: 99.5140 Valid Loss: 1.2616 Valid Accuracy: 65.5172 Test Loss: 1.3393 Test Accuracy: 61.8644
# Epoch 39/50: Train Loss: 0.0193 Train Accuracy: 99.3521 Valid Loss: 1.2673 Valid Accuracy: 64.4397 Test Loss: 1.3339 Test Accuracy: 60.1695
# Epoch 40/50: Train Loss: 0.0189 Train Accuracy: 99.3521 Valid Loss: 1.2616 Valid Accuracy: 65.5172 Test Loss: 1.3497 Test Accuracy: 60.5932
# Epoch 41/50: Train Loss: 0.0162 Train Accuracy: 99.5680 Valid Loss: 1.2685 Valid Accuracy: 65.5172 Test Loss: 1.3183 Test Accuracy: 61.0169
# Epoch 42/50: Train Loss: 0.0185 Train Accuracy: 99.4060 Valid Loss: 1.2676 Valid Accuracy: 64.8707 Test Loss: 1.3462 Test Accuracy: 60.5932
# Epoch 43/50: Train Loss: 0.0188 Train Accuracy: 99.4060 Valid Loss: 1.2767 Valid Accuracy: 65.3017 Test Loss: 1.3581 Test Accuracy: 59.3220
# Epoch 44/50: Train Loss: 0.0165 Train Accuracy: 99.3521 Valid Loss: 1.2754 Valid Accuracy: 64.6552 Test Loss: 1.3879 Test Accuracy: 58.4746
# Epoch 45/50: Train Loss: 0.0157 Train Accuracy: 99.3521 Valid Loss: 1.2690 Valid Accuracy: 65.9483 Test Loss: 1.3609 Test Accuracy: 60.1695
# Epoch 46/50: Train Loss: 0.0154 Train Accuracy: 99.5140 Valid Loss: 1.2804 Valid Accuracy: 64.6552 Test Loss: 1.3756 Test Accuracy: 60.1695
# Epoch 47/50: Train Loss: 0.0167 Train Accuracy: 99.4600 Valid Loss: 1.2593 Valid Accuracy: 65.3017 Test Loss: 1.3533 Test Accuracy: 60.5932
# Epoch 48/50: Train Loss: 0.0172 Train Accuracy: 99.4600 Valid Loss: 1.2799 Valid Accuracy: 64.8707 Test Loss: 1.4025 Test Accuracy: 59.7458
# Epoch 49/50: Train Loss: 0.0141 Train Accuracy: 99.3521 Valid Loss: 1.2899 Valid Accuracy: 64.6552 Test Loss: 1.3984 Test Accuracy: 58.8983
# Epoch 50/50: Train Loss: 0.0129 Train Accuracy: 99.5140 Valid Loss: 1.2975 Valid Accuracy: 65.5172 Test Loss: 1.3798 Test Accuracy: 61.0169
# Finished Fold
# ==================================================
# Fold 2/5
# Epoch 1/50: Train Loss: 2.9537 Train Accuracy: 18.6724 Valid Loss: 2.4281 Valid Accuracy: 34.3413 Test Loss: 2.6291 Test Accuracy: 31.3559
# Epoch 2/50: Train Loss: 2.0353 Train Accuracy: 47.2207 Valid Loss: 1.7508 Valid Accuracy: 50.3240 Test Loss: 1.9920 Test Accuracy: 43.2203
# Epoch 3/50: Train Loss: 1.4294 Train Accuracy: 63.0329 Valid Loss: 1.3978 Valid Accuracy: 58.0994 Test Loss: 1.5518 Test Accuracy: 54.2373
# Epoch 4/50: Train Loss: 1.0207 Train Accuracy: 74.6357 Valid Loss: 1.2097 Valid Accuracy: 64.3629 Test Loss: 1.3289 Test Accuracy: 56.7797
# Epoch 5/50: Train Loss: 0.7326 Train Accuracy: 84.0259 Valid Loss: 1.1309 Valid Accuracy: 65.0108 Test Loss: 1.2292 Test Accuracy: 58.4746
# Epoch 6/50: Train Loss: 0.5041 Train Accuracy: 90.2321 Valid Loss: 1.0939 Valid Accuracy: 66.7387 Test Loss: 1.1635 Test Accuracy: 60.5932
# Epoch 7/50: Train Loss: 0.3538 Train Accuracy: 94.4414 Valid Loss: 1.0720 Valid Accuracy: 67.1706 Test Loss: 1.1612 Test Accuracy: 61.4407
# Epoch 8/50: Train Loss: 0.2444 Train Accuracy: 96.9239 Valid Loss: 1.0738 Valid Accuracy: 66.7387 Test Loss: 1.1161 Test Accuracy: 62.2881
# Epoch 9/50: Train Loss: 0.1680 Train Accuracy: 98.4350 Valid Loss: 1.0899 Valid Accuracy: 65.4428 Test Loss: 1.1479 Test Accuracy: 62.2881
# Epoch 10/50: Train Loss: 0.1221 Train Accuracy: 98.7048 Valid Loss: 1.1027 Valid Accuracy: 65.8747 Test Loss: 1.1522 Test Accuracy: 60.1695
# Epoch 11/50: Train Loss: 0.0954 Train Accuracy: 99.0286 Valid Loss: 1.0884 Valid Accuracy: 68.2505 Test Loss: 1.1893 Test Accuracy: 61.8644
# Epoch 12/50: Train Loss: 0.0788 Train Accuracy: 99.4064 Valid Loss: 1.1135 Valid Accuracy: 68.0346 Test Loss: 1.2066 Test Accuracy: 63.9831
# Epoch 13/50: Train Loss: 0.0644 Train Accuracy: 99.2445 Valid Loss: 1.1378 Valid Accuracy: 69.3305 Test Loss: 1.2271 Test Accuracy: 63.9831
# Epoch 14/50: Train Loss: 0.0554 Train Accuracy: 99.2445 Valid Loss: 1.1345 Valid Accuracy: 67.8186 Test Loss: 1.2355 Test Accuracy: 63.1356
# Epoch 15/50: Train Loss: 0.0468 Train Accuracy: 99.4603 Valid Loss: 1.1321 Valid Accuracy: 68.0346 Test Loss: 1.2224 Test Accuracy: 63.9831
# Epoch 16/50: Train Loss: 0.0363 Train Accuracy: 99.5143 Valid Loss: 1.1630 Valid Accuracy: 67.8186 Test Loss: 1.2226 Test Accuracy: 63.9831
# Epoch 17/50: Train Loss: 0.0388 Train Accuracy: 99.5683 Valid Loss: 1.1709 Valid Accuracy: 67.8186 Test Loss: 1.2308 Test Accuracy: 63.9831
# Epoch 18/50: Train Loss: 0.0352 Train Accuracy: 99.6222 Valid Loss: 1.1789 Valid Accuracy: 66.9546 Test Loss: 1.2341 Test Accuracy: 64.4068
# Epoch 19/50: Train Loss: 0.0309 Train Accuracy: 99.4603 Valid Loss: 1.1892 Valid Accuracy: 66.5227 Test Loss: 1.2649 Test Accuracy: 63.9831
# Epoch 20/50: Train Loss: 0.0347 Train Accuracy: 99.4603 Valid Loss: 1.1847 Valid Accuracy: 67.1706 Test Loss: 1.3106 Test Accuracy: 63.1356
# Epoch 21/50: Train Loss: 0.0272 Train Accuracy: 99.6222 Valid Loss: 1.1979 Valid Accuracy: 68.2505 Test Loss: 1.2620 Test Accuracy: 63.1356
# Epoch 22/50: Train Loss: 0.0279 Train Accuracy: 99.4064 Valid Loss: 1.2050 Valid Accuracy: 66.3067 Test Loss: 1.2792 Test Accuracy: 63.9831
# Epoch 23/50: Train Loss: 0.0221 Train Accuracy: 99.7841 Valid Loss: 1.2012 Valid Accuracy: 68.2505 Test Loss: 1.3067 Test Accuracy: 62.7119
# Epoch 24/50: Train Loss: 0.0227 Train Accuracy: 99.6762 Valid Loss: 1.1950 Valid Accuracy: 66.9546 Test Loss: 1.3184 Test Accuracy: 64.8305
# Epoch 25/50: Train Loss: 0.0239 Train Accuracy: 99.6762 Valid Loss: 1.2173 Valid Accuracy: 67.6026 Test Loss: 1.3360 Test Accuracy: 62.2881
# Epoch 26/50: Train Loss: 0.0183 Train Accuracy: 99.6222 Valid Loss: 1.2192 Valid Accuracy: 66.7387 Test Loss: 1.3274 Test Accuracy: 63.1356
# Epoch 27/50: Train Loss: 0.0179 Train Accuracy: 99.5683 Valid Loss: 1.2173 Valid Accuracy: 68.2505 Test Loss: 1.3036 Test Accuracy: 63.9831
# Epoch 28/50: Train Loss: 0.0172 Train Accuracy: 99.6222 Valid Loss: 1.2504 Valid Accuracy: 67.1706 Test Loss: 1.3241 Test Accuracy: 62.2881
# Epoch 29/50: Train Loss: 0.0167 Train Accuracy: 99.6222 Valid Loss: 1.2352 Valid Accuracy: 67.3866 Test Loss: 1.3098 Test Accuracy: 63.5593
# Epoch 30/50: Train Loss: 0.0198 Train Accuracy: 99.4064 Valid Loss: 1.2861 Valid Accuracy: 67.3866 Test Loss: 1.3553 Test Accuracy: 62.7119
# Epoch 31/50: Train Loss: 0.0182 Train Accuracy: 99.6762 Valid Loss: 1.2621 Valid Accuracy: 67.3866 Test Loss: 1.3400 Test Accuracy: 63.1356
# Epoch 32/50: Train Loss: 0.0189 Train Accuracy: 99.4603 Valid Loss: 1.2432 Valid Accuracy: 66.3067 Test Loss: 1.3709 Test Accuracy: 62.7119
# Epoch 33/50: Train Loss: 0.0149 Train Accuracy: 99.7302 Valid Loss: 1.2514 Valid Accuracy: 67.8186 Test Loss: 1.3787 Test Accuracy: 61.0169
# Epoch 34/50: Train Loss: 0.0130 Train Accuracy: 99.6222 Valid Loss: 1.2581 Valid Accuracy: 66.9546 Test Loss: 1.3820 Test Accuracy: 62.2881
# Epoch 35/50: Train Loss: 0.0145 Train Accuracy: 99.7841 Valid Loss: 1.2568 Valid Accuracy: 67.3866 Test Loss: 1.3790 Test Accuracy: 64.4068
# Epoch 36/50: Train Loss: 0.0130 Train Accuracy: 99.7841 Valid Loss: 1.2587 Valid Accuracy: 66.5227 Test Loss: 1.3596 Test Accuracy: 63.9831
# Epoch 37/50: Train Loss: 0.0129 Train Accuracy: 99.6762 Valid Loss: 1.2828 Valid Accuracy: 67.3866 Test Loss: 1.4040 Test Accuracy: 64.8305
# Epoch 38/50: Train Loss: 0.0106 Train Accuracy: 99.6762 Valid Loss: 1.2685 Valid Accuracy: 66.9546 Test Loss: 1.4200 Test Accuracy: 62.7119
# Epoch 39/50: Train Loss: 0.0113 Train Accuracy: 99.7841 Valid Loss: 1.2838 Valid Accuracy: 65.8747 Test Loss: 1.4149 Test Accuracy: 63.1356
# Epoch 40/50: Train Loss: 0.0101 Train Accuracy: 99.7841 Valid Loss: 1.3041 Valid Accuracy: 66.5227 Test Loss: 1.4136 Test Accuracy: 63.5593
# Epoch 41/50: Train Loss: 0.0122 Train Accuracy: 99.6762 Valid Loss: 1.2901 Valid Accuracy: 66.9546 Test Loss: 1.3945 Test Accuracy: 63.1356
# Epoch 42/50: Train Loss: 0.0095 Train Accuracy: 99.7302 Valid Loss: 1.2778 Valid Accuracy: 67.3866 Test Loss: 1.4235 Test Accuracy: 62.2881
# Epoch 43/50: Train Loss: 0.0106 Train Accuracy: 99.6762 Valid Loss: 1.2918 Valid Accuracy: 66.9546 Test Loss: 1.4118 Test Accuracy: 63.9831
# Epoch 44/50: Train Loss: 0.0121 Train Accuracy: 99.6762 Valid Loss: 1.2896 Valid Accuracy: 66.9546 Test Loss: 1.4029 Test Accuracy: 63.9831
# Epoch 45/50: Train Loss: 0.0108 Train Accuracy: 99.6762 Valid Loss: 1.3010 Valid Accuracy: 66.5227 Test Loss: 1.4423 Test Accuracy: 62.2881
# Epoch 46/50: Train Loss: 0.0104 Train Accuracy: 99.7841 Valid Loss: 1.2829 Valid Accuracy: 66.5227 Test Loss: 1.4150 Test Accuracy: 63.1356
# Epoch 47/50: Train Loss: 0.0095 Train Accuracy: 99.7302 Valid Loss: 1.2874 Valid Accuracy: 68.2505 Test Loss: 1.4001 Test Accuracy: 63.5593
# Epoch 48/50: Train Loss: 0.0102 Train Accuracy: 99.7302 Valid Loss: 1.2857 Valid Accuracy: 67.1706 Test Loss: 1.4087 Test Accuracy: 63.1356
# Epoch 49/50: Train Loss: 0.0090 Train Accuracy: 99.6762 Valid Loss: 1.2902 Valid Accuracy: 67.8186 Test Loss: 1.4287 Test Accuracy: 63.9831
# Epoch 50/50: Train Loss: 0.0092 Train Accuracy: 99.7302 Valid Loss: 1.2931 Valid Accuracy: 68.0346 Test Loss: 1.4541 Test Accuracy: 63.1356
# Finished Fold
# ==================================================
# Fold 3/5
# Epoch 1/50: Train Loss: 3.0103 Train Accuracy: 17.4852 Valid Loss: 2.5174 Valid Accuracy: 30.6695 Test Loss: 2.7143 Test Accuracy: 25.4237
# Epoch 2/50: Train Loss: 2.0800 Train Accuracy: 45.1160 Valid Loss: 1.8564 Valid Accuracy: 49.0281 Test Loss: 2.0578 Test Accuracy: 38.5593
# Epoch 3/50: Train Loss: 1.4609 Train Accuracy: 62.4393 Valid Loss: 1.4988 Valid Accuracy: 57.6674 Test Loss: 1.6218 Test Accuracy: 52.9661
# Epoch 4/50: Train Loss: 1.0538 Train Accuracy: 72.8548 Valid Loss: 1.3186 Valid Accuracy: 60.0432 Test Loss: 1.4181 Test Accuracy: 56.3559
# Epoch 5/50: Train Loss: 0.7341 Train Accuracy: 83.3783 Valid Loss: 1.2324 Valid Accuracy: 63.0670 Test Loss: 1.2513 Test Accuracy: 62.7119
# Epoch 6/50: Train Loss: 0.5195 Train Accuracy: 89.1527 Valid Loss: 1.2007 Valid Accuracy: 61.9870 Test Loss: 1.2043 Test Accuracy: 58.8983
# Epoch 7/50: Train Loss: 0.3692 Train Accuracy: 94.3875 Valid Loss: 1.1722 Valid Accuracy: 64.1469 Test Loss: 1.1894 Test Accuracy: 62.2881
# Epoch 8/50: Train Loss: 0.2431 Train Accuracy: 97.0858 Valid Loss: 1.1488 Valid Accuracy: 65.4428 Test Loss: 1.1802 Test Accuracy: 58.8983
# Epoch 9/50: Train Loss: 0.1782 Train Accuracy: 98.5969 Valid Loss: 1.1654 Valid Accuracy: 65.6587 Test Loss: 1.2072 Test Accuracy: 61.8644
# Epoch 10/50: Train Loss: 0.1322 Train Accuracy: 98.5969 Valid Loss: 1.1727 Valid Accuracy: 64.3629 Test Loss: 1.1970 Test Accuracy: 63.1356
# Epoch 11/50: Train Loss: 0.1056 Train Accuracy: 99.1365 Valid Loss: 1.1852 Valid Accuracy: 64.1469 Test Loss: 1.2045 Test Accuracy: 62.7119
# Epoch 12/50: Train Loss: 0.0865 Train Accuracy: 99.1905 Valid Loss: 1.2129 Valid Accuracy: 65.0108 Test Loss: 1.2203 Test Accuracy: 62.7119
# Epoch 13/50: Train Loss: 0.0724 Train Accuracy: 99.2445 Valid Loss: 1.1868 Valid Accuracy: 65.4428 Test Loss: 1.2833 Test Accuracy: 61.8644
# Epoch 14/50: Train Loss: 0.0589 Train Accuracy: 99.2984 Valid Loss: 1.2194 Valid Accuracy: 64.7948 Test Loss: 1.2798 Test Accuracy: 62.2881
# Epoch 15/50: Train Loss: 0.0503 Train Accuracy: 99.4064 Valid Loss: 1.2292 Valid Accuracy: 65.2268 Test Loss: 1.2890 Test Accuracy: 62.7119
# Epoch 16/50: Train Loss: 0.0480 Train Accuracy: 99.3524 Valid Loss: 1.2449 Valid Accuracy: 66.5227 Test Loss: 1.2762 Test Accuracy: 63.1356
# Epoch 17/50: Train Loss: 0.0408 Train Accuracy: 99.2984 Valid Loss: 1.2243 Valid Accuracy: 65.4428 Test Loss: 1.2888 Test Accuracy: 62.2881
# Epoch 18/50: Train Loss: 0.0349 Train Accuracy: 99.4603 Valid Loss: 1.2498 Valid Accuracy: 65.0108 Test Loss: 1.3304 Test Accuracy: 62.2881
# Epoch 19/50: Train Loss: 0.0322 Train Accuracy: 99.6222 Valid Loss: 1.2502 Valid Accuracy: 65.4428 Test Loss: 1.3247 Test Accuracy: 63.5593
# Epoch 20/50: Train Loss: 0.0297 Train Accuracy: 99.5143 Valid Loss: 1.2572 Valid Accuracy: 65.4428 Test Loss: 1.3469 Test Accuracy: 63.5593
# Epoch 21/50: Train Loss: 0.0291 Train Accuracy: 99.5683 Valid Loss: 1.2740 Valid Accuracy: 65.6587 Test Loss: 1.3582 Test Accuracy: 61.4407
# Epoch 22/50: Train Loss: 0.0261 Train Accuracy: 99.5683 Valid Loss: 1.2818 Valid Accuracy: 66.0907 Test Loss: 1.3560 Test Accuracy: 63.5593
# Epoch 23/50: Train Loss: 0.0289 Train Accuracy: 99.4603 Valid Loss: 1.2879 Valid Accuracy: 65.6587 Test Loss: 1.3444 Test Accuracy: 62.2881
# Epoch 24/50: Train Loss: 0.0269 Train Accuracy: 99.3524 Valid Loss: 1.2989 Valid Accuracy: 66.7387 Test Loss: 1.3569 Test Accuracy: 63.1356
# Epoch 25/50: Train Loss: 0.0250 Train Accuracy: 99.5143 Valid Loss: 1.2831 Valid Accuracy: 65.6587 Test Loss: 1.3907 Test Accuracy: 63.5593
# Epoch 26/50: Train Loss: 0.0224 Train Accuracy: 99.5683 Valid Loss: 1.3067 Valid Accuracy: 65.6587 Test Loss: 1.3638 Test Accuracy: 61.8644
# Epoch 27/50: Train Loss: 0.0202 Train Accuracy: 99.5683 Valid Loss: 1.2793 Valid Accuracy: 66.7387 Test Loss: 1.3753 Test Accuracy: 63.5593
# Epoch 28/50: Train Loss: 0.0176 Train Accuracy: 99.6222 Valid Loss: 1.2898 Valid Accuracy: 66.3067 Test Loss: 1.3787 Test Accuracy: 63.1356
# Epoch 29/50: Train Loss: 0.0164 Train Accuracy: 99.7841 Valid Loss: 1.3140 Valid Accuracy: 66.9546 Test Loss: 1.3881 Test Accuracy: 62.2881
# Epoch 30/50: Train Loss: 0.0192 Train Accuracy: 99.6222 Valid Loss: 1.3235 Valid Accuracy: 65.6587 Test Loss: 1.4068 Test Accuracy: 61.4407
# Epoch 31/50: Train Loss: 0.0161 Train Accuracy: 99.6222 Valid Loss: 1.3062 Valid Accuracy: 66.5227 Test Loss: 1.4120 Test Accuracy: 62.2881
# Epoch 32/50: Train Loss: 0.0155 Train Accuracy: 99.6222 Valid Loss: 1.3341 Valid Accuracy: 65.6587 Test Loss: 1.4533 Test Accuracy: 62.2881
# Epoch 33/50: Train Loss: 0.0150 Train Accuracy: 99.5683 Valid Loss: 1.3152 Valid Accuracy: 66.9546 Test Loss: 1.4470 Test Accuracy: 63.1356
# Epoch 34/50: Train Loss: 0.0164 Train Accuracy: 99.6222 Valid Loss: 1.3131 Valid Accuracy: 66.9546 Test Loss: 1.4321 Test Accuracy: 63.5593
# Epoch 35/50: Train Loss: 0.0153 Train Accuracy: 99.6762 Valid Loss: 1.3531 Valid Accuracy: 67.1706 Test Loss: 1.4378 Test Accuracy: 61.8644
# Epoch 36/50: Train Loss: 0.0137 Train Accuracy: 99.7302 Valid Loss: 1.3330 Valid Accuracy: 66.3067 Test Loss: 1.4448 Test Accuracy: 63.1356
# Epoch 37/50: Train Loss: 0.0129 Train Accuracy: 99.6762 Valid Loss: 1.3709 Valid Accuracy: 66.7387 Test Loss: 1.4548 Test Accuracy: 63.9831
# Epoch 38/50: Train Loss: 0.0129 Train Accuracy: 99.6762 Valid Loss: 1.3314 Valid Accuracy: 68.4665 Test Loss: 1.4608 Test Accuracy: 63.5593
# Epoch 39/50: Train Loss: 0.0139 Train Accuracy: 99.6762 Valid Loss: 1.3474 Valid Accuracy: 65.8747 Test Loss: 1.4485 Test Accuracy: 62.2881
# Epoch 40/50: Train Loss: 0.0121 Train Accuracy: 99.7302 Valid Loss: 1.3381 Valid Accuracy: 67.1706 Test Loss: 1.4332 Test Accuracy: 63.5593
# Epoch 41/50: Train Loss: 0.0105 Train Accuracy: 99.7302 Valid Loss: 1.3417 Valid Accuracy: 67.6026 Test Loss: 1.4632 Test Accuracy: 63.5593
# Epoch 42/50: Train Loss: 0.0103 Train Accuracy: 99.7302 Valid Loss: 1.3687 Valid Accuracy: 67.1706 Test Loss: 1.4584 Test Accuracy: 62.2881
# Epoch 43/50: Train Loss: 0.0111 Train Accuracy: 99.7841 Valid Loss: 1.3738 Valid Accuracy: 66.0907 Test Loss: 1.4826 Test Accuracy: 61.4407
# Epoch 44/50: Train Loss: 0.0167 Train Accuracy: 99.5143 Valid Loss: 1.3673 Valid Accuracy: 67.1706 Test Loss: 1.4530 Test Accuracy: 63.1356
# Epoch 45/50: Train Loss: 0.0116 Train Accuracy: 99.5683 Valid Loss: 1.3761 Valid Accuracy: 66.0907 Test Loss: 1.4440 Test Accuracy: 63.9831
# Epoch 46/50: Train Loss: 0.0097 Train Accuracy: 99.8381 Valid Loss: 1.3610 Valid Accuracy: 65.8747 Test Loss: 1.4892 Test Accuracy: 62.2881
# Epoch 47/50: Train Loss: 0.0093 Train Accuracy: 99.7302 Valid Loss: 1.3682 Valid Accuracy: 65.6587 Test Loss: 1.4892 Test Accuracy: 62.2881
# Epoch 48/50: Train Loss: 0.0105 Train Accuracy: 99.7302 Valid Loss: 1.3574 Valid Accuracy: 65.0108 Test Loss: 1.4917 Test Accuracy: 63.1356
# Epoch 49/50: Train Loss: 0.0123 Train Accuracy: 99.5683 Valid Loss: 1.4012 Valid Accuracy: 65.6587 Test Loss: 1.4888 Test Accuracy: 61.8644
# Epoch 50/50: Train Loss: 0.0136 Train Accuracy: 99.6222 Valid Loss: 1.3874 Valid Accuracy: 66.3067 Test Loss: 1.4926 Test Accuracy: 62.2881
# Finished Fold
# ==================================================
# Fold 4/5
# Epoch 1/50: Train Loss: 2.9761 Train Accuracy: 16.7836 Valid Loss: 2.4732 Valid Accuracy: 34.7732 Test Loss: 2.6360 Test Accuracy: 25.4237
# Epoch 2/50: Train Loss: 2.0413 Train Accuracy: 46.1954 Valid Loss: 1.7973 Valid Accuracy: 49.4600 Test Loss: 1.9849 Test Accuracy: 40.2542
# Epoch 3/50: Train Loss: 1.4283 Train Accuracy: 62.4933 Valid Loss: 1.4244 Valid Accuracy: 58.5313 Test Loss: 1.5704 Test Accuracy: 52.1186
# Epoch 4/50: Train Loss: 1.0358 Train Accuracy: 74.6897 Valid Loss: 1.2573 Valid Accuracy: 61.9870 Test Loss: 1.3469 Test Accuracy: 54.6610
# Epoch 5/50: Train Loss: 0.7499 Train Accuracy: 82.1910 Valid Loss: 1.1340 Valid Accuracy: 67.6026 Test Loss: 1.2480 Test Accuracy: 57.6271
# Epoch 6/50: Train Loss: 0.5007 Train Accuracy: 91.2035 Valid Loss: 1.0747 Valid Accuracy: 67.8186 Test Loss: 1.2223 Test Accuracy: 58.4746
# Epoch 7/50: Train Loss: 0.3541 Train Accuracy: 95.0890 Valid Loss: 1.0663 Valid Accuracy: 67.8186 Test Loss: 1.1658 Test Accuracy: 60.1695
# Epoch 8/50: Train Loss: 0.2488 Train Accuracy: 97.0858 Valid Loss: 1.0472 Valid Accuracy: 69.5464 Test Loss: 1.1539 Test Accuracy: 59.7458
# Epoch 9/50: Train Loss: 0.1740 Train Accuracy: 98.2731 Valid Loss: 1.0549 Valid Accuracy: 69.3305 Test Loss: 1.1988 Test Accuracy: 61.0169
# Epoch 10/50: Train Loss: 0.1310 Train Accuracy: 98.7048 Valid Loss: 1.0553 Valid Accuracy: 68.8985 Test Loss: 1.1888 Test Accuracy: 61.4407
# Epoch 11/50: Train Loss: 0.1040 Train Accuracy: 98.8127 Valid Loss: 1.0528 Valid Accuracy: 69.1145 Test Loss: 1.1834 Test Accuracy: 60.1695
# Epoch 12/50: Train Loss: 0.0825 Train Accuracy: 99.0826 Valid Loss: 1.0828 Valid Accuracy: 69.3305 Test Loss: 1.2314 Test Accuracy: 61.8644
# Epoch 13/50: Train Loss: 0.0681 Train Accuracy: 99.0826 Valid Loss: 1.0814 Valid Accuracy: 68.6825 Test Loss: 1.2382 Test Accuracy: 63.1356
# Epoch 14/50: Train Loss: 0.0600 Train Accuracy: 99.1905 Valid Loss: 1.0955 Valid Accuracy: 69.9784 Test Loss: 1.2448 Test Accuracy: 58.8983
# Epoch 15/50: Train Loss: 0.0580 Train Accuracy: 99.2984 Valid Loss: 1.0978 Valid Accuracy: 70.1944 Test Loss: 1.2716 Test Accuracy: 61.8644
# Epoch 16/50: Train Loss: 0.0517 Train Accuracy: 99.1365 Valid Loss: 1.0966 Valid Accuracy: 68.2505 Test Loss: 1.2543 Test Accuracy: 63.9831
# Epoch 17/50: Train Loss: 0.0423 Train Accuracy: 99.1905 Valid Loss: 1.0996 Valid Accuracy: 69.7624 Test Loss: 1.2573 Test Accuracy: 61.0169
# Epoch 18/50: Train Loss: 0.0436 Train Accuracy: 99.1905 Valid Loss: 1.0923 Valid Accuracy: 68.8985 Test Loss: 1.2654 Test Accuracy: 63.9831
# Epoch 19/50: Train Loss: 0.0383 Train Accuracy: 99.0826 Valid Loss: 1.1247 Valid Accuracy: 68.6825 Test Loss: 1.3140 Test Accuracy: 62.2881
# Epoch 20/50: Train Loss: 0.0330 Train Accuracy: 99.1365 Valid Loss: 1.1411 Valid Accuracy: 68.0346 Test Loss: 1.3034 Test Accuracy: 61.8644
# Epoch 21/50: Train Loss: 0.0298 Train Accuracy: 99.5683 Valid Loss: 1.1232 Valid Accuracy: 68.8985 Test Loss: 1.3035 Test Accuracy: 61.0169
# Epoch 22/50: Train Loss: 0.0329 Train Accuracy: 99.1905 Valid Loss: 1.1351 Valid Accuracy: 68.8985 Test Loss: 1.3285 Test Accuracy: 63.1356
# Epoch 23/50: Train Loss: 0.0269 Train Accuracy: 99.4064 Valid Loss: 1.1513 Valid Accuracy: 68.4665 Test Loss: 1.3366 Test Accuracy: 63.9831
# Epoch 24/50: Train Loss: 0.0270 Train Accuracy: 99.3524 Valid Loss: 1.1569 Valid Accuracy: 68.4665 Test Loss: 1.3390 Test Accuracy: 63.1356
# Epoch 25/50: Train Loss: 0.0260 Train Accuracy: 99.2445 Valid Loss: 1.1539 Valid Accuracy: 69.3305 Test Loss: 1.3499 Test Accuracy: 61.0169
# Epoch 26/50: Train Loss: 0.0260 Train Accuracy: 99.3524 Valid Loss: 1.1562 Valid Accuracy: 69.3305 Test Loss: 1.3468 Test Accuracy: 62.7119
# Epoch 27/50: Train Loss: 0.0243 Train Accuracy: 99.4064 Valid Loss: 1.1647 Valid Accuracy: 69.3305 Test Loss: 1.3589 Test Accuracy: 61.4407
# Epoch 28/50: Train Loss: 0.0262 Train Accuracy: 99.2984 Valid Loss: 1.1529 Valid Accuracy: 69.3305 Test Loss: 1.3500 Test Accuracy: 61.8644
# Epoch 29/50: Train Loss: 0.0208 Train Accuracy: 99.2984 Valid Loss: 1.1684 Valid Accuracy: 68.6825 Test Loss: 1.3571 Test Accuracy: 62.7119
# Epoch 30/50: Train Loss: 0.0200 Train Accuracy: 99.3524 Valid Loss: 1.1594 Valid Accuracy: 69.7624 Test Loss: 1.3472 Test Accuracy: 62.2881
# Epoch 31/50: Train Loss: 0.0191 Train Accuracy: 99.6762 Valid Loss: 1.1686 Valid Accuracy: 69.1145 Test Loss: 1.3888 Test Accuracy: 61.0169
# Epoch 32/50: Train Loss: 0.0172 Train Accuracy: 99.5143 Valid Loss: 1.1716 Valid Accuracy: 69.5464 Test Loss: 1.3942 Test Accuracy: 61.0169
# Epoch 33/50: Train Loss: 0.0197 Train Accuracy: 99.3524 Valid Loss: 1.1814 Valid Accuracy: 70.1944 Test Loss: 1.4101 Test Accuracy: 61.8644
# Epoch 34/50: Train Loss: 0.0163 Train Accuracy: 99.7302 Valid Loss: 1.2071 Valid Accuracy: 69.7624 Test Loss: 1.3987 Test Accuracy: 61.8644
# Epoch 35/50: Train Loss: 0.0155 Train Accuracy: 99.5683 Valid Loss: 1.2065 Valid Accuracy: 69.3305 Test Loss: 1.4122 Test Accuracy: 62.2881
# Epoch 36/50: Train Loss: 0.0188 Train Accuracy: 99.4064 Valid Loss: 1.1907 Valid Accuracy: 69.5464 Test Loss: 1.3901 Test Accuracy: 62.7119
# Epoch 37/50: Train Loss: 0.0157 Train Accuracy: 99.4603 Valid Loss: 1.2126 Valid Accuracy: 68.6825 Test Loss: 1.4006 Test Accuracy: 61.0169
# Epoch 38/50: Train Loss: 0.0169 Train Accuracy: 99.4603 Valid Loss: 1.1931 Valid Accuracy: 69.7624 Test Loss: 1.4362 Test Accuracy: 61.8644
# Epoch 39/50: Train Loss: 0.0167 Train Accuracy: 99.4064 Valid Loss: 1.2048 Valid Accuracy: 68.0346 Test Loss: 1.3882 Test Accuracy: 63.5593
# Epoch 40/50: Train Loss: 0.0175 Train Accuracy: 99.2984 Valid Loss: 1.2185 Valid Accuracy: 69.5464 Test Loss: 1.4268 Test Accuracy: 62.7119
# Epoch 41/50: Train Loss: 0.0160 Train Accuracy: 99.2984 Valid Loss: 1.2074 Valid Accuracy: 69.5464 Test Loss: 1.4051 Test Accuracy: 61.4407
# Epoch 42/50: Train Loss: 0.0155 Train Accuracy: 99.4064 Valid Loss: 1.2000 Valid Accuracy: 69.9784 Test Loss: 1.4126 Test Accuracy: 63.5593
# Epoch 43/50: Train Loss: 0.0135 Train Accuracy: 99.5683 Valid Loss: 1.2097 Valid Accuracy: 69.9784 Test Loss: 1.4076 Test Accuracy: 61.8644
# Epoch 44/50: Train Loss: 0.0144 Train Accuracy: 99.3524 Valid Loss: 1.2110 Valid Accuracy: 69.1145 Test Loss: 1.4372 Test Accuracy: 62.2881
# Epoch 45/50: Train Loss: 0.0117 Train Accuracy: 99.7841 Valid Loss: 1.2084 Valid Accuracy: 69.1145 Test Loss: 1.4193 Test Accuracy: 63.9831
# Epoch 46/50: Train Loss: 0.0163 Train Accuracy: 99.3524 Valid Loss: 1.2389 Valid Accuracy: 69.3305 Test Loss: 1.4446 Test Accuracy: 62.7119
# Epoch 47/50: Train Loss: 0.0160 Train Accuracy: 99.4603 Valid Loss: 1.2290 Valid Accuracy: 70.8423 Test Loss: 1.4093 Test Accuracy: 62.2881
# Epoch 48/50: Train Loss: 0.0147 Train Accuracy: 99.4064 Valid Loss: 1.2277 Valid Accuracy: 68.6825 Test Loss: 1.4201 Test Accuracy: 61.4407
# Epoch 49/50: Train Loss: 0.0133 Train Accuracy: 99.5143 Valid Loss: 1.2303 Valid Accuracy: 70.1944 Test Loss: 1.4334 Test Accuracy: 62.2881
# Epoch 50/50: Train Loss: 0.0122 Train Accuracy: 99.6222 Valid Loss: 1.2379 Valid Accuracy: 68.0346 Test Loss: 1.4243 Test Accuracy: 62.7119
# Finished Fold
# ==================================================
# Fold 5/5
# Epoch 1/50: Train Loss: 2.9516 Train Accuracy: 18.5645 Valid Loss: 2.4488 Valid Accuracy: 35.8531 Test Loss: 2.6375 Test Accuracy: 25.0000
# Epoch 2/50: Train Loss: 2.0664 Train Accuracy: 45.7097 Valid Loss: 1.7873 Valid Accuracy: 48.5961 Test Loss: 2.0442 Test Accuracy: 40.2542
# Epoch 3/50: Train Loss: 1.4571 Train Accuracy: 62.8710 Valid Loss: 1.4470 Valid Accuracy: 56.3715 Test Loss: 1.6576 Test Accuracy: 51.6949
# Epoch 4/50: Train Loss: 1.0575 Train Accuracy: 73.0167 Valid Loss: 1.2428 Valid Accuracy: 62.8510 Test Loss: 1.4253 Test Accuracy: 56.7797
# Epoch 5/50: Train Loss: 0.7545 Train Accuracy: 82.5148 Valid Loss: 1.1746 Valid Accuracy: 61.7711 Test Loss: 1.3228 Test Accuracy: 56.3559
# Epoch 6/50: Train Loss: 0.5293 Train Accuracy: 89.3686 Valid Loss: 1.1026 Valid Accuracy: 62.4190 Test Loss: 1.2446 Test Accuracy: 59.7458
# Epoch 7/50: Train Loss: 0.3740 Train Accuracy: 93.9557 Valid Loss: 1.0716 Valid Accuracy: 62.8510 Test Loss: 1.1965 Test Accuracy: 61.0169
# Epoch 8/50: Train Loss: 0.2629 Train Accuracy: 96.4382 Valid Loss: 1.0962 Valid Accuracy: 63.9309 Test Loss: 1.1977 Test Accuracy: 62.2881
# Epoch 9/50: Train Loss: 0.1775 Train Accuracy: 98.3270 Valid Loss: 1.1064 Valid Accuracy: 61.9870 Test Loss: 1.2086 Test Accuracy: 62.2881
# Epoch 10/50: Train Loss: 0.1285 Train Accuracy: 99.1365 Valid Loss: 1.1218 Valid Accuracy: 63.0670 Test Loss: 1.2539 Test Accuracy: 60.1695
# Epoch 11/50: Train Loss: 0.1036 Train Accuracy: 99.1365 Valid Loss: 1.1274 Valid Accuracy: 62.4190 Test Loss: 1.2251 Test Accuracy: 62.7119
# Epoch 12/50: Train Loss: 0.0859 Train Accuracy: 99.2445 Valid Loss: 1.1312 Valid Accuracy: 62.8510 Test Loss: 1.2532 Test Accuracy: 63.1356
# Epoch 13/50: Train Loss: 0.0673 Train Accuracy: 99.3524 Valid Loss: 1.1458 Valid Accuracy: 64.3629 Test Loss: 1.2439 Test Accuracy: 63.5593
# Epoch 14/50: Train Loss: 0.0643 Train Accuracy: 99.0826 Valid Loss: 1.1515 Valid Accuracy: 63.2829 Test Loss: 1.2815 Test Accuracy: 63.5593
# Epoch 15/50: Train Loss: 0.0502 Train Accuracy: 99.4603 Valid Loss: 1.1549 Valid Accuracy: 63.7149 Test Loss: 1.2872 Test Accuracy: 62.7119
# Epoch 16/50: Train Loss: 0.0400 Train Accuracy: 99.5143 Valid Loss: 1.1651 Valid Accuracy: 64.1469 Test Loss: 1.2798 Test Accuracy: 62.7119
# Epoch 17/50: Train Loss: 0.0382 Train Accuracy: 99.2984 Valid Loss: 1.1758 Valid Accuracy: 63.4989 Test Loss: 1.3319 Test Accuracy: 63.1356
# Epoch 18/50: Train Loss: 0.0356 Train Accuracy: 99.3524 Valid Loss: 1.1879 Valid Accuracy: 65.2268 Test Loss: 1.3304 Test Accuracy: 62.7119
# Epoch 19/50: Train Loss: 0.0320 Train Accuracy: 99.6222 Valid Loss: 1.2031 Valid Accuracy: 63.0670 Test Loss: 1.3388 Test Accuracy: 61.4407
# Epoch 20/50: Train Loss: 0.0338 Train Accuracy: 99.0826 Valid Loss: 1.2097 Valid Accuracy: 63.4989 Test Loss: 1.3426 Test Accuracy: 63.1356
# Epoch 21/50: Train Loss: 0.0293 Train Accuracy: 99.4064 Valid Loss: 1.1968 Valid Accuracy: 64.1469 Test Loss: 1.3424 Test Accuracy: 62.7119
# Epoch 22/50: Train Loss: 0.0288 Train Accuracy: 99.5683 Valid Loss: 1.2132 Valid Accuracy: 63.9309 Test Loss: 1.3693 Test Accuracy: 62.7119
# Epoch 23/50: Train Loss: 0.0250 Train Accuracy: 99.4603 Valid Loss: 1.2102 Valid Accuracy: 64.5788 Test Loss: 1.3874 Test Accuracy: 61.8644
# Epoch 24/50: Train Loss: 0.0247 Train Accuracy: 99.4603 Valid Loss: 1.2160 Valid Accuracy: 64.7948 Test Loss: 1.3835 Test Accuracy: 62.2881
# Epoch 25/50: Train Loss: 0.0227 Train Accuracy: 99.5683 Valid Loss: 1.2466 Valid Accuracy: 63.0670 Test Loss: 1.4352 Test Accuracy: 63.1356
# Epoch 26/50: Train Loss: 0.0221 Train Accuracy: 99.5683 Valid Loss: 1.2295 Valid Accuracy: 63.2829 Test Loss: 1.3793 Test Accuracy: 63.1356
# Epoch 27/50: Train Loss: 0.0194 Train Accuracy: 99.6762 Valid Loss: 1.2417 Valid Accuracy: 65.2268 Test Loss: 1.4100 Test Accuracy: 62.2881
# Epoch 28/50: Train Loss: 0.0195 Train Accuracy: 99.6222 Valid Loss: 1.2546 Valid Accuracy: 63.9309 Test Loss: 1.4159 Test Accuracy: 63.1356
# Epoch 29/50: Train Loss: 0.0191 Train Accuracy: 99.5143 Valid Loss: 1.2511 Valid Accuracy: 64.7948 Test Loss: 1.4165 Test Accuracy: 63.1356
# Epoch 30/50: Train Loss: 0.0202 Train Accuracy: 99.4603 Valid Loss: 1.2688 Valid Accuracy: 62.6350 Test Loss: 1.4525 Test Accuracy: 62.7119
# Epoch 31/50: Train Loss: 0.0191 Train Accuracy: 99.4603 Valid Loss: 1.2916 Valid Accuracy: 63.2829 Test Loss: 1.4255 Test Accuracy: 62.2881
# Epoch 32/50: Train Loss: 0.0173 Train Accuracy: 99.5683 Valid Loss: 1.2766 Valid Accuracy: 64.7948 Test Loss: 1.4286 Test Accuracy: 62.2881
# Epoch 33/50: Train Loss: 0.0225 Train Accuracy: 99.2984 Valid Loss: 1.2707 Valid Accuracy: 64.7948 Test Loss: 1.3897 Test Accuracy: 61.4407
# Epoch 34/50: Train Loss: 0.0182 Train Accuracy: 99.4603 Valid Loss: 1.2769 Valid Accuracy: 64.5788 Test Loss: 1.3838 Test Accuracy: 62.2881
# Epoch 35/50: Train Loss: 0.0169 Train Accuracy: 99.5143 Valid Loss: 1.2792 Valid Accuracy: 65.6587 Test Loss: 1.4106 Test Accuracy: 62.7119
# Epoch 36/50: Train Loss: 0.0183 Train Accuracy: 99.4064 Valid Loss: 1.2903 Valid Accuracy: 63.9309 Test Loss: 1.4239 Test Accuracy: 62.7119
# Epoch 37/50: Train Loss: 0.0168 Train Accuracy: 99.5683 Valid Loss: 1.3113 Valid Accuracy: 62.6350 Test Loss: 1.4326 Test Accuracy: 63.5593
# Epoch 38/50: Train Loss: 0.0153 Train Accuracy: 99.3524 Valid Loss: 1.3003 Valid Accuracy: 64.5788 Test Loss: 1.4520 Test Accuracy: 63.1356
# Epoch 39/50: Train Loss: 0.0154 Train Accuracy: 99.6222 Valid Loss: 1.2958 Valid Accuracy: 64.3629 Test Loss: 1.4317 Test Accuracy: 63.9831
# Epoch 40/50: Train Loss: 0.0131 Train Accuracy: 99.5683 Valid Loss: 1.3093 Valid Accuracy: 64.3629 Test Loss: 1.4673 Test Accuracy: 63.1356
# Epoch 41/50: Train Loss: 0.0145 Train Accuracy: 99.4603 Valid Loss: 1.2867 Valid Accuracy: 64.7948 Test Loss: 1.4549 Test Accuracy: 63.5593
# Epoch 42/50: Train Loss: 0.0126 Train Accuracy: 99.5683 Valid Loss: 1.3018 Valid Accuracy: 64.7948 Test Loss: 1.4589 Test Accuracy: 63.1356
# Epoch 43/50: Train Loss: 0.0132 Train Accuracy: 99.6762 Valid Loss: 1.3011 Valid Accuracy: 64.5788 Test Loss: 1.4500 Test Accuracy: 62.7119
# Epoch 44/50: Train Loss: 0.0136 Train Accuracy: 99.5683 Valid Loss: 1.3150 Valid Accuracy: 64.7948 Test Loss: 1.4285 Test Accuracy: 61.8644
# Epoch 45/50: Train Loss: 0.0147 Train Accuracy: 99.5143 Valid Loss: 1.3197 Valid Accuracy: 65.4428 Test Loss: 1.4576 Test Accuracy: 61.8644
# Epoch 46/50: Train Loss: 0.0128 Train Accuracy: 99.4603 Valid Loss: 1.2957 Valid Accuracy: 64.5788 Test Loss: 1.4841 Test Accuracy: 62.2881
# Epoch 47/50: Train Loss: 0.0134 Train Accuracy: 99.5683 Valid Loss: 1.3142 Valid Accuracy: 65.2268 Test Loss: 1.5056 Test Accuracy: 62.7119
# Epoch 48/50: Train Loss: 0.0133 Train Accuracy: 99.5683 Valid Loss: 1.3277 Valid Accuracy: 64.5788 Test Loss: 1.5073 Test Accuracy: 63.1356
# Epoch 49/50: Train Loss: 0.0146 Train Accuracy: 99.4064 Valid Loss: 1.3188 Valid Accuracy: 65.6587 Test Loss: 1.4790 Test Accuracy: 62.7119
# Epoch 50/50: Train Loss: 0.0115 Train Accuracy: 99.5683 Valid Loss: 1.3226 Valid Accuracy: 64.3629 Test Loss: 1.4804 Test Accuracy: 62.2881
# Finished Fold
# ==================================================

# %%
# Evaluate the trained model on the training and validation sets for each fold.
resnet50_avg_train_acc_k_folds = []
resnet50_avg_val_acc_k_folds = []

def evaluate_accuracy(history, index):
    history_cpu = [item.cpu() for item in history]
    return sum(history_cpu) / len(history_cpu)

for i in range(num_folds):
    train_accuracy = evaluate_accuracy(fold_train_accs[i], 2)
    valid_accuracy = evaluate_accuracy(fold_valid_accs[i], 3)
    print(f'Fold {i + 1}/{num_folds}:')
    print(f'\tTraining Accuracy: {train_accuracy * 100:.2f}%')
    print(f'\tValidation Accuracy: {valid_accuracy * 100:.2f}%')
    resnet50_avg_train_acc_k_folds.append(train_accuracy)
    resnet50_avg_val_acc_k_folds.append(valid_accuracy)

# Compute the average training and validation accuracy over all folds.
overall_train_acc = sum(resnet50_avg_train_acc_k_folds) / len(resnet50_avg_train_acc_k_folds)
overall_val_acc = sum(resnet50_avg_val_acc_k_folds) / len(resnet50_avg_val_acc_k_folds)

# Calculate the average and standard deviation of the training and validation accuracy over all folds.
resnet50_avg_train_acc = np.mean(resnet50_avg_train_acc_k_folds)
resnet50_std_train_acc = np.std(resnet50_avg_train_acc_k_folds)
resnet50_avg_val_acc = np.mean(resnet50_avg_val_acc_k_folds)
resnet50_std_val_acc = np.std(resnet50_avg_val_acc_k_folds)

# Print the average and standard deviation of the training and validation accuracy over all folds.
print(f'\nAverage Training Accuracy over {num_folds}-fold Cross Validation: {resnet50_avg_train_acc * 100:.2f}% +/- {resnet50_std_train_acc * 100:.2f}%')
print(f'Average Validation Accuracy over {num_folds}-fold Cross Validation: {resnet50_avg_val_acc * 100:.2f}% +/- {resnet50_std_val_acc * 100:.2f}%')
# Out:
# Fold 1/5:
# 	Training Accuracy: 94.69%
# 	Validation Accuracy: 64.03%
# Fold 2/5:
# 	Training Accuracy: 95.01%
# 	Validation Accuracy: 65.96%
# Fold 3/5:
# 	Training Accuracy: 94.83%
# 	Validation Accuracy: 64.52%
# Fold 4/5:
# 	Training Accuracy: 94.74%
# 	Validation Accuracy: 67.71%
# Fold 5/5:
# 	Training Accuracy: 94.77%
# 	Validation Accuracy: 62.96%
#
# Average Training Accuracy over 5-fold Cross Validation: 94.81% +/- 0.11%
# Average Validation Accuracy over 5-fold Cross Validation: 65.03% +/- 1.65%

# %%
# Plot the training and validation loss for each epoch
model_name = "ResNet-50"
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(fold_train_losses[fold], label=f'Training Loss (Fold {fold+1})')
    plt.plot(fold_valid_losses[fold], label=f'Validation Loss (Fold {fold+1})')

plt.title(f'{model_name} Training and Validation Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Compute mean loss across all folds at each epoch
train_loss_mean = np.mean([np.array(fold_train_losses[i]) for i in range(num_folds)], axis=0)
valid_loss_mean = np.mean([np.array(fold_valid_losses[i]) for i in range(num_folds)], axis=0)

# Plot mean loss history
plt.figure(figsize=(10, 7))
plt.plot(train_loss_mean, label='Training Loss', color='pink')
plt.plot(valid_loss_mean, label='Validation Loss', color='purple')
plt.title(f'{model_name} Mean Training and Validation Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the training and validation accuracy for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(np.array([acc.cpu() for acc in fold_train_accs[fold]]) * 100, label=f'Training Accuracy (Fold {fold+1})')
    plt.plot(np.array([acc.cpu() for acc in fold_valid_accs[fold]]) * 100, label=f'Validation Accuracy (Fold {fold+1})')

plt.title(f'{model_name} Training and Validation Accuracy - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Compute mean accuracy across all folds at each epoch
train_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_train_accs[i]]) for i in range(num_folds)], axis=0)
valid_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_valid_accs[i]]) for i in range(num_folds)], axis=0)

# Plot mean accuracy history
plt.figure(figsize=(10, 7))
plt.plot(np.arange(1, num_epochs + 1), train_acc_mean * 100, label='Training Accuracy', color='pink')
plt.plot(np.arange(1, num_epochs + 1), valid_acc_mean * 100, label='Validation Accuracy', color='purple')
plt.title(f'{model_name} Mean Training and Validation Accuracy for {num_folds}-fold Cross-validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Evaluate the trained model on the test sets for each fold.
resnet50_avg_test_acc_k_folds = []

def evaluate_accuracy(history, index):
    history_cpu = [item.cpu() for item in history]
    return sum(history_cpu) / len(history_cpu)

for i in range(num_folds):
    test_accuracy = evaluate_accuracy(fold_test_accs[i], 2)
    print(f'Fold {i + 1}/{num_folds}:')
    print(f'\tTest Accuracy: {test_accuracy * 100:.2f}%')
    resnet50_avg_test_acc_k_folds.append(test_accuracy)

# Compute the average test accuracy over all folds.
overall_test_acc = sum(resnet50_avg_test_acc_k_folds) / len(resnet50_avg_test_acc_k_folds)

# Calculate the average and standard deviation of the test accuracy over all folds.
resnet50_avg_test_acc = np.mean(resnet50_avg_test_acc_k_folds)
resnet50_std_test_acc = np.std(resnet50_avg_test_acc_k_folds)

# Print the average and standard deviation of the test accuracy over all folds.
print(f'\nAverage Test Accuracy over {num_folds}-fold Cross Validation: {resnet50_avg_test_acc * 100:.2f}% +/- {resnet50_std_test_acc * 100:.2f}%')
# Out:
# Fold 1/5:
# 	Test Accuracy: 58.73%
# Fold 2/5:
# 	Test Accuracy: 61.69%
# Fold 3/5:
# 	Test Accuracy: 61.01%
# Fold 4/5:
# 	Test Accuracy: 60.36%
# Fold 5/5:
# 	Test Accuracy: 60.91%
#
# Average Test Accuracy over 5-fold Cross Validation: 60.54% +/- 1.00%

# %%
# Plot the test loss for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(fold_test_losses[fold], label=f'Test Loss (Fold {fold+1})')

plt.title(f'{model_name} Test Loss - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the test accuracy for each epoch
plt.figure(figsize=(10, 7))
for fold in range(num_folds):
    plt.plot(np.array([acc.cpu() for acc in fold_test_accs[fold]]) * 100, label=f'Test Accuracy (Fold {fold+1})')

plt.title(f'{model_name} Test Accuracy - {num_folds}-Fold Cross-Validation')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
# Compute mean accuracy across all folds at each epoch
test_acc_mean = np.mean([np.array([acc.cpu() for acc in fold_test_accs[i]]) for i in range(num_folds)], axis=0)

# Plot mean accuracy history
plt.figure(figsize=(10, 7))
plt.plot(np.arange(1, num_epochs + 1), test_acc_mean * 100, label='Test Accuracy', color='purple')
plt.title(f'{model_name} Mean Test Accuracy for {num_folds}-fold Cross-validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# %%
print("Classes: ")
class_names = test_dataset.classes
print(test_dataset.classes)
# Out:
# Classes:
# ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Bell_pepper leaf', 'Bell_pepper leaf spot', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Potato leaf early blight', 'Potato leaf late blight', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'Tomato Early blight leaf', 'Tomato Septoria leaf spot', 'Tomato leaf', 'Tomato leaf bacterial spot', 'Tomato leaf late blight', 'Tomato leaf mosaic virus', 'Tomato leaf yellow virus', 'Tomato mold leaf', 'grape leaf', 'grape leaf black rot']

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

def predict_single_image(model, image_path, device, top_k=3):
    model.eval()

    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    image = Image.open(image_path).convert('RGB')
    image_tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image_tensor)
        probabilities = torch.nn.functional.softmax(output, dim=1)
        top_probs, top_indices = torch.topk(probabilities, top_k)

    top_probs = top_probs.cpu().numpy().flatten()
    top_indices = top_indices.cpu().numpy().flatten()

    return top_probs, top_indices

import matplotlib.cm as cm

def display_image_with_predictions(image_path, top_probs, top_indices, class_names):
    image = Image.open(image_path).convert('RGB')
    
    fig, (ax1, ax2) = plt.subplots(figsize=(8, 4), ncols=2)
    
    ax1.imshow(image)
    ax1.axis('on')
    ax1.set_title(f"Class: {class_names[top_indices[0]]}")
    
    for idx in range(len(top_indices)):
        ax1.annotate(f"{top_probs[idx]*100:.2f}%", 
                     (image.size[0] * (idx+1) / (len(top_indices)+1), image.size[1] - 20),
                     color='white',
                     fontsize=12,
                     bbox=dict(facecolor='black', edgecolor='white', boxstyle='round,pad=0.5'))
    
    y_pos = np.arange(len(top_indices))
    cmap = cm.get_cmap('viridis')
    colors = cmap(np.linspace(0, 1, len(top_indices)))
    ax2.barh(y_pos, top_probs * 100, align='center', color=colors)
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels([test_dataset.classes[idx] for idx in top_indices])
    ax2.invert_yaxis()
    ax2.set_xlabel('Score (%)')
    ax2.set_title('Top 3 Predictions')

    plt.tight_layout()
    plt.show()

image_path = "test/Apple rust leaf/Apple rust leaf (6).jpg"
top_probs, top_indices = predict_single_image(model, image_path, device, top_k=3)
display_image_with_predictions(image_path, top_probs, top_indices, test_dataset.classes)
# Out:
# <ipython-input-27-4a79520e20bc>:49: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis')

# %%
def print_predictions(top_probs, top_indices, class_names):
    print("Predictions:")
    for i in range(len(top_indices)):
        print(f"Prediction {i+1}: {test_dataset.classes[top_indices[i]]}, Score: {top_probs[i] * 100:.5f}%")

print_predictions(top_probs, top_indices, test_dataset.classes)
# Out:
# Predictions:
# Prediction 1: Apple rust leaf, Score: 95.82607%
# Prediction 2: grape leaf black rot, Score: 3.88178%
# Prediction 3: grape leaf, Score: 0.05975%

# %%
image_path = "test/grape leaf black rot/grape leaf black rot (3).jpg"
top_probs, top_indices = predict_single_image(model, image_path, device, top_k=3)
display_image_with_predictions(image_path, top_probs, top_indices, test_dataset.classes)
# Out:
# <ipython-input-27-4a79520e20bc>:49: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis')

# %%
def print_predictions(top_probs, top_indices, class_names):
    print("Predictions:")
    for i in range(len(top_indices)):
        print(f"Prediction {i+1}: {test_dataset.classes[top_indices[i]]}, Score: {top_probs[i] * 100:.5f}%")

print_predictions(top_probs, top_indices, test_dataset.classes)
# Out:
# Predictions:
# Prediction 1: grape leaf black rot, Score: 99.10325%
# Prediction 2: Tomato Septoria leaf spot, Score: 0.33370%
# Prediction 3: Apple rust leaf, Score: 0.15012%
